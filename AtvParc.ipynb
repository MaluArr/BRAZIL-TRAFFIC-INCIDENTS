# %% [markdown]
# <a href="https://colab.research.google.com/github/MaluArr/BRAZIL-TRAFFIC-INCIDENTS/blob/main/AtvParc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **BRAZIL TRAFFIC INCIDENTS**
#
#
# ---
#
# **Requisitos:**
# probabilidade simples
# • probabilidade com união
# • probabilidade com intersecção
# • probabilidade com complemento
# • probabilidade da diferença
# • probabilidades condicional
# • probabilidade com o teorema de Bayes
# • definição de novas variáveis aleatórias
# • função probabilidade
# • função repartição (cumulativa)
# • gráficos simples
# • variância e desvio padrão
# • covariância
# • correlação

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Dados 2019**

# %%
from google.colab import drive
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0f00d44a-bed2-4e3d-86f8-09cfcce9940a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0f00d44a-bed2-4e3d-86f8-09cfcce9940a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
leitura2019 = pd.read_csv(r'Dados_PRF_2019.csv',encoding='cp437', sep = ';' )
leitura2019.head(5)
# Out:
#          id data_inversa   dia_semana   horario  uf     br     km  \
# 0  182256.0   2019-01-01  terτa-feira  04:00:00  CE  116.0  136,9
# 1  182263.0   2019-01-01  terτa-feira  05:00:00  MT  158.0  599,5
# 2  182277.0   2019-01-01  terτa-feira  10:00:00  PA   10.0     34
# 3  182289.0   2019-01-01  terτa-feira  08:30:00  BA  101.0     13
# 4  182307.0   2019-01-01  terτa-feira  13:50:00  BA  116.0    440
#
#           municipio               causa_acidente              tipo_acidente  \
# 0            RUSSAS             Animais na Pista    Atropelamento de Animal
# 1          AGUA BOA  Defeito MecΓnico no Veφculo                   IncΩndio
# 2        DOM ELISEU      Velocidade Incompatφvel           Colisπo traseira
# 3          RIO REAL           Ingestπo de ┴lcool           Colisπo traseira
# 4  FEIRA DE SANTANA           Ingestπo de ┴lcool  Saφda de leito carroτßvel
#
#    ... feridos_graves ilesos ignorados feridos veiculos     latitude  \
# ...

# %%
print(len(leitura2019))
# Out:
# 67556

# %% [markdown]
# # **Dados 2020**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-76f9b2e8-565e-4a1c-ab62-0076f1103eb2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-76f9b2e8-565e-4a1c-ab62-0076f1103eb2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
leitura2020 = pd.read_csv(r'Dados_PRF_2020.csv',encoding='cp437', sep = ';' )
leitura2020.head(5)
# Out:
#          id data_inversa    dia_semana   horario  uf     br     km  \
# 0  260068.0   2020-01-01  quarta-feira  05:40:00  PA  316.0     84
# 1  260073.0   2020-01-01  quarta-feira  06:00:00  MG  262.0    804
# 2  260087.0   2020-01-01  quarta-feira  06:00:00  BA  116.0    191
# 3  260116.0   2020-01-01  quarta-feira  10:08:00  SP  116.0     71
# 4  260129.0   2020-01-01  quarta-feira  12:10:00  MG  262.0  380,9
#
#                municipio                      causa_acidente  \
# 0  SAO FRANCISCO DO PARA         Falta de Atenτπo α Conduτπo
# 1                UBERABA         Falta de Atenτπo α Conduτπo
# 2                CANUDOS                   Condutor Dormindo
# 3              APARECIDA  Nπo guardar distΓncia de seguranτa
# 4                JUATUBA                   Condutor Dormindo
#
#                tipo_acidente  ... feridos_graves ilesos ignorados feridos  \
# 0  Saφda de leito carroτßvel  ...              0      0         0       2
# ...

# %%
print(len(leitura2020))
# Out:
# 63576

# %% [markdown]
# # **Dados 2021**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7f80b80b-8e80-438d-bb42-13a1af846054" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f80b80b-8e80-438d-bb42-13a1af846054">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
leitura2021 = pd.read_csv(r'Dados_PRF_2021.csv',encoding='cp437', sep = ';' )
leitura2021.head(5)
# Out:
#          id data_inversa   dia_semana   horario  uf     br     km  \
# 0  331730.0   2021-01-01  sexta-feira  05:30:00  SP  116.0    453
# 1  331804.0   2021-01-01  sexta-feira  08:05:00  AM  174.0    937
# 2  331815.0   2021-01-01  sexta-feira  10:10:00  CE  222.0  128,5
# 3  331823.0   2021-01-01  sexta-feira  12:30:00  RJ  493.0     18
# 4  331843.0   2021-01-01  sexta-feira  14:40:00  RJ  393.0    252
#
#         municipio                                     causa_acidente  \
# 0        REGISTRO           Reaτπo tardia ou ineficiente do condutor
# 1          MANAUS           Reaτπo tardia ou ineficiente do condutor
# 2         ITAPAJE                            Velocidade Incompatφvel
# 3            MAGE  Ingestπo de ßlcool e/ou substΓncias psicoativa...
# 4  BARRA DO PIRAI                                  Condutor Dormindo
#
#       tipo_acidente  ... feridos_graves ilesos ignorados feridos veiculos  \
# 0        Tombamento  ...              0      0         0       1        1
# ...

# %%
print(len(leitura2021))
# Out:
# 64539

# %% [markdown]
# # **Dados 2022**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-54faa084-2c2a-4c81-a5d7-8422cd8fd21d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-54faa084-2c2a-4c81-a5d7-8422cd8fd21d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
leitura2022 = pd.read_csv(r'Dados_PRF_2022.csv',encoding='cp437', sep = ';' )
leitura2022.head(5)
# Out:
#        id data_inversa dia_semana   horario  uf     br     km  \
# 0  405151   2022-01-01     sßbado  01:35:00  PI  316.0    415
# 1  405158   2022-01-01     sßbado  02:40:00  PR  116.0     33
# 2  405172   2022-01-01     sßbado  05:22:00  MS  163.0    393
# 3  405203   2022-01-01     sßbado  07:00:00  RJ  101.0    457
# 4  405207   2022-01-01     sßbado  09:00:00  MG   40.0  508,3
#
#                municipio                                     causa_acidente  \
# 0            MARCOLANDIA                   Ingestπo de ßlcool pelo condutor
# 1  CAMPINA GRANDE DO SUL                   Ingestπo de ßlcool pelo condutor
# 2   NOVA ALVORADA DO SUL  Condutor deixou de manter distΓncia do veφculo...
# 3         ANGRA DOS REIS           Reaτπo tardia ou ineficiente do condutor
# 4     RIBEIRAO DAS NEVES                  Acumulo de ßgua sobre o pavimento
#
#                tipo_acidente  ... feridos_graves ilesos ignorados feridos  \
# ...

# %%
print(len(leitura2022))
# Out:
# 64547

# %% [markdown]
# # **Dados 2023**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ff08dbec-3707-4989-8f2a-b14b79c42342" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff08dbec-3707-4989-8f2a-b14b79c42342">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
leitura2023 = pd.read_csv(r'Dados_PRF_2023.csv',encoding='cp437', sep = ';' )
leitura2023.head(5)
# Out:
#        id data_inversa dia_semana   horario  uf     br     km  \
# 0  496519   2023-01-01    domingo  02:00:00  ES  101.0    114
# 1  496543   2023-01-01    domingo  03:40:00  SP  116.0  113,1
# 2  496590   2023-01-01    domingo  01:40:00  MT  163.0   1112
# 3  496610   2023-01-01    domingo  10:40:00  PR  376.0  314,8
# 4  496659   2023-01-01    domingo  14:55:00  MG  116.0  569,4
#
#            municipio                            causa_acidente  \
# 0          SOORETAMA            AusΩncia de reaτπo do condutor
# 1            TAUBATE             Entrada inopinada do pedestre
# 2  GUARANTA DO NORTE  Reaτπo tardia ou ineficiente do condutor
# 3         ORTIGUEIRA                   Velocidade Incompatφvel
# 4           MANHUACU         Acumulo de ßgua sobre o pavimento
#
#                tipo_acidente  ... feridos_graves ilesos ignorados feridos  \
# 0  Saφda de leito carroτßvel  ...              0      0         0       1
# ...

# %%
print(len(leitura2023))
# Out:
# 32440

# %% [markdown]
# # **Probabilidade Simples**

# %%
trafficIncidents = len(leitura2019) + len(leitura2020) + len(leitura2021) + len(leitura2022) + len(leitura2023)
print("Total de acidentes nos últimos 5 anos: ", trafficIncidents)
# Out:
# Total de acidentes nos últimos 5 anos:  292658

# %% [markdown]
# **Prababilidade dos aciendentes aconterem em São Paulo:**
#
#
# População projetada em 2023 pelo IBGE: 50.596.822 habitantes

# %%
probSP2019 = len(leitura2019[leitura2019['uf']== 'SP']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado de São Paulo em 2019: '+ str(round(probSP2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de São Paulo em 2019: 6.48%

# %%
probSP2020 = len(leitura2020[leitura2020['uf']== 'SP']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado de São Paulo em 2020: '+ str(round(probSP2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de São Paulo em 2020: 6.36%

# %%
probSP2021 = len(leitura2021[leitura2021['uf']== 'SP']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado de São Paulo em 2021: '+ str(round(probSP2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de São Paulo em 2021: 6.66%

# %%
probSP2022 = len(leitura2022[leitura2022['uf']== 'SP']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado de São Paulo em 2022: '+ str(round(probSP2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de São Paulo em 2022: 6.79%

# %%
probSP2023 = len(leitura2023[leitura2023['uf']== 'SP']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado de São Paulo em 2023 (até agora): '+ str(round(probSP2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de São Paulo em 2023 (até agora): 7.04%

# %% [markdown]
# **Probablidade dos acidentes acontecerem em Minas Gerais:**
#
# População projetada em 2023 pelo IBGE : 20.538.718 habitantes

# %%
probMG2019 = len(leitura2019[leitura2019['uf']== 'MG']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado de Minas Gerais em 2019: '+ str(round(probMG2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Minas Gerais em 2019: 12.93%

# %%
probMG2020 = len(leitura2020[leitura2020['uf']== 'MG']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado de Minas Gerais em 2020: '+ str(round(probMG2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Minas Gerais em 2020: 13.17%

# %%
probMG2021 = len(leitura2021[leitura2021['uf']== 'MG']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado de Minas Gerais em 2021: '+ str(round(probMG2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Minas Gerais em 2021: 12.9%

# %%
probMG2022 = len(leitura2022[leitura2022['uf']== 'MG']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado de Minas Gerais em 2022: '+ str(round(probMG2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Minas Gerais em 2022: 12.84%

# %%
probMG2023 = len(leitura2023[leitura2023['uf']== 'MG']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado de Minas Gerais em 2013 (até agora): '+ str(round(probMG2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Minas Gerais em 2013 (até agora): 13.05%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no Pernambuco:**
#
# População projetada em 2023 pelo IBGE: 9.945.508 habitantes

# %%
probPE2019 = len(leitura2019[leitura2019['uf']== 'PE']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado de Pernambuco em 2019: '+ str(round(probPE2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Pernambuco em 2019: 4.05%

# %%
probPE2020 = len(leitura2020[leitura2020['uf']== 'PE']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado de Pernambuco em 2020: '+ str(round(probPE2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Pernambuco em 2020: 4.03%

# %%
probPE2021 = len(leitura2021[leitura2021['uf']== 'PE']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado de Pernambuco em 2021: '+ str(round(probPE2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Pernambuco em 2021: 3.96%

# %%
probPE2022 = len(leitura2022[leitura2022['uf']== 'PE']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado de Pernambuco em 2022: '+ str(round(probPE2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Pernambuco em 2022: 4.25%

# %%
probPE2023 = len(leitura2023[leitura2023['uf']== 'PE']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado de Pernambuco em 2023: '+ str(round(probPE2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Pernambuco em 2023: 4.44%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem em Pará:**
#
# População projetada em 2023 pelo IBGE: 8.442.962 habitantes

# %%
probPA2019 = len(leitura2019[leitura2019['uf']== 'PA']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado de Pará em 2019: '+ str(round(probPA2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Pará em 2019: 1.22%

# %%
probPA2020 = len(leitura2020[leitura2020['uf']== 'PA']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado de Pará em 2020: '+ str(round(probPA2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Pará em 2020: 1.51%

# %%
probPA2021 = len(leitura2021[leitura2021['uf']== 'PA']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado de Pará em 2021: '+ str(round(probPA2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Pará em 2021: 1.31%

# %%
probPA2022 = len(leitura2022[leitura2022['uf']== 'PA']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado de Pará em 2022: '+ str(round(probPA2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Pará em 2022: 1.29%

# %%
probPA2023 = len(leitura2023[leitura2023['uf']== 'PA']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado de Pará em 2023: '+ str(round(probPA2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Pará em 2023: 1.29%

# %% [markdown]
# **Probabilidade dos acidentes aconteceram em Santa Catarina:**
#
# População projetada em 2023: 9.015.090

# %%
probSC2019 = len(leitura2019[leitura2019['uf']== 'SC']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado de Santa Catarina em 2019: '+ str(round(probSC2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Santa Catarina em 2019: 12.48%

# %%
probSC2020 = len(leitura2020[leitura2020['uf']== 'SC']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado de Santa Catarina em 2020: '+ str(round(probSC2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Santa Catarina em 2020: 11.36%

# %%
probSC2021= len(leitura2021[leitura2021['uf']== 'SC']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado de Santa Catarina em 2021: '+ str(round(probSC2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Santa Catarina em 2021: 12.23%

# %%
probSC2022 = len(leitura2022[leitura2022['uf']== 'SC']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado de Santa Catarina em 2022: '+ str(round(probSC2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Santa Catarina em 2022: 11.76%

# %%
probSC2023 = len(leitura2023[leitura2023['uf']== 'SC']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado de Santa Catarina em 2023: '+ str(round(probSC2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Santa Catarina em 2023: 11.83%

# %%
totalSC = probSC2019 + probSC2020 + probSC2021 + probSC2022 + probSC2023 / trafficIncidents
print(str(round(totalSC * 100,2)) + '%')
# Out:
# 47.82%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no Rio de Janeiro:**
#
# População projetada em 2023 pelo IBGE :  16.054.524 habitantes

# %%
probRJ2019 = len(leitura2019[leitura2019['uf']== 'RJ']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado de Rio de Janeiro em 2019: '+ str(round(probRJ2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Rio de Janeiro em 2019: 6.83%

# %%
probRJ2020= len(leitura2020[leitura2020['uf']== 'RJ']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado de Rio de Janeiro em 2020: '+ str(round(probRJ2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Rio de Janeiro em 2020: 6.67%

# %%
probRJ2021 = len(leitura2021[leitura2021['uf']== 'RJ']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado de Rio de Janeiro em 2021: '+ str(round(probRJ2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Rio de Janeiro em 2021: 7.07%

# %%
probRJ2022 = len(leitura2022[leitura2022['uf']== 'RJ']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado de Rio de Janeiro em 2022: '+ str(round(probRJ2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Rio de Janeiro em 2022: 7.29%

# %%
probRJ2023 = len(leitura2023[leitura2023['uf']== 'RJ']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado de Rio de Janeiro em 2019: '+ str(round(probRJ2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Rio de Janeiro em 2019: 8.02%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no Amazonas:**
#
# População projetada em 2023 pelo IBGE :  4.207.715 habitantes

# %%
probAM2019 = len(leitura2019[leitura2019['uf']== 'AM']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado do Amazonas em 2019: '+ str(round(probAM2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Amazonas em 2019: 0.15%

# %%
probAM2020 = len(leitura2020[leitura2020['uf']== 'AM']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado do Amazonas em 2020: '+ str(round(probAM2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Amazonas em 2020: 0.22%

# %%
probAM2021 = len(leitura2021[leitura2021['uf']== 'AM']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado do Amazonas em 2021: '+ str(round(probAM2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Amazonas em 2021: 0.14%

# %%
probAM2022 = len(leitura2022[leitura2022['uf']== 'AM']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado do Amazonas em 2022: '+ str(round(probAM2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Amazonas em 2022: 0.18%

# %%
probAM2023 = len(leitura2023[leitura2023['uf']== 'AM']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado do Amazonas em 2023: '+ str(round(probAM2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Amazonas em 2023: 0.14%

# %% [markdown]
# **Probabilidade dos acidentes aconteceram no Acre:**
#
# População projetada em 2023 pelo IBGE: 894.470 habitantes

# %%
probAC2019 = len(leitura2019[leitura2019['uf']== 'AC']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado do Acre em 2019: '+ str(round(probAC2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Acre em 2019: 0.39%

# %%
probAC2020 = len(leitura2020[leitura2020['uf']== 'AC']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado do Acre em 2020: '+ str(round(probAC2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Acre em 2020: 0.47%

# %%
probAC2021 = len(leitura2021[leitura2021['uf']== 'AC']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado do Acre em 2021: '+ str(round(probAC2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Acre em 2021: 0.4%

# %%
probAC2022 = len(leitura2022[leitura2022['uf']== 'AC']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado do Acre em 2022: '+ str(round(probAC2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Acre em 2022: 0.35%

# %%
probAC2023 = len(leitura2023[leitura2023['uf']== 'AC']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado do Acre em 2023: '+ str(round(probAC2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Acre em 2023: 0.3%

# %% [markdown]
# **A probabilidade dos acidentes ocorrerem no estado do Amapá:**
#
# População projetada em 2023 pelo IBGE: 733.508 habitantes

# %%
probAP2019 = len(leitura2019[leitura2019['uf']== 'AP']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado do Amapá em 2019: '+ str(round(probAP2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Amapá em 2019: 0.19%

# %%
probAP2020 = len(leitura2020[leitura2020['uf']== 'AP']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado do Amapá em 2020: '+ str(round(probAP2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Amapá em 2020: 0.24%

# %%
probAP2021 = len(leitura2021[leitura2021['uf']== 'AP']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado do Amapá em 2021: '+ str(round(probAP2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Amapá em 2021: 0.26%

# %%
probAP2022 = len(leitura2022[leitura2022['uf']== 'AP']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado do Amapá em 2022: '+ str(round(probAP2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Amapá em 2022: 0.28%

# %%
probAP2023 = len(leitura2023[leitura2023['uf']== 'AP']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado do Amapá em 2023: '+ str(round(probAP2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Amapá em 2023: 0.21%

# %% [markdown]
# **A probabilidade dos acidentes ocorrerem no estado do RO:**
#
# População projetada em 2023 pelo IBGE: 2.120.212 habitantes

# %%
probRO2019 = len(leitura2019[leitura2019['uf']== 'RO']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado do Rondôndia em 2019: '+ str(round(probRO2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Rondôndia em 2019: 2.27%

# %%
probRO2020 = len(leitura2020[leitura2020['uf']== 'RO']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado do Rondôndia em 2020: '+ str(round(probRO2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Rondôndia em 2020: 2.34%

# %%
probRO2021= len(leitura2021[leitura2021['uf']== 'RO']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado do Rondôndia em 2021: '+ str(round(probRO2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Rondôndia em 2021: 2.2%

# %%
probRO2022 = len(leitura2022[leitura2022['uf']== 'RO']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado do Rondôndia em 2022: '+ str(round(probRO2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Rondôndia em 2022: 2.13%

# %%
probRO2023 = len(leitura2023[leitura2023['uf']== 'RO']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado do Rondôndia em 2023: '+ str(round(probRO2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Rondôndia em 2023: 2.15%

# %% [markdown]
# **A probabilidade dos acidentes ocorrerem no estado do RR:**
#
# População projetada em 2023 pelo IBGE: 984.511 habitantes

# %%
probRR2019 = len(leitura2019[leitura2019['uf']== 'RR']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado do Roraima em 2019: '+ str(round(probRR2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Roraima em 2019: 0.35%

# %%
probRR2020 = len(leitura2020[leitura2020['uf']== 'RR']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado do Roraima em 2020: '+ str(round(probRR2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Roraima em 2020: 0.39%

# %%
probRR2021= len(leitura2021[leitura2021['uf']== 'RR']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado do Roraima em 2021: '+ str(round(probRR2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Roraima em 2021: 0.42%

# %%
probRR2022 = len(leitura2022[leitura2022['uf']== 'RR']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado do Roraima em 2022: '+ str(round(probRR2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Roraima em 2022: 0.35%

# %%
probRR2023 = len(leitura2023[leitura2023['uf']== 'RR']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado do Roraima em 2023: '+ str(round(probRR2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Roraima em 2023: 0.24%

# %% [markdown]
# **A probabilidade dos acidentes ocorrerem no estado do TO:**
#
# População projetada em 2023 pelo IBGE: 1.935.575 habitantes

# %%
probTO2019 = len(leitura2019[leitura2019['uf']== 'TO']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado do Tocantins em 2019: '+ str(round(probTO2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Tocantins em 2019: 0.77%

# %%
probTO2020 = len(leitura2020[leitura2020['uf']== 'TO']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado do Tocantins em 2020: '+ str(round(probTO2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Tocantins em 2020: 0.94%

# %%
probTO2021 = len(leitura2021[leitura2021['uf']== 'TO']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado do Tocantins em 2021: '+ str(round(probTO2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Tocantins em 2021: 0.78%

# %%
probTO2022 = len(leitura2022[leitura2022['uf']== 'TO']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado do Tocantins em 2022: '+ str(round(probTO2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Tocantins em 2022: 0.88%

# %%
probTO2023= len(leitura2023[leitura2023['uf']== 'TO']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado do Tocantins em 2023: '+ str(round(probTO2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Tocantins em 2023: 0.92%

# %% [markdown]
# **A probabilidade dos acidentes ocorrerem no estado do MA:**
#
# População projetada em 2023 pelo IBGE:  6.775.152 habitantes

# %%
probMA2019 = len(leitura2019[leitura2019['uf']== 'MA']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado do Maranhão em 2019: '+ str(round(probMA2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Maranhão em 2019: 1.6%

# %%
probMA2020 = len(leitura2020[leitura2020['uf']== 'MA']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado do Maranhão em 2020: '+ str(round(probMA2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Maranhão em 2020: 1.82%

# %%
probMA2021 = len(leitura2021[leitura2021['uf']== 'MA']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado do Maranhão em 2021: '+ str(round(probMA2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Maranhão em 2021: 1.75%

# %%
probMA2022 = len(leitura2022[leitura2022['uf']== 'MA']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado do Maranhão em 2022: '+ str(round(probMA2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Maranhão em 2022: 1.68%

# %%
probMA2023 = len(leitura2023[leitura2023['uf']== 'MA']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado do Maranhão em 2023: '+ str(round(probMA2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Maranhão em 2023: 1.63%

# %% [markdown]
# **A probabilidade dos acidentes ocorrerem no estado do PI:**
#
# População projetada em 2023 pelo IBGE: 2.948.119 habitantes

# %%
probPI2019 = len(leitura2019[leitura2019['uf']== 'PI']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado do Piauí em 2019: '+ str(round(probPI2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Piauí em 2019: 1.99%

# %%
probPI2020 = len(leitura2020[leitura2020['uf']== 'PI']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado do Piauí em 2020: '+ str(round(probPI2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Piauí em 2020: 1.9%

# %%
probPI2021 = len(leitura2021[leitura2021['uf']== 'PI']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado do Piauí em 2021: '+ str(round(probPI2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Piauí em 2021: 1.76%

# %%
probPI2022 = len(leitura2022[leitura2022['uf']== 'PI']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado do Piauí em 2022: '+ str(round(probPI2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Piauí em 2022: 1.73%

# %%
probPI2023 = len(leitura2023[leitura2023['uf']== 'PI']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado do Piauí em 2023: '+ str(round(probPI2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Piauí em 2023: 1.73%

# %% [markdown]
# **A probabilidade dos acidentes ocorrerem no estado do CE:**
#
# Populaçã proujetada em 2023 pelo IBGE: 8.791.688 habitantes

# %%
probCE2019 = len(leitura2019[leitura2019['uf']== 'CE']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado do Ceará em 2019: '+ str(round(probCE2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Ceará em 2019: 2.51%

# %%
probCE2020= len(leitura2020[leitura2020['uf']== 'CE']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado do Ceará em 2020: '+ str(round(probCE2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Ceará em 2020: 2.47%

# %%
probCE2021 = len(leitura2021[leitura2021['uf']== 'CE']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado do Ceará em 2021: '+ str(round(probCE2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Ceará em 2021: 2.39%

# %%
probCE2022 = len(leitura2022[leitura2022['uf']== 'CE']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado do Ceará em 2022: '+ str(round(probCE2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Ceará em 2022: 2.13%

# %%
probCE2023 = len(leitura2023[leitura2023['uf']== 'CE']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado do Ceará em 2023: '+ str(round(probCE2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Ceará em 2023: 1.98%

# %% [markdown]
# **A probabilidade dos acidentes ocorrerem no estado do RN:**
#
# População projetada em 2023 pelo IBGE: 3.815.691 habitantes

# %%
probRN2019 = len(leitura2019[leitura2019['uf']== 'RN']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Norte em 2019: '+ str(round(probRN2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Norte em 2019: 2.13%

# %%
probRN2020 = len(leitura2020[leitura2020['uf']== 'RN']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Norte em 2020: '+ str(round(probRN2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Norte em 2020: 2.11%

# %%
probRN2021 = len(leitura2021[leitura2021['uf']== 'RN']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Norte em 2021: '+ str(round(probRN2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Norte em 2021: 2.08%

# %%
probRN2022 = len(leitura2022[leitura2022['uf']== 'RN']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Norte em 2022: '+ str(round(probRN2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Norte em 2022: 1.99%

# %%
probRN2023 = len(leitura2023[leitura2023['uf']== 'RN']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Norte em 2023: '+ str(round(probRN2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Norte em 2023: 2.02%

# %% [markdown]
# **A probabilidade dos acidentes ocorrerem no estado do PB:**
#
# População projetada em 2023 pelo IBGE: 4.048.336 habitantes

# %%
probPB2019 = len(leitura2019[leitura2019['uf']== 'PB']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2019: '+ str(round(probPB2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2019: 2.32%

# %%
probPB2020 = len(leitura2020[leitura2020['uf']== 'PB']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2020: '+ str(round(probPB2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2020: 2.2%

# %%
probPB2021 = len(leitura2021[leitura2021['uf']== 'PB']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2021: '+ str(round(probPB2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2021: 2.23%

# %%
probPB2022 = len(leitura2022[leitura2022['uf']== 'PB']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2022: '+ str(round(probPB2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2022: 2.28%

# %%
probPB2023 = len(leitura2023[leitura2023['uf']== 'PB']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2023: '+ str(round(probPB2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2023: 2.31%

# %% [markdown]
# **A probabilidade dos acidentes ocorrerem no estado do AL:**
#
# População projetada em 2023 pelo IBGE: 3.230.875 habitantes

# %%
probAL2019 = len(leitura2019[leitura2019['uf']== 'AL']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2019: '+ str(round(probAL2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2019: 0.93%

# %%
probAL2020 = len(leitura2020[leitura2020['uf']== 'AL']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2020: '+ str(round(probAL2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2020: 0.99%

# %%
probAL2021 = len(leitura2021[leitura2021['uf']== 'AL']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2021: '+ str(round(probAL2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2021: 0.9%

# %%
probAL2022 = len(leitura2022[leitura2022['uf']== 'AL']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2022: '+ str(round(probAL2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2022: 0.92%

# %%
probAL2023 = len(leitura2023[leitura2023['uf']== 'AL']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2023: '+ str(round(probAL2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Paraíba em 2023: 0.94%

# %% [markdown]
# **A probabilidade dos acidentes ocorrerem no estado do SE:**
#
# População projetada em 2023 pelo IBGE: 2.598.353 habitantes

# %%
probSE2019 = len(leitura2019[leitura2019['uf']== 'SE']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado do Sergipe em 2019: '+ str(round(probSE2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Sergipe em 2019: 0.91%

# %%
probSE2020 = len(leitura2020[leitura2020['uf']== 'SE']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado do Sergipe em 2020: '+ str(round(probSE2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Sergipe em 2020: 0.9%

# %%
probSE2021 = len(leitura2021[leitura2021['uf']== 'SE']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado do Sergipe em 2021: '+ str(round(probSE2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Sergipe em 2021: 0.79%

# %%
probSE2022 = len(leitura2022[leitura2022['uf']== 'SE']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado do Sergipe em 2022: '+ str(round(probSE2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Sergipe em 2022: 0.79%

# %%
probSE2023 = len(leitura2023[leitura2023['uf']== 'SE']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado do Sergipe em 2023: '+ str(round(probSE2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Sergipe em 2023: 0.8%

# %% [markdown]
# **A probabilidade dos acidentes ocorrerem no estado do BA:**
#
# População projetada em 2023 pelo IBGE: 13.825.958 habitantes

# %%
probBA2019 = len(leitura2019[leitura2019['uf']== 'BA']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado da Bahia em 2019: '+ str(round(probBA2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado da Bahia em 2019: 5.16%

# %%
probBA2020 = len(leitura2020[leitura2020['uf']== 'BA']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado da Bahia em 2020: '+ str(round(probBA2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado da Bahia em 2020: 5.44%

# %%
probBA2021 = len(leitura2021[leitura2021['uf']== 'BA']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado da Bahia em 2021: '+ str(round(probBA2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado da Bahia em 2021: 5.13%

# %%
probBA2022 = len(leitura2022[leitura2022['uf']== 'BA']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado da Bahia em 2022: '+ str(round(probBA2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado da Bahia em 2022: 5.33%

# %%
probBA2023 = len(leitura2023[leitura2023['uf']== 'BA']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado da Bahia em 2023: '+ str(round(probBA2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado da Bahia em 2023: 5.36%

# %% [markdown]
# **A probabilidade dos acidentes ocorrerem no estado do GO:**
#
# População projetada em 2023 pelo IBGE: 9.189.311 habitantes

# %%
probGO2019 = len(leitura2019[leitura2019['uf']== 'GO']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado de Góias em 2019: '+ str(round(probGO2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Góias em 2019: 4.97%

# %%
probGO2020 = len(leitura2020[leitura2020['uf']== 'GO']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado de Góias em 2020: '+ str(round(probGO2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Góias em 2020: 5.08%

# %%
probGO2021 = len(leitura2021[leitura2021['uf']== 'GO']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado de Góias em 2021: '+ str(round(probGO2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Góias em 2021: 4.94%

# %%
probGO2022 = len(leitura2022[leitura2022['uf']== 'GO']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado de Góias em 2022: '+ str(round(probGO2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Góias em 2022: 4.82%

# %%
probGO2023 = len(leitura2023[leitura2023['uf']== 'GO']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado de Góias em 2023: '+ str(round(probGO2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado de Góias em 2023: 4.57%

# %% [markdown]
# **A probabilidade dos acidentes ocorrerem no estado do MT:**
#
# População projetada em 2023 pelo IBGE: 3.658.813 habitantes

# %%
probMT2019 = len(leitura2019[leitura2019['uf']== 'MT']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado do Mato Grossp em 2019: '+ str(round(probMT2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Mato Grossp em 2019: 3.17%

# %%
probMT2020 = len(leitura2020[leitura2020['uf']== 'MT']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado do Mato Grossp em 2020: '+ str(round(probMT2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Mato Grossp em 2020: 3.45%

# %%
probMT2021 = len(leitura2021[leitura2021['uf']== 'MT']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado do Mato Grossp em 2021: '+ str(round(probMT2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Mato Grossp em 2021: 3.31%

# %%
probMT2022 = len(leitura2022[leitura2022['uf']== 'MT']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado do Mato Grossp em 2022: '+ str(round(probMT2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Mato Grossp em 2022: 3.37%

# %%
probMT2023 = len(leitura2023[leitura2023['uf']== 'MT']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado do Mato Grossp em 2023: '+ str(round(probMT2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Mato Grossp em 2023: 3.31%

# %% [markdown]
# **A probabilidade dos acidentes ocorrerem no estado do MS:**
#
# População rojetada para 2023 pelo IBGE: 3.440.594 habitantes

# %%
probMS2019 = len(leitura2019[leitura2019['uf']== 'MS']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado do Mato Grosso do Sul em 2019: '+ str(round(probMS2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Mato Grosso do Sul em 2019: 2.13%

# %%
probMS2020 = len(leitura2020[leitura2020['uf']== 'MS']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado do Mato Grosso do Sul em 2020: '+ str(round(probMS2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Mato Grosso do Sul em 2020: 2.43%

# %%
probMS2021 = len(leitura2021[leitura2021['uf']== 'MS']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado do Mato Grosso do Sul em 2021: '+ str(round(probMS2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Mato Grosso do Sul em 2021: 2.54%

# %%
probMS2022 = len(leitura2022[leitura2022['uf']== 'MS']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado do Mato Grosso do Sul em 2022: '+ str(round(probMS2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Mato Grosso do Sul em 2022: 2.54%

# %%
probMS2023 = len(leitura2023[leitura2023['uf']== 'MS']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado do Mato Grosso do Sul em 2023: '+ str(round(probMS2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Mato Grosso do Sul em 2023: 2.5%

# %% [markdown]
# **A probabilidade dos acidentes ocorrerem no estado do DF:**
#
# População projetada em 2023 pelo IBGE: 3.094.325 habitantes

# %%
probDF2019 = len(leitura2019[leitura2019['uf']== 'DF']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado do Destrito Federal em 2019: '+ str(round(probDF2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Destrito Federal em 2019: 1.61%

# %%
probDF2020 = len(leitura2020[leitura2020['uf']== 'DF']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado do Destrito Federal em 2020: '+ str(round(probDF2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Destrito Federal em 2020: 1.64%

# %%
probDF2021 = len(leitura2021[leitura2021['uf']== 'DF']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado do Destrito Federal em 2021: '+ str(round(probDF2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Destrito Federal em 2021: 1.52%

# %%
probDF2022 = len(leitura2022[leitura2022['uf']== 'DF']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado do Destrito Federal em 2022: '+ str(round(probDF2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Destrito Federal em 2022: 1.43%

# %%
probDF2023 = len(leitura2023[leitura2023['uf']== 'DF']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado do Destrito Federal em 2023: '+ str(round(probDF2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Destrito Federal em 2023: 1.43%

# %% [markdown]
# **A probabilidade dos acidentes ocorrerem no estado do ES:**
#
# População projetada em 2023 pelo IBGE: 4.927.795 habitantes

# %%
probES2019 = len(leitura2019[leitura2019['uf']== 'ES']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado do Espirito Santo em 2019: '+ str(round(probES2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Espirito Santo em 2019: 4.21%

# %%
probES2020 = len(leitura2020[leitura2020['uf']== 'ES']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado do Espirito Santo em 2020: '+ str(round(probES2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Espirito Santo em 2020: 3.99%

# %%
probES2021= len(leitura2021[leitura2021['uf']== 'ES']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado do Espirito Santo em 2021: '+ str(round(probES2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Espirito Santo em 2021: 3.91%

# %%
probES2022= len(leitura2022[leitura2022['uf']== 'ES']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado do Espirito Santo em 2022: '+ str(round(probES2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Espirito Santo em 2022: 3.53%

# %%
probES2023 = len(leitura2023[leitura2023['uf']== 'ES']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado do Espirito Santo em 2023: '+ str(round(probES2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Espirito Santo em 2023: 3.36%

# %% [markdown]
# **A probabilidade dos acidentes ocorrerem no estado do PR:**
#
# População projetada em 2023 pelo IBGE: 	12.342.362 habitantes

# %%
probPR2019 = len(leitura2019[leitura2019['uf']== 'PR']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado do Paraná em 2019: '+ str(round(probPR2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Paraná em 2019: 11.43%

# %%
probPR2020 = len(leitura2020[leitura2020['uf']== 'PR']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado do Paraná em 2020: '+ str(round(probPR2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Paraná em 2020: 11.32%

# %%
probPR2021 = len(leitura2021[leitura2021['uf']== 'PR']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado do Paraná em 2021: '+ str(round(probPR2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Paraná em 2021: 11.38%

# %%
probPR2022 = len(leitura2022[leitura2022['uf']== 'PR']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado do Paraná em 2022: '+ str(round(probPR2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Paraná em 2022: 11.43%

# %%
probPR2023= len(leitura2023[leitura2023['uf']== 'PR']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado do Paraná em 2023: '+ str(round(probPR2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Paraná em 2023: 10.61%

# %% [markdown]
# **A probabilidade dos acidentes ocorrerem no estado do RS:**
#
# População projetada em 2023 pelo IBGE: 10.945.217 habitantes

# %%
probRS2019 = len(leitura2019[leitura2019['uf']== 'RS']) / len(leitura2019)
print('A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Sul em 2019: '+ str(round(probRS2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Sul em 2019: 6.81%

# %%
probRS2020 = len(leitura2020[leitura2020['uf']== 'RS']) / len(leitura2020)
print('A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Sul em 2020: '+ str(round(probRS2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Sul em 2020: 6.57%

# %%
probRS2021 = len(leitura2021[leitura2021['uf']== 'RS']) / len(leitura2021)
print('A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Sul em 2021: '+ str(round(probRS2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Sul em 2021: 7.03%

# %%
probRS2022 = len(leitura2022[leitura2022['uf']== 'RS']) / len(leitura2022)
print('A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Sul em 2022: '+ str(round(probRS2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Sul em 2022: 7.64%

# %%
probRS2023 = len(leitura2023[leitura2023['uf']== 'RS']) / len(leitura2023)
print('A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Sul em 2023: '+ str(round(probRS2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes de carro ocorrem no estado do Rio Grande do Sul em 2023: 7.82%

# %% [markdown]
# # **Probabilidade da Intersecção**

# %% [markdown]
# **Probabilidade dos acidentes acontecerem em SP durante chuvas:**

# %%
SPChuva2019 = len(leitura2019[leitura2019['uf'] == 'SP'])  & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
print(SPChuva2019)
probSPChuva2019  = SPChuva2019 /len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado de São Paulo durante chuvas em 2019 é:  '+ str(round(probSPChuva2019 *100, 2)) + '%')
# Out:
# 4115
# A probabilidade dos acidentes acontecerem no estado de São Paulo durante chuvas em 2019 é:  6.09%

# %%
SPChuva2020= len(leitura2020[leitura2020['uf'] == 'SP'])  & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probSPChuva2020  = SPChuva2020 /len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado de São Paulo durante chuvas em 2020 é:  '+ str(round(probSPChuva2020 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de São Paulo durante chuvas em 2020 é:  4.24%

# %%
SPChuva2021= len(leitura2021[leitura2021['uf'] == 'SP'])  & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probSPChuva2021  = SPChuva2021 /len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado de São Paulo durante chuvas em 2021 é:  '+ str(round(probSPChuva2021 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de São Paulo durante chuvas em 2021 é:  6.35%

# %%
SPChuva2022 = len(leitura2022[leitura2022['uf'] == 'SP'])  & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probSPChuva2022  = SPChuva2022 /len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado de São Paulo durante chuvasem 2022 é:  '+ str(round(probSPChuva2022 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de São Paulo durante chuvasem 2022 é:  6.74%

# %%
SPChuva2023 = len(leitura2023[leitura2023['uf'] == 'SP'])  & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probSPChuva2023  = SPChuva2023 /len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado de São Paulo durante chuvas em 2023 é:  '+ str(round(probSPChuva2023 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de São Paulo durante chuvas em 2023 é:  6.82%

# %%
totalSPChuvas = ((SPChuva2019 + SPChuva2020 + SPChuva2021 + SPChuva2022 + SPChuva2023) / trafficIncidents)
print(str(round(totalSPChuvas * 100,2)) + '%')
# Out:
# 5.97%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem em MG durante chuvas:**

# %%
MGChuva2019 = len(leitura2019[leitura2019['uf'] == 'MG'])  & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probMGChuva2019  = MGChuva2019 / len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado de Minas Gerais durante chuvas em 2019 é:  '+ str(round(probMGChuva2019 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Minas Gerais durante chuvas em 2019 é:  0.05%

# %%
MGChuva2020 = len(leitura2020[leitura2020['uf'] == 'MG'])  & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probMGChuva2020 = MGChuva2020 /len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado de Minas Gerais durante chuvas em 2020 é:  '+ str(round(probMGChuva2020 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Minas Gerais durante chuvas em 2020 é:  0.23%

# %%
MGChuva2021 = len(leitura2021[leitura2021['uf'] == 'MG'])  & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probMGChuva2021 = MGChuva2021 /len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado de Minas Gerais durante chuvas em 2021 é:  '+ str(round(probMGChuva2021 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Minas Gerais durante chuvas em 2021 é:  0.01%

# %%
MGChuva2022 = len(leitura2022[leitura2022['uf'] == 'MG'])  & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probMGChuva2022 = MGChuva2022 /len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado de Minas Gerais durante chuvas em 2022 é:  '+ str(round(probMGChuva2022 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Minas Gerais durante chuvas em 2022 é:  0.1%

# %%
MGChuva2023 = len(leitura2023[leitura2023['uf'] == 'MG'])  & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probMGChuva2023 = MGChuva2023 /len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado de Minas Gerais durante chuvas em 2023 é:  '+ str(round(probMGChuva2023 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Minas Gerais durante chuvas em 2023 é:  0.4%

# %%
totalMGChuvas = ((MGChuva2019 + MGChuva2020 + MGChuva2021 + MGChuva2022 + MGChuva2023) / trafficIncidents)
print(str(round(totalMGChuvas * 100,2)) + '%')
# Out:
# 0.13%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem em PE durante chuvas:**

# %%
PEChuva2019= len(leitura2019[leitura2019['uf'] == 'PE'])  & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probPEChuva2019 = MGChuva2019 /len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado de Pernambuco durante chuvas em 2019 é:  '+ str(round(probPEChuva2019 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Pernambuco durante chuvas em 2019 é:  0.05%

# %%
PEChuva2020 = len(leitura2020[leitura2020['uf'] == 'PE'])  & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probPEChuva2020 = MGChuva2020 /len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado de Pernambuco durante chuvas em 2020 é:  '+ str(round(probPEChuva2020 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Pernambuco durante chuvas em 2020 é:  0.23%

# %%
PEChuva2021 = len(leitura2021[leitura2021['uf'] == 'PE'])  & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probPEChuva2021 = MGChuva2021 /len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado de Pernambuco durante chuvas em 2021 é:  '+ str(round(probPEChuva2021 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Pernambuco durante chuvas em 2021 é:  0.01%

# %%
PEChuva2022 = len(leitura2022[leitura2022['uf'] == 'PE'])  & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probPEChuva2022 = MGChuva2022 /len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado de Pernambuco durante chuvas em 2022 é:  '+ str(round(probPEChuva2022 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Pernambuco durante chuvas em 2022 é:  0.1%

# %%
PEChuva2023 = len(leitura2023[leitura2023['uf'] == 'PE'])  & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probPEChuva2023 = MGChuva2023 /len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado de Pernambuco durante chuvas em 2023 é:  '+ str(round(probPEChuva2023 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Pernambuco durante chuvas em 2023 é:  0.4%

# %%
totalPEChuvas = ((PEChuva2019 + PEChuva2020 + PEChuva2021 + PEChuva2022 + PEChuva2023) / trafficIncidents)
print(str(round(totalPEChuvas * 100,2)) + '%')
# Out:
# 3.73%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem em PA durante chuvas:**

# %%
PAChuva2019= len(leitura2019[leitura2019['uf'] == 'PA'])  & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probPAChuva2019 = PAChuva2019 /len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado do Pará durante chuvas em 2019 é:  '+ str(round(probPAChuva2019 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Pará durante chuvas em 2019 é:  0.08%

# %%
PAChuva2020 = len(leitura2020[leitura2020['uf'] == 'PA'])  & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probPAChuva2020 = PAChuva2020 /len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado do Pará durante chuvas em 2020 é:  '+ str(round(probPAChuva2020 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Pará durante chuvas em 2020 é:  1.01%

# %%
PAChuva2021 = len(leitura2021[leitura2021['uf'] == 'PA'])  & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probPAChuva2021 = PAChuva2021 /len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado do Pará durante chuvas em 2021 é:  '+ str(round(probPAChuva2021 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Pará durante chuvas em 2021 é:  0.8%

# %%
PAChuva2022 = len(leitura2022[leitura2022['uf'] == 'PA'])  & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probPAChuva2022 = PAChuva2022 /len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado do Pará durante chuvas em 2022 é:  '+ str(round(probPAChuva2022 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Pará durante chuvas em 2022 é:  1.22%

# %%
PAChuva2023 = len(leitura2023[leitura2023['uf'] == 'PA'])  & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probPAChuva2023 = PAChuva2023 /len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado do Pará durante chuvas em 2023 é:  '+ str(round(probPAChuva2023 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Pará durante chuvas em 2023 é:  1.29%

# %%
totalPAChuvas = ((PAChuva2019 + PAChuva2020 + PAChuva2021 + PAChuva2022 + PAChuva2023) / trafficIncidents)
print(str(round(totalPAChuvas * 100,2)) + '%')
# Out:
# 0.83%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem em SC durante chuvas:**

# %%
SCChuva2019= len(leitura2019[leitura2019['uf'] == 'SC'])  & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probSCChuva2019 = SCChuva2019 /len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado de Santa Catarina durante chuvas em 2019 é:  '+ str(round(probSCChuva2019 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Santa Catarina durante chuvas em 2019 é:  0.07%

# %%
SCChuva2020 = len(leitura2020[leitura2020['uf'] == 'SC'])  & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probSCChuva2020 = SCChuva2020 /len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado de Santa Catarina durante chuvas em 2020 é:  '+ str(round(probSCChuva2020 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Santa Catarina durante chuvas em 2020 é:  9.7%

# %%
SCChuva2021 = len(leitura2021[leitura2021['uf'] == 'SC'])  & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probSCChuva2021 = SCChuva2021 /len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado de Santa Catarina durante chuvas em 2021 é:  '+ str(round(probSCChuva2021 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Santa Catarina durante chuvas em 2021 é:  10.34%

# %%
SCChuva2022 = len(leitura2022[leitura2022['uf'] == 'SC'])  & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probSCChuva2022 = SCChuva2022/len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado de Santa Catarina durante chuvas em 2022 é:  '+ str(round(probSCChuva2022 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Santa Catarina durante chuvas em 2022 é:  10.12%

# %%
SCChuva2023 = len(leitura2023[leitura2023['uf'] == 'SC'])  & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probSCChuva2023 = SCChuva2023 /len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado de Santa Catarina durante chuvas em 2023 é:  '+ str(round(probSCChuva2023 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Santa Catarina durante chuvas em 2023 é:  9.98%

# %%
totalSCChuvas = ((SCChuva2019 + SCChuva2020 + SCChuva2021 + SCChuva2022 + SCChuva2023) / trafficIncidents)
print(str(round(totalSCChuvas * 100,2)) + '%')
# Out:
# 7.74%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no RJ durante chuvas:**

# %%
RJChuva2019= len(leitura2019[leitura2019['uf'] == 'RJ'])  & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probRJChuva2019 = RJChuva2019 /len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado do Rio de Janeiro durante chuvas em 2019 é:  '+ str(round(probRJChuva2019 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Rio de Janeiro durante chuvas em 2019 é:  6.06%

# %%
RJChuva2020 = len(leitura2020[leitura2020['uf'] == 'RJ'])  & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probRJChuva2020 = RJChuva2020 /len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado do Rio de Janeiro durante chuvas em 2020 é:  '+ str(round(probRJChuva2020 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Rio de Janeiro durante chuvas em 2020 é:  6.66%

# %%
RJChuva2021 = len(leitura2021[leitura2021['uf'] == 'RJ'])  & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probRJChuva2021 = RJChuva2021 /len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado do Rio de Janeiro durante chuvas em 2021 é:  '+ str(round(probRJChuva2021 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Rio de Janeiro durante chuvas em 2021 é:  6.38%

# %%
RJChuva2022 = len(leitura2022[leitura2022['uf'] == 'RJ'])  & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probRJChuva2022 = RJChuva2022 /len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado do Rio de Janeiro durante chuvas em 2022 é:  '+ str(round(probRJChuva2022 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Rio de Janeiro durante chuvas em 2022 é:  7.24%

# %%
RJChuva2023 = len(leitura2023[leitura2023['uf'] == 'RJ'])  & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probRJChuva2023 = RJChuva2023 /len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado do Rio de Janeiro durante chuvas em 2023 é:  '+ str(round(probRJChuva2023 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Rio de Janeiro durante chuvas em 2023 é:  6.42%

# %%
totalRJChuvas = ((RJChuva2019 + RJChuva2020 + RJChuva2021 + RJChuva2022 + RJChuva2023 )/ trafficIncidents)
print(str(round(totalRJChuvas * 100,2)) + '%')
# Out:
# 6.56%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no AM durante chuvas:**

# %%
AMChuva2019= len(leitura2019[leitura2019['uf'] == 'AM'])  & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probAMChuva2019 = AMChuva2019 /len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado do Amazonas o durante chuvas em 2019 é:  '+ str(round(probAMChuva2019 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Amazonas o durante chuvas em 2019 é:  0.06%

# %%
AMChuva2020 = len(leitura2020[leitura2020['uf'] == 'AM'])  & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probAMChuva2020 = AMChuva2020 /len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado do Amazonas o durante chuvas em 2020 é:  '+ str(round(probAMChuva2020 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Amazonas o durante chuvas em 2020 é:  0.21%

# %%
AMChuva2021 = len(leitura2021[leitura2021['uf'] == 'AM'])  & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probAMChuva2021 = AMChuva2021 /len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado do Amazonas o durante chuvas em 2021 é:  '+ str(round(probAMChuva2021 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Amazonas o durante chuvas em 2021 é:  0.03%

# %%
AMChuva2022 = len(leitura2022[leitura2022['uf'] == 'AM'])  & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probAMChuva2022 = AMChuva2022 /len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado do Amazonas o durante chuvas em 2022 é:  '+ str(round(probAMChuva2022 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Amazonas o durante chuvas em 2022 é:  0.13%

# %%
AMChuva2023 = len(leitura2023[leitura2023['uf'] == 'AM'])  & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probAMChuva2023 = AMChuva2023 /len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado do Amazonas o durante chuvas em 2023 é:  '+ str(round(probAMChuva2023 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Amazonas o durante chuvas em 2023 é:  0.12%

# %%
totalAMChuvas = ((AMChuva2019 + AMChuva2020 + AMChuva2021 + AMChuva2022 + AMChuva2023) / trafficIncidents)
print(str(round(totalAMChuvas * 100,2)) + '%')
# Out:
# 0.11%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no AC durante chuvas:**

# %%
ACChuva2019 = len(leitura2019[leitura2019['uf'] == 'AC'])  & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probACChuva2019 = ACChuva2019 /len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado do Acre durante chuvas em 2019 é:  '+ str(round(probACChuva2019 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Acre durante chuvas em 2019 é:  0.01%

# %%
ACChuva2020 = len(leitura2020[leitura2020['uf'] == 'AC'])  & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probACChuva2020 = ACChuva2020 /len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado do Acre durante chuvas em 2020 é:  '+ str(round(probACChuva2020 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Acre durante chuvas em 2020 é:  0.02%

# %%
ACChuva2021 = len(leitura2021[leitura2021['uf'] == 'AC'])  & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probACChuva2021 = ACChuva2021 /len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado do Acre durante chuvas em 2021 é:  '+ str(round(probACChuva2021 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Acre durante chuvas em 2021 é:  0.08%

# %%
ACChuva2022 = len(leitura2022[leitura2022['uf'] == 'AC'])  & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probACChuva2022 = ACChuva2022 /len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado do Acre durante chuvas em 2022 é:  '+ str(round(probACChuva2022 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Acre durante chuvas em 2022 é:  0.3%

# %%
ACChuva2023 = len(leitura2023[leitura2023['uf'] == 'AC'])  & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probACChuva2023 = ACChuva2023 /len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado do Acre durante chuvas em 2023 é:  '+ str(round(probACChuva2023 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Acre durante chuvas em 2023 é:  0.1%

# %%
totalACChuvas = ((ACChuva2019 + ACChuva2020 + ACChuva2021 + ACChuva2022 + ACChuva2023) / trafficIncidents)
print(str(round(totalACChuvas * 100,2)) + '%')
# Out:
# 0.1%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no AP durante chuvas:**

# %%
APChuva2019 = len(leitura2019[leitura2019['uf'] == 'AP'])  & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probAPChuva2019 = APChuva2019 /len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado do Amapá durante chuvas em 2019 é:  '+ str(round(probAPChuva2019 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Amapá durante chuvas em 2019 é:  0.0%

# %%
APChuva2020 = len(leitura2020[leitura2020['uf'] == 'AP'])  & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probAPChuva2020 = APChuva2020 /len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado do Amapá durante chuvas em 2020 é:  '+ str(round(probAPChuva2020 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Amapá durante chuvas em 2020 é:  0.24%

# %%
APChuva2021 = len(leitura2021[leitura2021['uf'] == 'AP'])  & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probAPChuva2021 = APChuva2021 /len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado do Amapá durante chuvas em 2021 é:  '+ str(round(probAPChuva2021 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Amapá durante chuvas em 2021 é:  0.05%

# %%
APChuva2022 = len(leitura2022[leitura2022['uf'] == 'AP'])  & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probAPChuva2022 = APChuva2022 /len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado do Amapá durante chuvas em 2022 é:  '+ str(round(probAPChuva2022 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Amapá durante chuvas em 2022 é:  0.22%

# %%
APChuva2023 = len(leitura2023[leitura2023['uf'] == 'AP'])  & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probAPChuva2023 = APChuva2023 /len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado do Amapá durante chuvas em 2023 é:  '+ str(round(probAPChuva2023 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Amapá durante chuvas em 2023 é:  0.01%

# %%
totalAPChuvas = ((APChuva2019 + APChuva2020 + APChuva2021 + APChuva2022 + APChuva2023 )/ trafficIncidents)
print(str(round(totalAPChuvas * 100,2)) + '%')
# Out:
# 0.11%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no RO durante chuvas:**

# %%
ROChuva2019 = len(leitura2019[leitura2019['uf'] == 'RO'])  & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probROChuva2019 = ROChuva2019 /len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado de Rondônia durante chuvas em 2019 é:  '+ str(round(probROChuva2019 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Rondônia durante chuvas em 2019 é:  1.52%

# %%
ROChuva2020 = len(leitura2020[leitura2020['uf'] == 'RO'])  & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probROChuva2020 = ROChuva2020 /len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado de Rondônia durante chuvas em 2020 é:  '+ str(round(probROChuva2020 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Rondônia durante chuvas em 2020 é:  0.22%

# %%
ROChuva2021 = len(leitura2021[leitura2021['uf'] == 'RO'])  & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probROChuva2021 = ROChuva2021 /len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado de Rondônia durante chuvas em 2021 é:  '+ str(round(probROChuva2021 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Rondônia durante chuvas em 2021 é:  0.0%

# %%
ROChuva2022 = len(leitura2022[leitura2022['uf'] == 'RO'])  & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probROChuva2022 = ROChuva2022 /len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado de Rondônia durante chuvas em 2022 é:  '+ str(round(probROChuva2022 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Rondônia durante chuvas em 2022 é:  0.5%

# %%
ROChuva2023 = len(leitura2023[leitura2023['uf'] == 'RO'])  & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probROChuva2023 = ROChuva2023 /len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado de Rondônia durante chuvas em 2023 é:  '+ str(round(probROChuva2023 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Rondônia durante chuvas em 2023 é:  0.49%

# %%
totalROChuvas = ((ROChuva2019 + ROChuva2020 + ROChuva2021 + ROChuva2022 + ROChuva2023) / trafficIncidents)
print(str(round(totalROChuvas * 100,2)) + '%')
# Out:
# 0.56%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no RR durante chuvas:**

# %%
RRChuva2019 = len(leitura2019[leitura2019['uf'] == 'RR'])  & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probRRChuva2019 = RRChuva2019 /len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado de Roraima durante chuvas em 2019 é:  '+ str(round(probRRChuva2019 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Roraima durante chuvas em 2019 é:  0.05%

# %%
RRChuva2020 = len(leitura2020[leitura2020['uf'] == 'RR'])  & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probRRChuva2020 = RRChuva2020 /len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado de Roraima durante chuvas em 2020 é:  '+ str(round(probRRChuva2020 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Roraima durante chuvas em 2020 é:  0.24%

# %%
RRChuva2021 = len(leitura2021[leitura2021['uf'] == 'RR'])  & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probRRChuva2021 = RRChuva2021 /len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado de Roraima durante chuvas em 2021 é:  '+ str(round(probRRChuva2021 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Roraima durante chuvas em 2021 é:  0.01%

# %%
RRChuva2022 = len(leitura2022[leitura2022['uf'] == 'RR'])  & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probRRChuva2022 = RRChuva2022 /len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado de Roraima durante chuvas em 2022 é:  '+ str(round(probRRChuva2022 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Roraima durante chuvas em 2022 é:  0.3%

# %%
RRChuva2023 = len(leitura2023[leitura2023['uf'] == 'RR'])  & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probRRChuva2023 = RRChuva2023 /len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado de Roraima durante chuvas em 2023 é:  '+ str(round(probRRChuva2023 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Roraima durante chuvas em 2023 é:  0.02%

# %%
totalRRChuvas = ((RRChuva2019 + RRChuva2020 + RRChuva2021 + RRChuva2022 + RRChuva2023) / trafficIncidents)
print(str(round(totalRRChuvas * 100,2)) + '%')
# Out:
# 0.13%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no TO durante chuvas:**

# %%
TOChuva2019 = len(leitura2019[leitura2019['uf'] == 'TO'])  & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probTOChuva2019 = TOChuva2019 /len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado do Tocantins durante chuvas em 2019 é:  '+ str(round(probTOChuva2019 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Tocantins durante chuvas em 2019 é:  0.0%

# %%
TOChuva2020 = len(leitura2020[leitura2020['uf'] == 'TO'])  & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probTOChuva2020 = TOChuva2020 /len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado do Tocantins durante chuvas em 2020 é:  '+ str(round(probTOChuva2020 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Tocantins durante chuvas em 2020 é:  0.83%

# %%
TOChuva2021 = len(leitura2021[leitura2021['uf'] == 'TO'])  & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probTOChuva2021 = TOChuva2021 /len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado do Tocantins durante chuvas em 2021 é:  '+ str(round(probTOChuva2021 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Tocantins durante chuvas em 2021 é:  0.08%

# %%
TOChuva2022 = len(leitura2022[leitura2022['uf'] == 'TO'])  & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probTOChuva2022 = TOChuva2022 /len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado do Tocantins durante chuvas em 2022 é:  '+ str(round(probTOChuva2022 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Tocantins durante chuvas em 2022 é:  0.82%

# %%
TOChuva2023 = len(leitura2023[leitura2023['uf'] == 'TO'])  & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probTOChuva2023 = TOChuva2023 /len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado do Tocantins durante chuvas em 2023 é:  '+ str(round(probTOChuva2023 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Tocantins durante chuvas em 2023 é:  0.89%

# %%
totalTOChuvas = ((TOChuva2019 + TOChuva2020 + TOChuva2021 + TOChuva2022 + TOChuva2023) / trafficIncidents)
print(str(round(totalTOChuvas * 100,2)) + '%')
# Out:
# 0.48%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no MA durante chuvas:**

# %%
MAChuva2019 = len(leitura2019[leitura2019['uf'] == 'MA'])  & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probMAChuva2019 = MAChuva2019 /len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado do Maranhão durante chuvas em 2019 é:  '+ str(round(probMAChuva2019 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Maranhão durante chuvas em 2019 é:  1.6%

# %%
MAChuva2020 = len(leitura2020[leitura2020['uf'] == 'MA'])  & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probMAChuva2020 = MAChuva2020 /len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado do Maranhão durante chuvas em 2020 é:  '+ str(round(probMAChuva2020 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Maranhão durante chuvas em 2020 é:  0.2%

# %%
MAChuva2021 = len(leitura2021[leitura2021['uf'] == 'MA'])  & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probMAChuva2021 = MAChuva2021 /len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado do Maranhão durante chuvas em 2021 é:  '+ str(round(probMAChuva2021 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Maranhão durante chuvas em 2021 é:  0.05%

# %%
MAChuva2022 = len(leitura2022[leitura2022['uf'] == 'MA'])  & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probMAChuva2022 = MAChuva2022 /len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado do Maranhão durante chuvas em 2022 é:  '+ str(round(probMAChuva2022 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Maranhão durante chuvas em 2022 é:  0.02%

# %%
MAChuva2023 = len(leitura2023[leitura2023['uf'] == 'MA'])  & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probMAChuva2023 = MAChuva2023 /len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado do Maranhão durante chuvas em 2023 é:  '+ str(round(probMAChuva2023 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Maranhão durante chuvas em 2023 é:  0.0%

# %%
totalMAChuvas = ((MAChuva2019 + MAChuva2020 + MAChuva2021 + MAChuva2022 + MAChuva2023) / trafficIncidents)
print(str(round(totalMAChuvas * 100,2)) + '%')
# Out:
# 0.43%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no PI durante chuvas:**

# %%
PIChuva2019 = len(leitura2019[leitura2019['uf'] == 'PI'])  & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probPIChuva2019 = PIChuva2019 /len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado do Piauí durante chuvas em 2019 é:  '+ str(round(probPIChuva2019 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Piauí durante chuvas em 2019 é:  1.52%

# %%
PIChuva2020 = len(leitura2020[leitura2020['uf'] == 'PI'])  & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probPIChuva2020 = PIChuva2020 /len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado do Piauí durante chuvas em 2020 é:  '+ str(round(probPIChuva2020 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Piauí durante chuvas em 2020 é:  0.23%

# %%
PIChuva2021 = len(leitura2021[leitura2021['uf'] == 'PI'])  & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probPIChuva2021 = PIChuva2021 /len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado do Piauí durante chuvas em 2021 é:  '+ str(round(probPIChuva2021 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Piauí durante chuvas em 2021 é:  0.08%

# %%
PIChuva2022 = len(leitura2022[leitura2022['uf'] == 'PI'])  & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probPIChuva2022 = PIChuva2022 /len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado do Piauí durante chuvas em 2022 é:  '+ str(round(probPIChuva2022 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Piauí durante chuvas em 2022 é:  0.13%

# %%
PIChuva2023 = len(leitura2023[leitura2023['uf'] == 'PI'])  & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probPIChuva2023 = PIChuva2023 /len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado do Piauí durante chuvas em 2023 é:  '+ str(round(probPIChuva2023 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Piauí durante chuvas em 2023 é:  0.1%

# %%
totalPIChuvas = ((PIChuva2019 + PIChuva2020 + PIChuva2021 + PIChuva2022 + PIChuva2023 )/ trafficIncidents)
print(str(round(totalPIChuvas * 100,2)) + '%')
# Out:
# 0.46%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no CE durante chuvas:**

# %%
CEChuva2019 = len(leitura2019[leitura2019['uf'] == 'CE'])  & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probCEChuva2019 = CEChuva2019 /len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado do Ceará durante chuvas em 2019 é:  '+ str(round(probCEChuva2019 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Ceará durante chuvas em 2019 é:  1.55%

# %%
CEChuva2020 = len(leitura2020[leitura2020['uf'] == 'CE'])  & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probCEChuva2020 = CEChuva2020 /len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado do Ceará durante chuvas em 2020 é:  '+ str(round(probCEChuva2020 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Ceará durante chuvas em 2020 é:  0.81%

# %%
CEChuva2021 = len(leitura2021[leitura2021['uf'] == 'CE'])  & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probCEChuva2021 = CEChuva2021 /len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado do Ceará durante chuvas em 2021 é:  '+ str(round(probCEChuva2021 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Ceará durante chuvas em 2021 é:  0.8%

# %%
CEChuva2022 = len(leitura2022[leitura2022['uf'] == 'CE'])  & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probCEChuva2022 = CEChuva2022 /len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado do Ceará durante chuvas em 2022 é:  '+ str(round(probCEChuva2022 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Ceará durante chuvas em 2022 é:  0.52%

# %%
CEChuva2023 = len(leitura2023[leitura2023['uf'] == 'CE'])  & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probCEChuva2023 = CEChuva2023 /len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado do Ceará durante chuvas em 2023 é:  '+ str(round(probCEChuva2023 *100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Ceará durante chuvas em 2023 é:  0.4%

# %%
totalCEChuvas = ((CEChuva2019 + CEChuva2020 + CEChuva2021 + CEChuva2022 + CEChuva2023) / trafficIncidents)
print(str(round(totalCEChuvas * 100,2)) + '%')
# Out:
# 0.87%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no CE durante chuvas:**

# %%
RNChuva2019 = len(leitura2019[leitura2019['uf'] == 'RN']) & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probRNChuva2019 = RNChuva2019 / len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado do Rio Grande do Norte durante chuvas em 2019 é: ' + str(round(probRNChuva2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Rio Grande do Norte durante chuvas em 2019 é: 1.57%

# %%
RNChuva2020 = len(leitura2020[leitura2020['uf'] == 'RN']) & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probRNChuva2020 = RNChuva2020 / len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado do Rio Grande do Norte durante chuvas em 2020 é: ' + str(round(probRNChuva2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Rio Grande do Norte durante chuvas em 2020 é: 0.04%

# %%
RNChuva2021 = len(leitura2021[leitura2021['uf'] == 'RN']) & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probRNChuva2021 = RNChuva2021 / len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado do Rio Grande do Norte durante chuvas em 2021 é: ' + str(round(probRNChuva2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Rio Grande do Norte durante chuvas em 2021 é: 0.08%

# %%
RNChuva2022 = len(leitura2022[leitura2022['uf'] == 'RN']) & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probRNChuva2022 = RNChuva2022 / len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado do Rio Grande do Norte durante chuvas em 2022 é: ' + str(round(probRNChuva2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Rio Grande do Norte durante chuvas em 2022 é: 0.4%

# %%
RNChuva2023 = len(leitura2023[leitura2023['uf'] == 'RN']) & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probRNChuva2023 = RNChuva2023 / len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado do Rio Grande do Norte durante chuvas em 2023 é: ' + str(round(probRNChuva2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Rio Grande do Norte durante chuvas em 2023 é: 0.41%

# %%
totalRNChuvas = ((RNChuva2019 + RNChuva2020 + RNChuva2021 + RNChuva2022 + RNChuva2023 )/ trafficIncidents)
print(str(round(totalRNChuvas * 100,2)) + '%')
# Out:
# 0.52%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no PB durante chuvas:**

# %%
PBChuva2019 = len(leitura2019[leitura2019['uf'] == 'PB']) & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probPBChuva2019 = PBChuva2019 / len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado da Paraíba durante chuvas em 2019 é: ' + str(round(probPBChuva2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado da Paraíba durante chuvas em 2019 é: 1.55%

# %%
PBChuva2020 = len(leitura2020[leitura2020['uf'] == 'PB']) & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probPBChuva2020 = PBChuva2020 / len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado da Paraíba durante chuvas em 2020 é: ' + str(round(probPBChuva2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado da Paraíba durante chuvas em 2020 é: 0.04%

# %%
PBChuva2021 = len(leitura2021[leitura2021['uf'] == 'PB']) & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probPBChuva2021 = PBChuva2021 / len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado da Paraíba durante chuvas em 2021 é: ' + str(round(probPBChuva2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado da Paraíba durante chuvas em 2021 é: 0.05%

# %%
PBChuva2022 = len(leitura2022[leitura2022['uf'] == 'PB']) & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probPBChuva2022 = PBChuva2022 / len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado da Paraíba durante chuvas em 2022 é: ' + str(round(probPBChuva2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado da Paraíba durante chuvas em 2022 é: 0.7%

# %%
PBChuva2023 = len(leitura2023[leitura2023['uf'] == 'PB']) & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probPBChuva2023 = PBChuva2023 / len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado da Paraíba durante chuvas em 2023 é: ' + str(round(probPBChuva2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado da Paraíba durante chuvas em 2023 é: 0.51%

# %%
totalPBChuvas = ((PBChuva2019 + PBChuva2020 + PBChuva2021 + PBChuva2022 + PBChuva2023) / trafficIncidents)
print(str(round(totalPBChuvas * 100,2)) + '%')
# Out:
# 0.59%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no AL durante chuvas:**

# %%
ALChuva2019 = len(leitura2019[leitura2019['uf'] == 'AL']) & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probALChuva2019 = ALChuva2019 / len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado de Alagoas durante chuvas em 2019 é: ' + str(round(probALChuva2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Alagoas durante chuvas em 2019 é: 0.08%

# %%
ALChuva2020 = len(leitura2020[leitura2020['uf'] == 'AL']) & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probALChuva2020 = ALChuva2020 / len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado de Alagoas durante chuvas em 2020 é: ' + str(round(probALChuva2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Alagoas durante chuvas em 2020 é: 0.84%

# %%
ALChuva2021 = len(leitura2021[leitura2021['uf'] == 'AL']) & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probALChuva2021 = ALChuva2021 / len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado de Alagoas durante chuvas em 2021 é: ' + str(round(probALChuva2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Alagoas durante chuvas em 2021 é: 0.8%

# %%
ALChuva2022 = len(leitura2022[leitura2022['uf'] == 'AL']) & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probALChuva2022 = ALChuva2022 / len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado de Alagoas durante chuvas em 2022 é: ' + str(round(probALChuva2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Alagoas durante chuvas em 2022 é: 0.92%

# %%
ALChuva2023 = len(leitura2023[leitura2023['uf'] == 'AL']) & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probALChuva2023 = ALChuva2023 / len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado de Alagoas durante chuvas em 2023 é: ' + str(round(probALChuva2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Alagoas durante chuvas em 2023 é: 0.89%

# %%
totalALChuvas = ((ALChuva2019 + ALChuva2020 + ALChuva2021 + ALChuva2022 + ALChuva2023 )/ trafficIncidents)
print(str(round(totalALChuvas * 100,2)) + '%')
# Out:
# 0.68%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no SE durante chuvas:**

# %%
SEChuva2019 = len(leitura2019[leitura2019['uf'] == 'SE']) & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probSEChuva2019 = SEChuva2019 / len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado de Sergipe durante chuvas em 2019 é: ' + str(round(probSEChuva2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Sergipe durante chuvas em 2019 é: 0.05%

# %%
SEChuva2020 = len(leitura2020[leitura2020['uf'] == 'SE']) & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probSEChuva2020 = SEChuva2020 / len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado de Sergipe durante chuvas em 2020 é: ' + str(round(probSEChuva2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Sergipe durante chuvas em 2020 é: 0.85%

# %%
SEChuva2021 = len(leitura2021[leitura2021['uf'] == 'SE']) & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probSEChuva2021 = SEChuva2021 / len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado de Sergipe durante chuvas em 2021 é: ' + str(round(probSEChuva2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Sergipe durante chuvas em 2021 é: 0.08%

# %%
SEChuva2022 = len(leitura2022[leitura2022['uf'] == 'SE']) & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probSEChuva2022 = SEChuva2022 / len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado de Sergipe durante chuvas em 2022 é: ' + str(round(probSEChuva2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Sergipe durante chuvas em 2022 é: 0.72%

# %%
SEChuva2023 = len(leitura2023[leitura2023['uf'] == 'SE']) & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probSEChuva2023 = SEChuva2023 / len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado de Sergipe durante chuvas em 2023 é: ' + str(round(probSEChuva2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Sergipe durante chuvas em 2023 é: 0.8%

# %%
totalSEChuvas = ((SEChuva2019 + SEChuva2020 + SEChuva2021 + SEChuva2022 + SEChuva2023) / trafficIncidents)
print(str(round(totalSEChuvas * 100,2)) + '%')
# Out:
# 0.46%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no BA durante chuvas:**

# %%
BAChuva2019 = len(leitura2019[leitura2019['uf'] == 'BA']) & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probBAChuva2019 = BAChuva2019 / len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado da Bahia durante chuvas em 2019 é: ' + str(round(probBAChuva2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado da Bahia durante chuvas em 2019 é: 4.58%

# %%
BAChuva2020 = len(leitura2020[leitura2020['uf'] == 'BA']) & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probBAChuva2020 = BAChuva2020 / len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado da Bahia durante chuvas em 2020 é: ' + str(round(probBAChuva2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado da Bahia durante chuvas em 2020 é: 3.43%

# %%
BAChuva2021 = len(leitura2021[leitura2021['uf'] == 'BA']) & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probBAChuva2021 = BAChuva2021 / len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado da Bahia durante chuvas em 2021 é: ' + str(round(probBAChuva2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado da Bahia durante chuvas em 2021 é: 3.25%

# %%
BAChuva2022 = len(leitura2022[leitura2022['uf'] == 'BA']) & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probBAChuva2022 = BAChuva2022 / len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado da Bahia durante chuvas em 2022 é: ' + str(round(probBAChuva2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado da Bahia durante chuvas em 2022 é: 3.69%

# %%
BAChuva2023 = len(leitura2023[leitura2023['uf'] == 'BA']) & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probBAChuva2023 = BAChuva2023 / len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado da Bahia durante chuvas em 2023 é: ' + str(round(probBAChuva2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado da Bahia durante chuvas em 2023 é: 3.56%

# %%
totalBAChuvas = ((BAChuva2019 + BAChuva2020 + BAChuva2021 + BAChuva2022 + BAChuva2023) / trafficIncidents)
print(str(round(totalBAChuvas * 100,2)) + '%')
# Out:
# 3.73%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no GO durante chuvas:**

# %%
GOChuva2019 = len(leitura2019[leitura2019['uf'] == 'GO']) & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probGOChuva2019 = GOChuva2019 / len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado de Goiás durante chuvas em 2019 é: ' + str(round(probGOChuva2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Goiás durante chuvas em 2019 é: 4.58%

# %%
GOChuva2020 = len(leitura2020[leitura2020['uf'] == 'GO']) & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probGOChuva2020 = GOChuva2020 / len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado de Goiás durante chuvas em 2020 é: ' + str(round(probGOChuva2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Goiás durante chuvas em 2020 é: 3.47%

# %%
GOChuva2021 = len(leitura2021[leitura2021['uf'] == 'GO']) & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probGOChuva2021 = GOChuva2021 / len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado de Goiás durante chuvas em 2021 é: ' + str(round(probGOChuva2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Goiás durante chuvas em 2021 é: 3.25%

# %%
GOChuva2022 = len(leitura2022[leitura2022['uf'] == 'GO']) & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probGOChuva2022 = GOChuva2022 / len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado de Goiás durante chuvas em 2022 é: ' + str(round(probGOChuva2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Goiás durante chuvas em 2022 é: 3.17%

# %%
GOChuva2023 = len(leitura2023[leitura2023['uf'] == 'GO']) & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probGOChuva2023 = GOChuva2023 / len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado de Goiás durante chuvas em 2023 é: ' + str(round(probGOChuva2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Goiás durante chuvas em 2023 é: 4.35%

# %%
totalGOChuvas = ((GOChuva2019 + GOChuva2020 + GOChuva2021 + GOChuva2022 + GOChuva2023) / trafficIncidents)
print(str(round(totalGOChuvas * 100,2)) + '%')
# Out:
# 3.71%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no MT durante chuvas:**

# %%
MTChuva2019 = len(leitura2019[leitura2019['uf'] == 'MT']) & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probMTChuva2019 = MTChuva2019 / len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado de Mato Grosso durante chuvas em 2019 é: ' + str(round(probMTChuva2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Mato Grosso durante chuvas em 2019 é: 3.06%

# %%
MTChuva2020 = len(leitura2020[leitura2020['uf'] == 'MT']) & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probMTChuva2020 = MTChuva2020 / len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado de Mato Grosso durante chuvas em 2020 é: ' + str(round(probMTChuva2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Mato Grosso durante chuvas em 2020 é: 3.45%

# %%
MTChuva2021 = len(leitura2021[leitura2021['uf'] == 'MT']) & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probMTChuva2021 = MTChuva2021 / len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado de Mato Grosso durante chuvas em 2021 é: ' + str(round(probMTChuva2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Mato Grosso durante chuvas em 2021 é: 3.2%

# %%
MTChuva2022 = len(leitura2022[leitura2022['uf'] == 'MT']) & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probMTChuva2022 = MTChuva2022 / len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado de Mato Grosso durante chuvas em 2022 é: ' + str(round(probMTChuva2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Mato Grosso durante chuvas em 2022 é: 3.3%

# %%
MTChuva2023 = len(leitura2023[leitura2023['uf'] == 'MT']) & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probMTChuva2023 = MTChuva2023 / len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado de Mato Grosso durante chuvas em 2023 é: ' + str(round(probMTChuva2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Mato Grosso durante chuvas em 2023 é: 3.26%

# %%
totalMTChuvas = ((MTChuva2019 + MTChuva2020 + MTChuva2021 + MTChuva2022 + MTChuva2023) / trafficIncidents)
print(str(round(totalMTChuvas * 100,2)) + '%')
# Out:
# 3.25%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no MS durante chuvas:**

# %%
MSChuva2019 = len(leitura2019[leitura2019['uf'] == 'MS']) & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probMSChuva2019 = MSChuva2019 / len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado de Mato Grosso do Sul durante chuvas em 2019 é: ' + str(round(probMSChuva2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Mato Grosso do Sul durante chuvas em 2019 é: 1.55%

# %%
MSChuva2020 = len(leitura2020[leitura2020['uf'] == 'MS']) & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probMSChuva2020 = MSChuva2020 / len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado de Mato Grosso do Sul durante chuvas em 2020 é: ' + str(round(probMSChuva2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Mato Grosso do Sul durante chuvas em 2020 é: 0.81%

# %%
MSChuva2021 = len(leitura2021[leitura2021['uf'] == 'MS']) & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probMSChuva2021 = MSChuva2021 / len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado de Mato Grosso do Sul durante chuvas em 2021 é: ' + str(round(probMSChuva2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Mato Grosso do Sul durante chuvas em 2021 é: 0.85%

# %%
MSChuva2022 = len(leitura2022[leitura2022['uf'] == 'MS']) & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probMSChuva2022 = MSChuva2022 / len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado de Mato Grosso do Sul durante chuvas em 2022 é: ' + str(round(probMSChuva2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Mato Grosso do Sul durante chuvas em 2022 é: 0.9%

# %%
MSChuva2023 = len(leitura2023[leitura2023['uf'] == 'MS']) & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probMSChuva2023 = MSChuva2023 / len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado de Mato Grosso do Sul durante chuvas em 2023 é: ' + str(round(probMSChuva2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado de Mato Grosso do Sul durante chuvas em 2023 é: 0.9%

# %%
totalMSChuvas = ((MSChuva2019 + MSChuva2020 + MSChuva2021 + MSChuva2022 + MSChuva2023) / trafficIncidents)
print(str(round(totalMSChuvas * 100,2)) + '%')
# Out:
# 1.02%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no DF durante chuvas:**

# %%
DFChuva2019 = len(leitura2019[leitura2019['uf'] == 'DF']) & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probDFChuva2019 = DFChuva2019 / len(leitura2019)
print('A probabilidade dos acidentes acontecerem no Distrito Federal durante chuvas em 2019 é: ' + str(round(probDFChuva2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Distrito Federal durante chuvas em 2019 é: 1.52%

# %%
DFChuva2020 = len(leitura2020[leitura2020['uf'] == 'DF']) & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probDFChuva2020 = DFChuva2020 / len(leitura2020)
print('A probabilidade dos acidentes acontecerem no Distrito Federal durante chuvas em 2020 é: ' + str(round(probDFChuva2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Distrito Federal durante chuvas em 2020 é: 0.03%

# %%
DFChuva2021 = len(leitura2021[leitura2021['uf'] == 'DF']) & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probDFChuva2021 = DFChuva2021 / len(leitura2021)
print('A probabilidade dos acidentes acontecerem no Distrito Federal durante chuvas em 2021 é: ' + str(round(probDFChuva2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Distrito Federal durante chuvas em 2021 é: 0.82%

# %%
DFChuva2022 = len(leitura2022[leitura2022['uf'] == 'DF']) & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probDFChuva2022 = DFChuva2022 / len(leitura2022)
print('A probabilidade dos acidentes acontecerem no Distrito Federal durante chuvas em 2022 é: ' + str(round(probDFChuva2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Distrito Federal durante chuvas em 2022 é: 1.42%

# %%
DFChuva2023 = len(leitura2023[leitura2023['uf'] == 'DF']) & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probDFChuva2023 = DFChuva2023 / len(leitura2023)
print('A probabilidade dos acidentes acontecerem no Distrito Federal durante chuvas em 2023 é: ' + str(round(probDFChuva2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Distrito Federal durante chuvas em 2023 é: 1.18%

# %%
totalDFChuvas = ((DFChuva2019 + DFChuva2020 + DFChuva2021 + DFChuva2022 + DFChuva2023) / trafficIncidents)
print(str(round(totalDFChuvas * 100,2)) + '%')
# Out:
# 0.98%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no ES durante chuvas:**

# %%
ESChuva2019 = len(leitura2019[leitura2019['uf'] == 'ES']) & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probESChuva2019 = ESChuva2019 / len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado do Espírito Santo durante chuvas em 2019 é: ' + str(round(probESChuva2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Espírito Santo durante chuvas em 2019 é: 3.06%

# %%
ESChuva2020 = len(leitura2020[leitura2020['uf'] == 'ES']) & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probESChuva2020 = ESChuva2020 / len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado do Espírito Santo durante chuvas em 2020 é: ' + str(round(probESChuva2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Espírito Santo durante chuvas em 2020 é: 3.43%

# %%
ESChuva2021 = len(leitura2021[leitura2021['uf'] == 'ES']) & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probESChuva2021 = ESChuva2021 / len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado do Espírito Santo durante chuvas em 2021 é: ' + str(round(probESChuva2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Espírito Santo durante chuvas em 2021 é: 3.2%

# %%
ESChuva2022 = len(leitura2022[leitura2022['uf'] == 'ES']) & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probESChuva2022 = ESChuva2022 / len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado do Espírito Santo durante chuvas em 2022 é: ' + str(round(probESChuva2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Espírito Santo durante chuvas em 2022 é: 3.47%

# %%
ESChuva2023 = len(leitura2023[leitura2023['uf'] == 'ES']) & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probESChuva2023 = ESChuva2023 / len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado do Espírito Santo durante chuvas em 2023 é: ' + str(round(probESChuva2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Espírito Santo durante chuvas em 2023 é: 3.16%

# %%
totalESChuvas = ((ESChuva2019 + ESChuva2020 + ESChuva2021 + ESChuva2022 + ESChuva2023) / trafficIncidents)
print(str(round(totalESChuvas * 100,2)) + '%')
# Out:
# 3.28%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no PR durante chuvas:**

# %%
PRChuva2019 = len(leitura2019[leitura2019['uf'] == 'PR']) & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probPRChuva2019 = PRChuva2019 / len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado do Paraná durante chuvas em 2019 é: ' + str(round(probPRChuva2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Paraná durante chuvas em 2019 é: 10.66%

# %%
PRChuva2020 = len(leitura2020[leitura2020['uf'] == 'PR']) & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probPRChuva2020 = PRChuva2020 / len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado do Paraná durante chuvas em 2020 é: ' + str(round(probPRChuva2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Paraná durante chuvas em 2020 é: 9.71%

# %%
PRChuva2021 = len(leitura2021[leitura2021['uf'] == 'PR']) & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probPRChuva2021 = PRChuva2021 / len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado do Paraná durante chuvas em 2021 é: ' + str(round(probPRChuva2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Paraná durante chuvas em 2021 é: 9.58%

# %%
PRChuva2022 = len(leitura2022[leitura2022['uf'] == 'PR']) & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probPRChuva2022 = PRChuva2022 / len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado do Paraná durante chuvas em 2022 é: ' + str(round(probPRChuva2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Paraná durante chuvas em 2022 é: 9.84%

# %%
PRChuva2023 = len(leitura2023[leitura2023['uf'] == 'PR']) & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probPRChuva2023 = PRChuva2023 / len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado do Paraná durante chuvas em 2023 é: ' + str(round(probPRChuva2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Paraná durante chuvas em 2023 é: 10.36%

# %%
totalPRChuvas = ((PRChuva2019 + PRChuva2020 + PRChuva2021 + PRChuva2022 + PRChuva2023) / trafficIncidents)
print(str(round(totalPRChuvas * 100,2)) + '%')
# Out:
# 10.0%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem no RS durante chuvas:**

# %%
RSChuva2019 = len(leitura2019[leitura2019['uf'] == 'RS']) & len(leitura2019[leitura2019['condicao_metereologica'] == 'Chuva'])
probRSChuva2019 = RSChuva2019 / len(leitura2019)
print('A probabilidade dos acidentes acontecerem no estado do Rio Grande do Sul durante chuvas em 2019 é: ' + str(round(probRSChuva2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Rio Grande do Sul durante chuvas em 2019 é: 6.14%

# %%
RSChuva2020 = len(leitura2020[leitura2020['uf'] == 'RS']) & len(leitura2020[leitura2020['condicao_metereologica'] == 'Chuva'])
probRSChuva2020 = RSChuva2020 / len(leitura2020)
print('A probabilidade dos acidentes acontecerem no estado do Rio Grande do Sul durante chuvas em 2020 é: ' + str(round(probRSChuva2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Rio Grande do Sul durante chuvas em 2020 é: 6.47%

# %%
RSChuva2021 = len(leitura2021[leitura2021['uf'] == 'RS']) & len(leitura2021[leitura2021['condicao_metereologica'] == 'Chuva'])
probRSChuva2021 = RSChuva2021 / len(leitura2021)
print('A probabilidade dos acidentes acontecerem no estado do Rio Grande do Sul durante chuvas em 2021 é: ' + str(round(probRSChuva2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Rio Grande do Sul durante chuvas em 2021 é: 6.42%

# %%
RSChuva2022 = len(leitura2022[leitura2022['uf'] == 'RS']) & len(leitura2022[leitura2022['condicao_metereologica'] == 'Chuva'])
probRSChuva2022 = RSChuva2022 / len(leitura2022)
print('A probabilidade dos acidentes acontecerem no estado do Rio Grande do Sul durante chuvas em 2022 é: ' + str(round(probRSChuva2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Rio Grande do Sul durante chuvas em 2022 é: 7.64%

# %%
RSChuva2023 = len(leitura2023[leitura2023['uf'] == 'RS']) & len(leitura2023[leitura2023['condicao_metereologica'] == 'Chuva'])
probRSChuva2023 = RSChuva2023 / len(leitura2023)
print('A probabilidade dos acidentes acontecerem no estado do Rio Grande do Sul durante chuvas em 2023 é: ' + str(round(probRSChuva2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no estado do Rio Grande do Sul durante chuvas em 2023 é: 7.6%

# %%
totalRSChuvas = ((RSChuva2019 + RSChuva2020 + RSChuva2021 + RSChuva2022 + RSChuva2023) / trafficIncidents)
print(str(round(totalRSChuvas * 100,2)) + '%')
# Out:
# 6.77%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem na região Centro-Oeste durante chuvas:**

# %%
totalRegCentroOeste2019 = ((MTChuva2019 + MSChuva2019 + GOChuva2019) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na região Centro-Oeste durante chuvas em 2019 é: "+ str(round(totalRegCentroOeste2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na região Centro-Oeste durante chuvas em 2019 é: 2.12%

# %%
totalRegCentroOeste2020 = ((MTChuva2020 + MSChuva2020 + GOChuva2020) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na região Centro-Oeste durante chuvas em 2020 é: "+ str(round(totalRegCentroOeste2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na região Centro-Oeste durante chuvas em 2020 é: 1.68%

# %%
totalRegCentroOeste2021 = ((MTChuva2021 + MSChuva2021 + GOChuva2021) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na região Centro-Oeste durante chuvas em 2021 é: "+ str(round(totalRegCentroOeste2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na região Centro-Oeste durante chuvas em 2021 é: 1.61%

# %%
totalRegCentroOeste2022 = ((MTChuva2022 + MSChuva2022 + GOChuva2022) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na região Centro-Oeste durante chuvas em 2022 é: "+ str(round(totalRegCentroOeste2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na região Centro-Oeste durante chuvas em 2022 é: 1.63%

# %%
totalRegCentroOeste2023 = ((MTChuva2023 + MSChuva2023 + GOChuva2023) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na região Centro-Oeste durante chuvas em 2023 é: "+ str(round(totalRegCentroOeste2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na região Centro-Oeste durante chuvas em 2023 é: 0.94%

# %% [markdown]
#  **Probabilidade dos acidentes acontecerem na região Nordeste durante chuvas**
#
# ---

# %%
totalRegNordeste2019 = ((MAChuva2019 + PIChuva2019 + CEChuva2019 + RNChuva2019 + PEChuva2019 + PBChuva2019 + SEChuva2019 + ALChuva2019 + BAChuva2019) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na região Nordeste durante chuvas em 2019 é: "+ str(round(totalRegNordeste2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na região Nordeste durante chuvas em 2019 é: 3.6%

# %%
totalRegNordeste2020 = ((MAChuva2020 + PIChuva2020 + CEChuva2020 + RNChuva2020 + PEChuva2020 + PBChuva2020 + SEChuva2020 + ALChuva2020 + BAChuva2020) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na região Nordeste durante chuvas em 2020 é: " + str(round(totalRegNordeste2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na região Nordeste durante chuvas em 2020 é: 2.27%

# %%
totalRegNordeste2021 = ((MAChuva2021 + PIChuva2021 + CEChuva2021 + RNChuva2021 + PEChuva2021 + PBChuva2021 + SEChuva2021 + ALChuva2021 + BAChuva2021) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na região Nordeste durante chuvas em 2021 é: " + str(round(totalRegNordeste2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na região Nordeste durante chuvas em 2021 é: 1.86%

# %%
totalRegNordeste2022 = ((MAChuva2022 + PIChuva2022 + CEChuva2022 + RNChuva2022 + PEChuva2022 + PBChuva2022 + SEChuva2022 + ALChuva2022 + BAChuva2022)/ trafficIncidents)
print("A probabilidade dos acidentes acontecerem na região Nordeste durante chuvas em 2022 é: " + str(round(totalRegNordeste2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na região Nordeste durante chuvas em 2022 é: 2.49%

# %%
totalRegNordeste2023 = ((MAChuva2023 + PIChuva2023 + CEChuva2023 + RNChuva2023 + PEChuva2023 + PBChuva2023 + SEChuva2023 + ALChuva2023 + BAChuva2023) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na região Nordeste durante chuvas em 2023 é: " + str(round(totalRegNordeste2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na região Nordeste durante chuvas em 2023 é: 1.23%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem na região Sul durante chuvas**

# %%
totalRegSul2019 = ((RSChuva2019 + SCChuva2019 + PRChuva2019) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Sul durante chuvas em 2019 é: " + str(round(totalRegSul2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Sul durante chuvas em 2019 é: 3.9%

# %%
totalRegSul2020 = ((RSChuva2020 + SCChuva2020 + PRChuva2020) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Sul durante chuvas em 2020 é: " + str(round(totalRegSul2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Sul durante chuvas em 2020 é: 5.62%

# %%
totalRegSul2021 = ((RSChuva2021 + SCChuva2021 + PRChuva2021) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Sul durante chuvas em 2021 é: " + str(round(totalRegSul2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Sul durante chuvas em 2021 é: 5.81%

# %%
totalRegSul2022 = ((RSChuva2022 + SCChuva2022 + PRChuva2022) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Sul durante chuvas em 2022 é: " + str(round(totalRegSul2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Sul durante chuvas em 2022 é: 6.09%

# %%
totalRegSul2023 = ((RSChuva2023 + SCChuva2023 + PRChuva2023) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Sul durante chuvas em 2023 é: " + str(round(totalRegSul2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Sul durante chuvas em 2023 é: 3.1%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem na região Sudeste durante chuvas**

# %%
totalRegSudeste2019 = ((SPChuva2019 + RJChuva2019 + ESChuva2019 + MGChuva2019) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Sudeste durante chuvas em 2019 é: " + str(round(totalRegSudeste2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Sudeste durante chuvas em 2019 é: 3.52%

# %%
totalRegSudeste2020 = ((SPChuva2020 + RJChuva2020 + ESChuva2020 + MGChuva2020) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Sudeste durante chuvas em 2019 é: " + str(round(totalRegSudeste2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Sudeste durante chuvas em 2019 é: 3.16%

# %%
totalRegSudeste2021 = ((SPChuva2021 + RJChuva2021 + ESChuva2021 + MGChuva2021) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Sudeste durante chuvas em 2021 é: " + str(round(totalRegSudeste2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Sudeste durante chuvas em 2021 é: 3.52%

# %%
totalRegSudeste2022 = ((SPChuva2022 + RJChuva2022 + ESChuva2022 + MGChuva2022) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Sudeste durante chuvas em 2022 é: " + str(round(totalRegSudeste2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Sudeste durante chuvas em 2022 é: 3.87%

# %%
totalRegSudeste2023 = ((SPChuva2023 + RJChuva2023 + ESChuva2023 + MGChuva2023) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Sudeste durante chuvas em 2023 é: " + str(round(totalRegSudeste2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Sudeste durante chuvas em 2023 é: 1.86%

# %% [markdown]
# **Probabilidade dos acidentes acontecerem na região Norte durante chuvas**

# %%
totalRegNorte2019 = ((AMChuva2019 + RRChuva2022 + APChuva2019 + PAChuva2019 + TOChuva2019 + ROChuva2019 + ACChuva2019) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Norte durante chuvas em 2019 é: " + str(round(totalRegNorte2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Norte durante chuvas em 2019 é: 0.45%

# %%
totalRegNorte2020 = ((AMChuva2020 + RRChuva2020 + APChuva2020 + PAChuva2020 + TOChuva2020 + ROChuva2020 + ACChuva2020) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Norte durante chuvas em 2020 é: " + str(round(totalRegNorte2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Norte durante chuvas em 2020 é: 0.6%

# %%
totalRegNorte2021 = ((AMChuva2021 + RRChuva2021 + APChuva2021 + PAChuva2021 + TOChuva2021 + ROChuva2021 + ACChuva2021) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Norte durante chuvas em 2021 é: " + str(round(totalRegNorte2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Norte durante chuvas em 2021 é: 0.23%

# %%
totalRegNorte2022 = ((AMChuva2022 + RRChuva2022 + APChuva2022 + PAChuva2022 + TOChuva2022 + ROChuva2022 + ACChuva2022) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Norte durante chuvas em 2022 é: " + str(round(totalRegNorte2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Norte durante chuvas em 2022 é: 0.77%

# %%
totalRegNorte2023 = ((AMChuva2023 + RRChuva2023 + APChuva2023 + PAChuva2023 + TOChuva2023 + ROChuva2023 + ACChuva2023) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Norte durante chuvas em 2023 é: " + str(round(totalRegNorte2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Norte durante chuvas em 2023 é: 0.32%

# %% [markdown]
# **Conclusão:**
# Sabe-se que as chuvas aumentam o risco de acidentes no trânito, pois afeta a visibilidade do motorista, os pneus, os freios e é necessário maior atenção.
# Após a análise de 7 estados variados pelo Brasil pode-se notar que nas regiões do Nordeste e Centro-oeste a quantidade de acidentes nas chuvas é baixo, devido principalmente a questões climática, como a seca. Assim, como nos estados do Sudeste e Sul é notório um alto índice de acidentes na chuva também decorrentes dos fatores climáticos, como o fenômeno dos rios voadores. Entranto, na região Norte os índices são baixissímos, devido ao enfrentamento de secas nos últimos anos e ao fator da população evitar sair durante períodos de chuvas, afinal por estarem próximos da floresta Amazônica a úmidade é alta causando chuvas intensas.

# %% [markdown]
# # **Probabilidade da União**

# %% [markdown]
# **Probabilidade dos acidentes acontecem em SP nos fins de semana - sexta, sábado e domingo**

# %%
SPfds2019 = len(leitura2019[leitura2019['uf'] == 'SP'])  & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probSPfds2019 = SPfds2019/ len(leitura2019)

print('A probabilidade dos acidentes acontecem em SP nos fins de semana em 2019 é de : '+ str(round(probSPfds2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em SP nos fins de semana em 2019 é de : 6.08%

# %%
SPfds2020 = len(leitura2020[leitura2020['uf'] == 'SP'])  & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probSPfds2020 = round(SPfds2020/len(leitura2020), 2)

print('A probabilidade dos acidentes acontecem em SP nos fins de semana em 2020 é de : '+ str(round(probSPfds2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em SP nos fins de semana em 2020 é de : 6.0%

# %%
SPfds2021 = len(leitura2021[leitura2021['uf'] == 'SP'])  & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probSPfds2021 = round(SPfds2021/len(leitura2021), 2)

print('A probabilidade dos acidentes acontecem em SP nos fins de semana em 2021 é de : '+ str(round(probSPfds2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em SP nos fins de semana em 2021 é de : 6.0%

# %%
SPfds2022 = len(leitura2022[leitura2022['uf'] == 'SP'])  & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probSPfds2022 = round(SPfds2022/len(leitura2022), 2)

print('A probabilidade dos acidentes acontecem em SP nos fins de semana em 2022 é de : '+ str(round(probSPfds2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em SP nos fins de semana em 2022 é de : 7.0%

# %%
SPfds2023 = len(leitura2023[leitura2023['uf'] == 'SP'])  & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probSPfds2023 = round(SPfds2023/len(leitura2023), 2)

print('A probabilidade dos acidentes acontecem em SP nos fins de semana em 2023 é de : '+ str(round(probSPfds2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em SP nos fins de semana em 2023 é de : 7.0%

# %%
totalSPfds = (SPfds2019 + SPfds2020 + SPfds2021 + SPfds2022 + SPfds2023) / trafficIncidents
print(str(round(totalSPfds * 100,2)) + '%')
# Out:
# 6.33%

# %% [markdown]
# **Probabilidade dos acidentes acontecem em MG nos fins de semana - sexta, sábado e domingo**

# %%
MGfds2019 = len(leitura2019[leitura2019['uf'] == 'MG'])
probMGfds2019 = MGfds2019/ len(leitura2019)

print('A probabilidade dos acidentes acontecem em Minas Gerais nos fins de semana em 2019 é de : '+ str(round(probMGfds2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em Minas Gerais nos fins de semana em 2019 é de : 12.93%

# %%
MGfds2020 = len(leitura2020[leitura2020['uf'] == 'MG'])  & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020[('dia_semana')] == 'domingo')])
probMGfds2020 = MGfds2020/ len(leitura2020)

print('A probabilidade dos acidentes acontecem em Minas Gerais nos fins de semana em 2020 é de : '+ str(round(probMGfds2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em Minas Gerais nos fins de semana em 2020 é de : 0.26%

# %%
MGfds2021 = len(leitura2021[leitura2021['uf'] == 'MG'])  & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021[('dia_semana')] == 'domingo')])
probMGfds2021 = MGfds2021/ len(leitura2021)

print('A probabilidade dos acidentes acontecem em Minas Gerais nos fins de semana em 2021 é de : '+ str(round(probMGfds2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em Minas Gerais nos fins de semana em 2021 é de : 0.01%

# %%
MGfds2022 = len(leitura2022[leitura2022['uf'] == 'MG'])  & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022[('dia_semana')] == 'domingo')])
probMGfds2022 = MGfds2022/ len(leitura2022)

print('A probabilidade dos acidentes acontecem em Minas Gerais nos fins de semana em 2022 é de : '+ str(round(probMGfds2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em Minas Gerais nos fins de semana em 2022 é de : 0.05%

# %%
MGfds2023 = len(leitura2023[leitura2023['uf'] == 'MG'])  & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023[('dia_semana')] == 'domingo')])
probMGfds2023 = MGfds2023/ len(leitura2023)

print('A probabilidade dos acidentes acontecem em Minas Gerais nos fins de semana em 2023 é de : '+ str(round(probMGfds2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em Minas Gerais nos fins de semana em 2023 é de : 0.03%

# %%
totalMGfds = (MGfds2019 + MGfds2020 + MGfds2021 + MGfds2022 + MGfds2023) / trafficIncidents
print(str(round(totalMGfds * 100, 2)) + '%')
# Out:
# 3.06%

# %% [markdown]
# **Probabilidade dos acidentes acontecem em PE nos fins de semana - sexta, sábado e domingo**

# %%
PEfds2019 = len(leitura2019[leitura2019['uf'] == 'PE']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probPEfds2019 = PEfds2019/ len(leitura2019)

print('A probabilidade dos acidentes acontecem em Pernambuco nos fins de semana em 2019 é de : '+ str(round(probPEfds2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em Pernambuco nos fins de semana em 2019 é de : 0.19%

# %%
PEfds2020 = len(leitura2020[leitura2020['uf'] == 'PE']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probPEfds2020 = PEfds2020/ len(leitura2020)

print('A probabilidade dos acidentes acontecem em Pernambuco nos fins de semana em 2020 é de : '+ str(round(probPEfds2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em Pernambuco nos fins de semana em 2020 é de : 4.03%

# %%
PEfds2021 = len(leitura2021[leitura2021['uf'] == 'PE']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probPEfds2021 = PEfds2021/ len(leitura2021)
#Qual o problema??
print('A probabilidade dos acidentes acontecem em Pernambuco nos fins de semana em 2021 é de : '+ str(round(probPEfds2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em Pernambuco nos fins de semana em 2021 é de : 0.0%

# %%
PEfds2022 = len(leitura2022[leitura2022['uf'] == 'PE']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probPEfds2022 = PEfds2022/ len(leitura2022)

print('A probabilidade dos acidentes acontecem em Pernambuco nos fins de semana em 2022 é de : '+ str(round(probPEfds2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em Pernambuco nos fins de semana em 2022 é de : 0.26%

# %%
PEfds2023 = len(leitura2023[leitura2023['uf'] == 'PE']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probPEfds2023 = PEfds2023/ len(leitura2023)

print('A probabilidade dos acidentes acontecem em Pernambuco nos fins de semana em 2023 é de : '+ str(round(probPEfds2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em Pernambuco nos fins de semana em 2023 é de : 0.1%

# %%
totalPEfds = (PEfds2019 + PEfds2020 + PEfds2021 + PEfds2022 + PEfds2023) / trafficIncidents
print(str(round(totalPEfds * 100, 2)) + '%')
# Out:
# 0.99%

# %% [markdown]
# **Probabilidade dos acidentes acontecem no  PA nos fins de semana - sexta, sábado e domingo**

# %%
PAfds2019 = len(leitura2019[leitura2019['uf'] == 'PA']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probPAfds2019 = PAfds2019/ len(leitura2019)

print('A probabilidade dos acidentes acontecem no Parà nos fins de semana em 2019 é de : '+ str(round(probPAfds2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Parà nos fins de semana em 2019 é de : 0.01%

# %%
PAfds2020 = len(leitura2020[leitura2020['uf'] == 'PA']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probPAfds2020 = PAfds2020/ len(leitura2020)

print('A probabilidade dos acidentes acontecem no Parà nos fins de semana em 2020 é de : '+ str(round(probPAfds2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Parà nos fins de semana em 2020 é de : 1.11%

# %%
PAfds2021 = len(leitura2021[leitura2021['uf'] == 'PA']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021[('dia_semana')] == 'domingo')])
probPAfds2021 = PAfds2021/ len(leitura2021)

print('A probabilidade dos acidentes acontecem no Parà nos fins de semana em 2021 é de : '+ str(round(probPAfds2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Parà nos fins de semana em 2021 é de : 0.8%

# %%
PAfds2022 = len(leitura2022[leitura2022['uf'] == 'PA']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probPAfds2022 = PAfds2022/ len(leitura2022)

print('A probabilidade dos acidentes acontecem no Parà nos fins de semana em 2022 é de : '+ str(round(probPAfds2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Parà nos fins de semana em 2022 é de : 0.46%

# %%
PAfds2023 = len(leitura2023[leitura2023['uf'] == 'PA']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023[('dia_semana')] == 'domingo')])
probPAfds2023 = PAfds2023/ len(leitura2023)

print('A probabilidade dos acidentes acontecem no Parà nos fins de semana em 2023 é de : '+ str(round(probPAfds2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Parà nos fins de semana em 2023 é de : 0.1%

# %%
totalPAfds = (PAfds2019 + PAfds2020 + PAfds2021 + PAfds2022 + PAfds2023) / trafficIncidents
print(str(round(totalPAfds * 100, 2)) + '%')
# Out:
# 0.53%

# %% [markdown]
# **Probabilidade dos acidentes acontecem em SC nos fins de semana - sexta, sábado e domingo**

# %%
SCfds2019 = len(leitura2019[leitura2019['uf'] == 'SC']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probSCfds2019 = SCfds2019/ len(leitura2019)

print('A probabilidade dos acidentes acontecem em Santa Catarina nos fins de semana em 2019 é de : '+ str(round(probSCfds2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em Santa Catarina nos fins de semana em 2019 é de : 0.28%

# %%
SCfds2020 = len(leitura2020[leitura2020['uf'] == 'SC']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020[('dia_semana')] == 'domingo')])
probSCfds2020 = SCfds2020/ len(leitura2020)

print('A probabilidade dos acidentes acontecem em Santa Catarina nos fins de semana em 2020 é de : '+ str(round(probSCfds2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em Santa Catarina nos fins de semana em 2020 é de : 4.88%

# %%
SCfds2021= len(leitura2021[leitura2021['uf'] == 'SC']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probSCfds2021 = SCfds2021/ len(leitura2021)

print('A probabilidade dos acidentes acontecem em Santa Catarina nos fins de semana em 2021 é de : '+ str(round(probSCfds2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em Santa Catarina nos fins de semana em 2021 é de : 7.14%

# %%
SCfds2022= len(leitura2022[leitura2022['uf'] == 'SC']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probSCfds2022 = SCfds2022/ len(leitura2022)

print('A probabilidade dos acidentes acontecem em Santa Catarina nos fins de semana em 2022 é de : '+ str(round(probSCfds2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em Santa Catarina nos fins de semana em 2022 é de : 6.99%

# %%
SCfds2022= len(leitura2022[leitura2022['uf'] == 'SC']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022[('dia_semana')] == 'domingo')])
probSCfds2022 = SCfds2022/ len(leitura2022)

print('A probabilidade dos acidentes acontecem em Santa Catarina nos fins de semana em 2022 é de : '+ str(round(probSCfds2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em Santa Catarina nos fins de semana em 2022 é de : 6.99%

# %%
SCfds2023= len(leitura2023[leitura2023['uf'] == 'SC']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023[('dia_semana')] == 'domingo')])
probSCfds2023 = SCfds2023/ len(leitura2023)

print('A probabilidade dos acidentes acontecem em Santa Catarina nos fins de semana em 2023 é de : '+ str(round(probSCfds2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem em Santa Catarina nos fins de semana em 2023 é de : 6.65%

# %%
totalSCfds = (SCfds2019 + SCfds2020 + SCfds2021 + SCfds2022 + SCfds2023) / trafficIncidents
print(str(round(totalSCfds * 100, 2)) + '%')
# Out:
# 4.98%

# %% [markdown]
# **Probabilidade dos acidentes acontecem no RJ nos fins de semana - sexta, sábado e domingo**

# %%
RJfds2019 = len(leitura2019[leitura2019['uf'] == 'RJ']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probRJfds2019 = RJfds2019/ len(leitura2019)

print('A probabilidade dos acidentes acontecem no Rio de Janeiro nos fins de semana em 2019 é de : '+ str(round(probRJfds2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Rio de Janeiro nos fins de semana em 2019 é de : 6.07%

# %%
RJfds2020 = len(leitura2020[leitura2020['uf'] == 'RJ']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probRJfds2020 = RJfds2020/ len(leitura2020)

print('A probabilidade dos acidentes acontecem no Rio de Janeiro nos fins de semana em 2020 é de : '+ str(round(probRJfds2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Rio de Janeiro nos fins de semana em 2020 é de : 0.2%

# %%
RJfds2021 = len(leitura2021[leitura2021['uf'] == 'RJ']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probRJfds2021 = RJfds2021/ len(leitura2021)

print('A probabilidade dos acidentes acontecem no Rio de Janeiro nos fins de semana em 2021 é de : '+ str(round(probRJfds2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Rio de Janeiro nos fins de semana em 2021 é de : 6.35%

# %%
RJfds2022= len(leitura2022[leitura2022['uf'] == 'RJ']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probRJfds2022 = RJfds2022/ len(leitura2022)

print('A probabilidade dos acidentes acontecem no Rio de Janeiro nos fins de semana em 2022 é de : '+ str(round(probRJfds2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Rio de Janeiro nos fins de semana em 2022 é de : 6.4%

# %%
RJfds2023 = len(leitura2023[leitura2023['uf'] == 'RJ']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probRJfds2023 = RJfds2023/ len(leitura2023)

print('A probabilidade dos acidentes acontecem no Rio de Janeiro nos fins de semana em 2023 é de : '+ str(round(probRJfds2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Rio de Janeiro nos fins de semana em 2023 é de : 6.44%

# %%
totalRJfds = (RJfds2019 + RJfds2020 + RJfds2021 + RJfds2022 + RJfds2023) / trafficIncidents
print(str(round(totalRJfds * 100, 2)) + '%')
# Out:
# 4.97%

# %% [markdown]
# **Probabilidade dos acidentes acontecem no AM nos fins de semana - sexta, sábado e domingo**

# %%
AMfds2019 = len(leitura2019[leitura2019['uf'] == 'AM']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probAMfds2019 = AMfds2019/ len(leitura2019)

print('A probabilidade dos acidentes acontecem no Amazonas nos fins de semana em 2019 é de : '+ str(round(probAMfds2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Amazonas nos fins de semana em 2019 é de : 0.1%

# %%
AMfds2020 = len(leitura2020[leitura2020['uf'] == 'AM']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020[('dia_semana')] == 'domingo')])
probAMfds2020 = AMfds2020/ len(leitura2020)

print('A probabilidade dos acidentes acontecem no Amazonas nos fins de semana em 2020 é de : '+ str(round(probAMfds2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Amazonas nos fins de semana em 2020 é de : 0.2%

# %%
AMfds2021 = len(leitura2021[leitura2021['uf'] == 'AM']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021[('dia_semana')] == 'domingo')])
probAMfds2021 = AMfds2021/ len(leitura2021)

print('A probabilidade dos acidentes acontecem no Amazonas nos fins de semana em 2021 é de : '+ str(round(probAMfds2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Amazonas nos fins de semana em 2021 é de : 0.01%

# %%
AMfds2022 = len(leitura2022[leitura2022['uf'] == 'AM']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022[('dia_semana')] == 'domingo')])
probAMfds2022 = AMfds2022/ len(leitura2022)

print('A probabilidade dos acidentes acontecem no Amazonas nos fins de semana em 2022 é de : '+ str(round(probAMfds2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Amazonas nos fins de semana em 2022 é de : 0.05%

# %%
AMfds2023 = len(leitura2023[leitura2023['uf'] == 'AM']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023[('dia_semana')] == 'domingo')])
probAMfds2023 = AMfds2023/ len(leitura2023)

print('A probabilidade dos acidentes acontecem no Amazonas nos fins de semana em 2023 é de : '+ str(round(probAMfds2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Amazonas nos fins de semana em 2023 é de : 0.14%

# %%
totalAMfds = (AMfds2019 + AMfds2020 + AMfds2021 + AMfds2022 + AMfds2023) / trafficIncidents
print(str(round(totalAMfds * 100, 2)) + '%')
# Out:
# 0.1%

# %% [markdown]
# **Probabilidade dos acidentes acontecem no AC nos fins de semana - sexta, sábado e domingo**

# %%
ACfds2019 = len(leitura2019[leitura2019['uf'] == 'AC']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probACfds2019 = ACfds2019/ len(leitura2019)

print('A probabilidade dos acidentes acontecem no Acre nos fins de semana em 2019 é de : '+ str(round(probACfds2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Acre nos fins de semana em 2019 é de : 0.01%

# %%
ACfds2020 = len(leitura2020[leitura2020['uf'] == 'AC']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probACfds2020 = ACfds2020/ len(leitura2020)

print('A probabilidade dos acidentes acontecem no Acre nos fins de semana em 2020 é de : '+ str(round(probACfds2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Acre nos fins de semana em 2020 é de : 0.05%

# %%
ACfds2021 = len(leitura2021[leitura2021['uf'] == 'AC']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probACfds2021 = ACfds2021/ len(leitura2021)

print('A probabilidade dos acidentes acontecem no Acre nos fins de semana em 2021 é de : '+ str(round(probACfds2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Acre nos fins de semana em 2021 é de : 0.01%

# %%
ACfds2022 = len(leitura2022[leitura2022['uf'] == 'AC']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probACfds2022 = ACfds2022/ len(leitura2022)

print('A probabilidade dos acidentes acontecem no Acre nos fins de semana em 2022 é de : '+ str(round(probACfds2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Acre nos fins de semana em 2022 é de : 0.25%

# %%
ACfds2023 = len(leitura2023[leitura2023['uf'] == 'AC']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probACfds2023 = ACfds2023/ len(leitura2023)

print('A probabilidade dos acidentes acontecem no Acre nos fins de semana em 2023 é de : '+ str(round(probACfds2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Acre nos fins de semana em 2023 é de : 0.3%

# %%
totalACfds = (ACfds2019 + ACfds2020 + ACfds2021 + ACfds2022 + ACfds2023) / trafficIncidents
print(str(round(totalACfds * 100, 2)) + '%')
# Out:
# 0.1%

# %% [markdown]
# **Probabilidade dos acidentes acontecem no AP nos fins de semana - sexta, sábado e domingo**

# %%
APfds2019 = len(leitura2019[leitura2019['uf'] == 'AP']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probAPfds2019 = APfds2019/ len(leitura2019)

print('A probabilidade dos acidentes acontecem no Amapá nos fins de semana em 2019 é de : '+ str(round(probAPfds2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Amapá nos fins de semana em 2019 é de : 0.19%

# %%
APfds2020 = len(leitura2020[leitura2020['uf'] == 'AP']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probAPfds2020 = APfds2020/ len(leitura2020)

print('A probabilidade dos acidentes acontecem no Amapá nos fins de semana em 2020 é de : '+ str(round(probAPfds2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Amapá nos fins de semana em 2020 é de : 0.21%

# %%
APfds2021 = len(leitura2021[leitura2021['uf'] == 'AP']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probAPfds2021 = APfds2021/ len(leitura2021)

print('A probabilidade dos acidentes acontecem no Amapá nos fins de semana em 2021 é de : '+ str(round(probAPfds2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Amapá nos fins de semana em 2021 é de : 0.0%

# %%
APfds2022 = len(leitura2022[leitura2022['uf'] == 'AP']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probAPfds2022 = APfds2022/ len(leitura2022)

print('A probabilidade dos acidentes acontecem no Amapá nos fins de semana em 2022 é de : '+ str(round(probAPfds2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Amapá nos fins de semana em 2022 é de : 0.25%

# %%
APfds2023 = len(leitura2023[leitura2023['uf'] == 'AP']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probAPfds2023 = APfds2023/ len(leitura2023)

print('A probabilidade dos acidentes acontecem no Amapá nos fins de semana em 2023 é de : '+ str(round(probAPfds2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Amapá nos fins de semana em 2023 é de : 0.21%

# %%
totalAPfds = (APfds2019 + APfds2020 + APfds2021 + APfds2022 + APfds2023) / trafficIncidents
print(str(round(totalAPfds * 100, 2)) + '%')
# Out:
# 0.17%

# %% [markdown]
# **Probabilidade dos acidentes acontecem no RO nos fins de semana - sexta, sábado e domingo**

# %%
ROfds2019 = len(leitura2019[leitura2019['uf'] == 'RO']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probROfds2019 = ROfds2019/ len(leitura2019)

print('A probabilidade dos acidentes acontecem no Rondônia nos fins de semana em 2019 é de : '+ str(round(probROfds2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Rondônia nos fins de semana em 2019 é de : 1.52%

# %%
ROfds2020 = len(leitura2020[leitura2020['uf'] == 'RO']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probROfds2020 = ROfds2020/ len(leitura2020)

print('A probabilidade dos acidentes acontecem no Rondônia nos fins de semana em 2020 é de : '+ str(round(probROfds2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Rondônia nos fins de semana em 2020 é de : 1.92%

# %%
ROfds2021 = len(leitura2021[leitura2021['uf'] == 'RO']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021[('dia_semana')] == 'domingo')])
probROfds2021 = ROfds2021/ len(leitura2021)

print('A probabilidade dos acidentes acontecem no Rondônia nos fins de semana em 2021 é de : '+ str(round(probROfds2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Rondônia nos fins de semana em 2021 é de : 0.0%

# %%
ROfds2022 = len(leitura2022[leitura2022['uf'] == 'RO']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022[('dia_semana')] == 'domingo')])
probROfds2022 = ROfds2022/ len(leitura2022)

print('A probabilidade dos acidentes acontecem no Rondônia nos fins de semana em 2022 é de : '+ str(round(probROfds2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Rondônia nos fins de semana em 2022 é de : 0.45%

# %%
ROfds2023 = len(leitura2023[leitura2023['uf'] == 'RO']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023[('dia_semana')] == 'domingo')])
probROfds2023 = ROfds2023/ len(leitura2023)

print('A probabilidade dos acidentes acontecem no Rondônia nos fins de semana em 2023 é de : '+ str(round(probROfds2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Rondônia nos fins de semana em 2023 é de : 0.12%

# %%
totalROfds = (ROfds2019 + ROfds2020 + ROfds2021 + ROfds2022 + ROfds2023) / trafficIncidents
print(str(round(totalROfds * 100, 2)) + '%')
# Out:
# 0.88%

# %% [markdown]
# **Probabilidade dos acidentes acontecem no RR nos fins de semana - sexta, sábado e domingo**

# %%
RRfds2019 = len(leitura2019[leitura2019['uf'] == 'RR']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probRRfds2019 = RRfds2019/ len(leitura2019)

print('A probabilidade dos acidentes acontecem no Roraima nos fins de semana em 2019 é de : '+ str(round(probRRfds2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Roraima nos fins de semana em 2019 é de : 0.3%

# %%
RRfds2020 = len(leitura2020[leitura2020['uf'] == 'RR']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020[('dia_semana')] == 'domingo')])
probRRfds2020 = RRfds2020/ len(leitura2020)

print('A probabilidade dos acidentes acontecem no Roraima nos fins de semana em 2020 é de : '+ str(round(probRRfds2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Roraima nos fins de semana em 2020 é de : 0.36%

# %%
RRfds2021 = len(leitura2021[leitura2021['uf'] == 'RR']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021[('dia_semana')] == 'domingo')])
probRRfds2021 = RRfds2021/ len(leitura2021)

print('A probabilidade dos acidentes acontecem no Roraima nos fins de semana em 2021 é de : '+ str(round(probRRfds2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Roraima nos fins de semana em 2021 é de : 0.01%

# %%
RRfds2022 = len(leitura2022[leitura2022['uf'] == 'RR']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022[('dia_semana')] == 'domingo')])
probRRfds2022 = RRfds2022/ len(leitura2022)

print('A probabilidade dos acidentes acontecem no Roraima nos fins de semana em 2022 é de : '+ str(round(probRRfds2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Roraima nos fins de semana em 2022 é de : 0.25%

# %%
RRfds2023 = len(leitura2023[leitura2023['uf'] == 'RR']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023[('dia_semana')] == 'domingo')])
probRRfds2023 = RRfds2023/ len(leitura2023)

print('A probabilidade dos acidentes acontecem no Roraima nos fins de semana em 2023 é de : '+ str(round(probRRfds2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Roraima nos fins de semana em 2023 é de : 0.24%

# %%
totalRRfds = (RRfds2019 + RRfds2020 + RRfds2021 + RRfds2022 + RRfds2023) / trafficIncidents
print(str(round(totalRRfds * 100, 2)) + '%')
# Out:
# 0.23%

# %% [markdown]
# **Probabilidade dos acidentes acontecem no TO nos fins de semana - sexta, sábado e domingo**

# %%
TOfds2019 = len(leitura2019[leitura2019['uf'] == 'TO']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probTOfds2019 = TOfds2019/ len(leitura2019)

print('A probabilidade dos acidentes acontecem no Tocantins nos fins de semana em 2019 é de : '+ str(round(probTOfds2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Tocantins nos fins de semana em 2019 é de : 0.01%

# %%
TOfds2020 = len(leitura2020[leitura2020['uf'] == 'TO']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probTOfds2020 = TOfds2020/ len(leitura2020)

print('A probabilidade dos acidentes acontecem no Tocantins nos fins de semana em 2020 é de : '+ str(round(probTOfds2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Tocantins nos fins de semana em 2020 é de : 0.91%

# %%
TOfds2021 = len(leitura2021[leitura2021['uf'] == 'TO']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021[('dia_semana')] == 'domingo')])
probTOfds2021 = TOfds2021/ len(leitura2021)

print('A probabilidade dos acidentes acontecem no Tocantins nos fins de semana em 2021 é de : '+ str(round(probTOfds2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Tocantins nos fins de semana em 2021 é de : 0.01%

# %%
TOfds2022 = len(leitura2022[leitura2022['uf'] == 'TO']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022[('dia_semana')] == 'domingo')])
probTOfds2022 = TOfds2022/ len(leitura2022)

print('A probabilidade dos acidentes acontecem no Tocantins nos fins de semana em 2022 é de : '+ str(round(probTOfds2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Tocantins nos fins de semana em 2022 é de : 0.06%

# %%
TOfds2023 = len(leitura2023[leitura2023['uf'] == 'TO']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probTOfds2023 = TOfds2023/ len(leitura2023)

print('A probabilidade dos acidentes acontecem no Tocantins nos fins de semana em 2023 é de : '+ str(round(probTOfds2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Tocantins nos fins de semana em 2023 é de : 0.13%

# %%
totalTOfds = (TOfds2019 + TOfds2020 + TOfds2021 + TOfds2022 + TOfds2023) / trafficIncidents
print(str(round(totalTOfds * 100, 2)) + '%')
# Out:
# 0.23%

# %% [markdown]
# **Probabilidade dos acidentes acontecem no MA nos fins de semana - sexta, sábado e domingo**

# %%
MAfds2019 = len(leitura2019[leitura2019['uf'] == 'MA']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probMAfds2019 = MAfds2019/ len(leitura2019)

print('A probabilidade dos acidentes acontecem no Maranhâo nos fins de semana em 2019 é de : '+ str(round(probMAfds2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Maranhâo nos fins de semana em 2019 é de : 1.53%

# %%
MAfds2020 = len(leitura2020[leitura2020['uf'] == 'MA']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probMAfds2020 = MAfds2020/ len(leitura2020)

print('A probabilidade dos acidentes acontecem no Maranhâo nos fins de semana em 2020 é de : '+ str(round(probMAfds2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Maranhâo nos fins de semana em 2020 é de : 1.82%

# %%
MAfds2021 = len(leitura2021[leitura2021['uf'] == 'MA']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probMAfds2021 = MAfds2021/ len(leitura2021)

print('A probabilidade dos acidentes acontecem no Maranhâo nos fins de semana em 2021 é de : '+ str(round(probMAfds2021*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Maranhâo nos fins de semana em 2021 é de : 0.0%

# %%
MAfds2022 = len(leitura2022[leitura2022['uf'] == 'MA']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probMAfds2022 = MAfds2022/ len(leitura2022)

print('A probabilidade dos acidentes acontecem no Maranhâo nos fins de semana em 2022 é de : '+ str(round(probMAfds2022*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Maranhâo nos fins de semana em 2022 é de : 0.06%

# %%
MAfds2023 = len(leitura2023[leitura2023['uf'] == 'MA']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probMAfds2023 = MAfds2023/ len(leitura2023)

print('A probabilidade dos acidentes acontecem no Maranhâo nos fins de semana em 2023 é de : '+ str(round(probMAfds2023*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Maranhâo nos fins de semana em 2023 é de : 0.0%

# %%
totalMAfds = (MAfds2019 + MAfds2020 + MAfds2021 + MAfds2022 + MAfds2023) / trafficIncidents
print(str(round(totalMAfds * 100, 2)) + '%')
# Out:
# 0.76%

# %% [markdown]
# **Probabilidade dos acidentes acontecem no PI nos fins de semana - sexta, sábado e domingo**

# %%
PIfds2019 = len(leitura2019[leitura2019['uf'] == 'PI']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probPIfds2019 = PIfds2019/ len(leitura2019)

print('A probabilidade dos acidentes acontecem no Piauí nos fins de semana em 2019 é de : '+ str(round(probPIfds2019*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Piauí nos fins de semana em 2019 é de : 1.61%

# %%
PIfds2020 = len(leitura2020[leitura2020['uf'] == 'PI']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probPIfds2020 = PIfds2020/ len(leitura2020)

print('A probabilidade dos acidentes acontecem no Piauí nos fins de semana em 2020 é de : '+ str(round(probPIfds2020*100,2)) + '%')
# Out:
# A probabilidade dos acidentes acontecem no Piauí nos fins de semana em 2020 é de : 1.86%

# %%
PIfds2021 = len(leitura2021[leitura2021['uf'] == 'PI']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probPIfds2021 = PIfds2021 / len(leitura2021)

print('A probabilidade dos acidentes acontecerem no Piauí nos fins de semana em 2021 é de: ' + str(round(probPIfds2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Piauí nos fins de semana em 2021 é de: 0.0%

# %%
PIfds2022 = len(leitura2022[leitura2022['uf'] == 'PI']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probPIfds2022 = PIfds2022 / len(leitura2022)

print('A probabilidade dos acidentes acontecerem no Piauí nos fins de semana em 2022 é de: ' + str(round(probPIfds2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Piauí nos fins de semana em 2022 é de: 0.01%

# %%
PIfds2023 = len(leitura2023[leitura2023['uf'] == 'PI']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probPIfds2023 = PIfds2023 / len(leitura2023)

print('A probabilidade dos acidentes acontecerem no Piauí nos fins de semana em 2023 é de: ' + str(round(probPIfds2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Piauí nos fins de semana em 2023 é de: 0.1%

# %%
totalPIfds = (PIfds2019 + PIfds2020 + PIfds2021 + PIfds2022 + PIfds2023) / trafficIncidents
print(str(round(totalPIfds * 100, 2)) + '%')
# Out:
# 0.79%

# %% [markdown]
# **Probabilidade dos acidentes acontecem no CE nos fins de semana - sexta, sábado e domingo**

# %%
CEfds2019 = len(leitura2019[leitura2019['uf'] == 'CE']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probCEfds2019 = CEfds2019 / len(leitura2019)

print('A probabilidade dos acidentes acontecerem no Ceará nos fins de semana em 2020 é de: ' + str(round(probCEfds2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Ceará nos fins de semana em 2020 é de: 0.78%

# %%
CEfds2020 = len(leitura2020[leitura2020['uf'] == 'CE']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probCEfds2020 = CEfds2020 / len(leitura2020)

print('A probabilidade dos acidentes acontecerem no Ceará nos fins de semana em 2020 é de: ' + str(round(probCEfds2020 * 100, 2)) + '%')

# %%
CEfds2021 = len(leitura2021[leitura2021['uf'] == 'CE']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probCEfds2021 = CEfds2021 / len(leitura2021)

print('A probabilidade dos acidentes acontecerem no Ceará nos fins de semana em 2021 é de: ' + str(round(probCEfds2021 * 100, 2)) + '%')

# %%
CEfds2022 = len(leitura2022[leitura2022['uf'] == 'CE']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probCEfds2022 = CEfds2022 / len(leitura2022)

print('A probabilidade dos acidentes acontecerem no Ceará nos fins de semana em 2022 é de: ' + str(round(probCEfds2022 * 100, 2)) + '%')

# %%
CEfds2023 = len(leitura2023[leitura2023['uf'] == 'CE']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probCEfds2023 = CEfds2023 / len(leitura2023)

print('A probabilidade dos acidentes acontecerem no Ceará nos fins de semana em 2023 é de: ' + str(round(probCEfds2023 * 100, 2)) + '%')

# %%
totalCEfds = (CEfds2019 + CEfds2020 + CEfds2021 + CEfds2022 + CEfds2023) / trafficIncidents
print(str(round(totalCEfds * 100, 2)) + '%')

# %% [markdown]
# **Probabilidade dos acidentes acontecem no RN nos fins de semana - sexta, sábado e domingo**

# %%
RNfds2019 = len(leitura2019[leitura2019['uf'] == 'RN']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probRNfds2019 = RNfds2019 / len(leitura2019)

print('A probabilidade dos acidentes acontecerem no Rio Grande do Norte nos fins de semana em 2019 é de: ' + str(round(probRNfds2019 * 100, 2)) + '%')

# %%
RNfds2020 = len(leitura2020[leitura2020['uf'] == 'RN']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probRNfds2020 = RNfds2020 / len(leitura2020)

print('A probabilidade dos acidentes acontecerem no Rio Grande do Norte nos fins de semana em 2020 é de: ' + str(round(probRNfds2020 * 100, 2)) + '%')

# %%
RNfds2021 = len(leitura2021[leitura2021['uf'] == 'RN']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probRNfds2021 = RNfds2021 / len(leitura2021)

print('A probabilidade dos acidentes acontecerem no Rio Grande do Norte nos fins de semana em 2021 é de: ' + str(round(probRNfds2021 * 100, 2)) + '%')

# %%
RNfds2022 = len(leitura2022[leitura2022['uf'] == 'RN']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probRNfds2022 = RNfds2022 / len(leitura2022)

print('A probabilidade dos acidentes acontecerem no Rio Grande do Norte nos fins de semana em 2022 é de: ' + str(round(probRNfds2022 * 100, 2)) + '%')

# %%
RNfds2023 = len(leitura2023[leitura2023['uf'] == 'RN']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probRNfds2023 = RNfds2023 / len(leitura2023)

print('A probabilidade dos acidentes acontecerem no Rio Grande do Norte nos fins de semana em 2023 é de: ' + str(round(probRNfds2023 * 100, 2)) + '%')

# %%
totalRNfds = (RNfds2019 + RNfds2020 + RNfds2021 + RNfds2022 + RNfds2023) / trafficIncidents
print(str(round(totalRNfds * 100, 2)) + '%')

# %% [markdown]
# **Probabilidade dos acidentes acontecem no PB nos fins de semana - sexta, sábado e domingo**

# %%
PBfds2019 = len(leitura2019[leitura2019['uf'] == 'PB']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probPBfds2019 = PBfds2019 / len(leitura2019)

print('A probabilidade dos acidentes acontecerem na Paraíba nos fins de semana em 2019 é de: ' + str(round(probPBfds2019 * 100, 2)) + '%')

# %%
PBfds2020 = len(leitura2020[leitura2020['uf'] == 'PB']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probPBfds2020 = PBfds2020 / len(leitura2020)

print('A probabilidade dos acidentes acontecerem na Paraíba nos fins de semana em 2020 é de: ' + str(round(probPBfds2020 * 100, 2)) + '%')

# %%
PBfds2021 = len(leitura2021[leitura2021['uf'] == 'PB']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probPBfds2021 = PBfds2021 / len(leitura2021)

print('A probabilidade dos acidentes acontecerem na Paraíba nos fins de semana em 2021 é de: ' + str(round(probPBfds2021 * 100, 2)) + '%')

# %%
PBfds2022 = len(leitura2022[leitura2022['uf'] == 'PB']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probPBfds2022 = PBfds2022 / len(leitura2022)

print('A probabilidade dos acidentes acontecerem na Paraíba nos fins de semana em 2022 é de: ' + str(round(probPBfds2022 * 100, 2)) + '%')

# %%
PBfds2023 = len(leitura2023[leitura2023['uf'] == 'PB']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probPBfds2023 = PBfds2023 / len(leitura2023)

print('A probabilidade dos acidentes acontecerem na Paraíba nos fins de semana em 2023 é de: ' + str(round(probPBfds2023 * 100, 2)) + '%')

# %%
totalPBfds = (PBfds2019 + PBfds2020 + PBfds2021 + PBfds2022 + PBfds2023) / trafficIncidents
print(str(round(totalPBfds * 100, 2)) + '%')

# %% [markdown]
# **Probabilidade dos acidentes acontecem no AL nos fins de semana - sexta, sábado e domingo**

# %%
ALfds2019 = len(leitura2019[leitura2019['uf'] == 'AL']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probALfds2019 = ALfds2019 / len(leitura2019)

print('A probabilidade dos acidentes acontecerem em Alagoas nos fins de semana em 2019 é de: ' + str(round(probALfds2019 * 100, 2)) + '%')

# %%
ALfds2020 = len(leitura2020[leitura2020['uf'] == 'AL']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probALfds2020 = ALfds2020 / len(leitura2020)

print('A probabilidade dos acidentes acontecerem em Alagoas nos fins de semana em 2020 é de: ' + str(round(probALfds2020 * 100, 2)) + '%')

# %%
ALfds2021 = len(leitura2021[leitura2021['uf'] == 'AL']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probALfds2021 = ALfds2021 / len(leitura2021)

print('A probabilidade dos acidentes acontecerem em Alagoas nos fins de semana em 2021 é de: ' + str(round(probALfds2021 * 100, 2)) + '%')

# %%
ALfds2022 = len(leitura2022[leitura2022['uf'] == 'AL']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probALfds2022 = ALfds2022 / len(leitura2022)

print('A probabilidade dos acidentes acontecerem em Alagoas nos fins de semana em 2022 é de: ' + str(round(probALfds2022 * 100, 2)) + '%')

# %%
ALfds2023 = len(leitura2023[leitura2023['uf'] == 'AL']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probALfds2023 = ALfds2023 / len(leitura2023)

print('A probabilidade dos acidentes acontecerem em Alagoas nos fins de semana em 2023 é de: ' + str(round(probALfds2023 * 100, 2)) + '%')

# %%
totalALfds = (ALfds2019 + ALfds2020 + ALfds2021 + ALfds2022 + ALfds2023) / trafficIncidents
print(str(round(totalALfds * 100, 2)) + '%')

# %% [markdown]
# **Probabilidade dos acidentes acontecem no SE nos fins de semana - sexta, sábado e domingo**

# %%
SEfds2019 = len(leitura2019[leitura2019['uf'] == 'SE']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probSEfds2019 = SEfds2019 / len(leitura2019)

print('A probabilidade dos acidentes acontecerem em Sergipe nos fins de semana em 2019 é de: ' + str(round(probSEfds2019 * 100, 2)) + '%')

# %%
SEfds2020 = len(leitura2020[leitura2020['uf'] == 'SE']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probSEfds2020 = SEfds2020 / len(leitura2020)

print('A probabilidade dos acidentes acontecerem em Sergipe nos fins de semana em 2020 é de: ' + str(round(probSEfds2020 * 100, 2)) + '%')

# %%
SEfds2021 = len(leitura2021[leitura2021['uf'] == 'SE']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probSEfds2021 = SEfds2021 / len(leitura2021)

print('A probabilidade dos acidentes acontecerem em Sergipe nos fins de semana em 2021 é de: ' + str(round(probSEfds2021 * 100, 2)) + '%')

# %%
SEfds2022 = len(leitura2022[leitura2022['uf'] == 'SE']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probSEfds2022 = SEfds2022 / len(leitura2022)

print('A probabilidade dos acidentes acontecerem em Sergipe nos fins de semana em 2022 é de: ' + str(round(probSEfds2022 * 100, 2)) + '%')

# %%
SEfds2023 = len(leitura2023[leitura2023['uf'] == 'SE']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probSEfds2023 = SEfds2023 / len(leitura2023)

print('A probabilidade dos acidentes acontecerem em Sergipe nos fins de semana em 2023 é de: ' + str(round(probSEfds2023 * 100, 2)) + '%')

# %%
totalSEfds = (SEfds2019 + SEfds2020 + SEfds2021 + SEfds2022 + SEfds2023) / trafficIncidents
print(str(round(totalSEfds * 100, 2)) + '%')
# Out:
# 0.36%

# %% [markdown]
# **Probabilidade dos acidentes acontecem no BA nos fins de semana - sexta, sábado e domingo**

# %%
BAfds2019 = len(leitura2019[leitura2019['uf'] == 'BA']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probBAfds2019 = BAfds2019 / len(leitura2019)

print('A probabilidade dos acidentes acontecerem na Bahia nos fins de semana em 2019 é de: ' + str(round(probBAfds2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Bahia nos fins de semana em 2019 é de: 1.73%

# %%
BAfds2020 = len(leitura2020[leitura2020['uf'] == 'BA']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probBAfds2020 = BAfds2020 / len(leitura2020)

print('A probabilidade dos acidentes acontecerem na Bahia nos fins de semana em 2020 é de: ' + str(round(probBAfds2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Bahia nos fins de semana em 2020 é de: 5.03%

# %%
BAfds2021 = len(leitura2021[leitura2021['uf'] == 'BA']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probBAfds2021 = BAfds2021 / len(leitura2021)

print('A probabilidade dos acidentes acontecerem na Bahia nos fins de semana em 2021 é de: ' + str(round(probBAfds2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Bahia nos fins de semana em 2021 é de: 0.0%

# %%
BAfds2022 = len(leitura2022[leitura2022['uf'] == 'BA']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probBAfds2022 = BAfds2022 / len(leitura2022)

print('A probabilidade dos acidentes acontecerem na Bahia nos fins de semana em 2022 é de: ' + str(round(probBAfds2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Bahia nos fins de semana em 2022 é de: 0.45%

# %%
BAfds2023 = len(leitura2023[leitura2023['uf'] == 'BA']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probBAfds2023 = BAfds2023 / len(leitura2023)

print('A probabilidade dos acidentes acontecerem na Bahia nos fins de semana em 2023 é de: ' + str(round(probBAfds2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Bahia nos fins de semana em 2023 é de: 0.23%

# %%
totalBAfds = (BAfds2019 + BAfds2020 + BAfds2021 + BAfds2022 + BAfds2023) / trafficIncidents
print(str(round(totalBAfds * 100, 2)) + '%')
# Out:
# 1.62%

# %% [markdown]
# **Probabilidade dos acidentes acontecem no GO nos fins de semana - sexta, sábado e domingo**

# %%
GOfds2019 = len(leitura2019[leitura2019['uf'] == 'GO']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probGOfds2019 = GOfds2019 / len(leitura2019)

print('A probabilidade dos acidentes acontecerem em Goiás nos fins de semana em 2019 é de: ' + str(round(probGOfds2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem em Goiás nos fins de semana em 2019 é de: 1.54%

# %%
GOfds2020 = len(leitura2020[leitura2020['uf'] == 'GO']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probGOfds2020 = GOfds2020 / len(leitura2020)

print('A probabilidade dos acidentes acontecerem em Goiás nos fins de semana em 2020 é de: ' + str(round(probGOfds2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem em Goiás nos fins de semana em 2020 é de: 5.03%

# %%
GOfds2021 = len(leitura2021[leitura2021['uf'] == 'GO']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probGOfds2021 = GOfds2021 / len(leitura2021)

print('A probabilidade dos acidentes acontecerem em Goiás nos fins de semana em 2021 é de: ' + str(round(probGOfds2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem em Goiás nos fins de semana em 2021 é de: 0.01%

# %%
GOfds2022 = len(leitura2022[leitura2022['uf'] == 'GO']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probGOfds2022 = GOfds2022 / len(leitura2022)

print('A probabilidade dos acidentes acontecerem em Goiás nos fins de semana em 2022 é de: ' + str(round(probGOfds2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem em Goiás nos fins de semana em 2022 é de: 0.06%

# %%
GOfds2023 = len(leitura2023[leitura2023['uf'] == 'GO']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probGOfds2023 = GOfds2023 / len(leitura2023)

print('A probabilidade dos acidentes acontecerem em Goiás nos fins de semana em 2023 é de: ' + str(round(probGOfds2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem em Goiás nos fins de semana em 2023 é de: 0.23%

# %%
totalGOfds = (GOfds2019 + GOfds2020 + GOfds2021 + GOfds2022 + GOfds2023) / trafficIncidents
print(str(round(totalGOfds * 100, 2)) + '%')
# Out:
# 1.49%

# %% [markdown]
# **Probabilidade dos acidentes acontecem no MT nos fins de semana - sexta, sábado e domingo**

# %%
MTfds2019 = len(leitura2019[leitura2019['uf'] == 'MT']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probMTfds2019 = MTfds2019 / len(leitura2019)

print('A probabilidade dos acidentes acontecerem em Mato Grosso nos fins de semana em 2019 é de: ' + str(round(probMTfds2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem em Mato Grosso nos fins de semana em 2019 é de: 0.11%

# %%
MTfds2020 = len(leitura2020[leitura2020['uf'] == 'MT']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probMTfds2020 = MTfds2020 / len(leitura2020)

print('A probabilidade dos acidentes acontecerem em Mato Grosso nos fins de semana em 2020 é de: ' + str(round(probMTfds2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem em Mato Grosso nos fins de semana em 2020 é de: 3.43%

# %%
MTfds2021 = len(leitura2021[leitura2021['uf'] == 'MT']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probMTfds2021 = MTfds2021 / len(leitura2021)

print('A probabilidade dos acidentes acontecerem em Mato Grosso nos fins de semana em 2021 é de: ' + str(round(probMTfds2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem em Mato Grosso nos fins de semana em 2021 é de: 0.0%

# %%
MTfds2022 = len(leitura2022[leitura2022['uf'] == 'MT']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probMTfds2022 = MTfds2022 / len(leitura2022)

print('A probabilidade dos acidentes acontecerem em Mato Grosso nos fins de semana em 2022 é de: ' + str(round(probMTfds2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem em Mato Grosso nos fins de semana em 2022 é de: 0.06%

# %%
MTfds2023 = len(leitura2023[leitura2023['uf'] == 'MT']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probMTfds2023 = MTfds2023 / len(leitura2023)

print('A probabilidade dos acidentes acontecerem em Mato Grosso nos fins de semana em 2023 é de: ' + str(round(probMTfds2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem em Mato Grosso nos fins de semana em 2023 é de: 0.1%

# %%
totalMTfds = (MTfds2019 + MTfds2020 + MTfds2021 + MTfds2022 + MTfds2023) / trafficIncidents
print(str(round(totalMTfds * 100, 2)) + '%')
# Out:
# 0.8%

# %% [markdown]
# **Probabilidade dos acidentes acontecem no MS nos fins de semana - sexta, sábado e domingo**

# %%
MSfds2019 = len(leitura2019[leitura2019['uf'] == 'MS']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probMSfds2019 = MSfds2019 / len(leitura2019)

print('A probabilidade dos acidentes acontecerem no Mato Grosso do Sul nos fins de semana em 2019 é de: ' + str(round(probMSfds2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Mato Grosso do Sul nos fins de semana em 2019 é de: 1.72%

# %%
MSfds2020 = len(leitura2020[leitura2020['uf'] == 'MS']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probMSfds2020 = MSfds2020 / len(leitura2020)

print('A probabilidade dos acidentes acontecerem no Mato Grosso do Sul nos fins de semana em 2020 é de: ' + str(round(probMSfds2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Mato Grosso do Sul nos fins de semana em 2020 é de: 2.42%

# %%
MSfds2021 = len(leitura2021[leitura2021['uf'] == 'MS']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probMSfds2021 = MSfds2021 / len(leitura2021)

print('A probabilidade dos acidentes acontecerem no Mato Grosso do Sul nos fins de semana em 2021 é de: ' + str(round(probMSfds2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Mato Grosso do Sul nos fins de semana em 2021 é de: 0.79%

# %%
MSfds2022 = len(leitura2022[leitura2022['uf'] == 'MS']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probMSfds2022 = MSfds2022 / len(leitura2022)

print('A probabilidade dos acidentes acontecerem no Mato Grosso do Sul nos fins de semana em 2022 é de: ' + str(round(probMSfds2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Mato Grosso do Sul nos fins de semana em 2022 é de: 0.05%

# %%
MSfds2023 = len(leitura2023[leitura2023['uf'] == 'MS']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probMSfds2023 = MSfds2023 / len(leitura2023)

print('A probabilidade dos acidentes acontecerem no Mato Grosso do Sul nos fins de semana em 2023 é de: ' + str(round(probMSfds2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Mato Grosso do Sul nos fins de semana em 2023 é de: 0.13%

# %%
totalMSfds = (MSfds2019 + MSfds2020 + MSfds2021 + MSfds2022 + MSfds2023) / trafficIncidents
print(str(round(totalMSfds * 100, 2)) + '%')
# Out:
# 1.12%

# %% [markdown]
# **Probabilidade dos acidentes acontecem no DF nos fins de semana - sexta, sábado e domingo**

# %%
DFfds2019 = len(leitura2019[leitura2019['uf'] == 'DF']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probDFfds2019 = DFfds2019 / len(leitura2019)

print('A probabilidade dos acidentes acontecerem no Distrito Federal nos fins de semana em 2019 é de: ' + str(round(probDFfds2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Distrito Federal nos fins de semana em 2019 é de: 1.61%

# %%
DFfds2020 = len(leitura2020[leitura2020['uf'] == 'DF']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probDFfds2020 = DFfds2020 / len(leitura2020)

print('A probabilidade dos acidentes acontecerem no Distrito Federal nos fins de semana em 2020 é de: ' + str(round(probDFfds2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Distrito Federal nos fins de semana em 2020 é de: 1.61%

# %%
DFfds2021 = len(leitura2021[leitura2021['uf'] == 'DF']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probDFfds2021 = DFfds2021 / len(leitura2021)

print('A probabilidade dos acidentes acontecerem no Distrito Federal nos fins de semana em 2021 é de: ' + str(round(probDFfds2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Distrito Federal nos fins de semana em 2021 é de: 0.8%

# %%
DFfds2022 = len(leitura2022[leitura2022['uf'] == 'DF']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probDFfds2022 = DFfds2022 / len(leitura2022)

print('A probabilidade dos acidentes acontecerem no Distrito Federal nos fins de semana em 2022 é de: ' + str(round(probDFfds2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Distrito Federal nos fins de semana em 2022 é de: 0.61%

# %%
DFfds2023 = len(leitura2023[leitura2023['uf'] == 'DF']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probDFfds2023 = DFfds2023 / len(leitura2023)

print('A probabilidade dos acidentes acontecerem no Distrito Federal nos fins de semana em 2023 é de: ' + str(round(probDFfds2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Distrito Federal nos fins de semana em 2023 é de: 0.2%

# %%
totalDFfds = (DFfds2019 + DFfds2020 + DFfds2021 + DFfds2022 + DFfds2023) / trafficIncidents
print(str(round(totalDFfds * 100, 2)) + '%')
# Out:
# 1.05%

# %% [markdown]
# **Probabilidade dos acidentes acontecem no ES nos fins de semana - sexta, sábado e domingo**

# %%
ESfds2019 = len(leitura2019[leitura2019['uf'] == 'ES']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probESfds2019 = ESfds2019 / len(leitura2019)

print('A probabilidade dos acidentes acontecerem no Espírito Santo nos fins de semana em 2019 é de: ' + str(round(probESfds2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Espírito Santo nos fins de semana em 2019 é de: 0.02%

# %%
ESfds2020 = len(leitura2020[leitura2020['uf'] == 'ES']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probESfds2020 = ESfds2020 / len(leitura2020)

print('A probabilidade dos acidentes acontecerem no Espírito Santo nos fins de semana em 2020 é de: ' + str(round(probESfds2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Espírito Santo nos fins de semana em 2020 é de: 3.58%

# %%
ESfds2021 = len(leitura2021[leitura2021['uf'] == 'ES']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probESfds2021 = ESfds2021 / len(leitura2021)

print('A probabilidade dos acidentes acontecerem no Espírito Santo nos fins de semana em 2021 é de: ' + str(round(probESfds2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Espírito Santo nos fins de semana em 2021 é de: 0.01%

# %%
ESfds2022 = len(leitura2022[leitura2022['uf'] == 'ES']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probESfds2022 = ESfds2022 / len(leitura2022)

print('A probabilidade dos acidentes acontecerem no Espírito Santo nos fins de semana em 2022 é de: ' + str(round(probESfds2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Espírito Santo nos fins de semana em 2022 é de: 0.25%

# %%
ESfds2023 = len(leitura2023[leitura2023['uf'] == 'ES']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probESfds2023 = ESfds2023 / len(leitura2023)

print('A probabilidade dos acidentes acontecerem no Espírito Santo nos fins de semana em 2023 é de: ' + str(round(probESfds2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Espírito Santo nos fins de semana em 2023 é de: 0.2%

# %%
totalESfds = (ESfds2019 + ESfds2020 + ESfds2021 + ESfds2022 + ESfds2023) / trafficIncidents
print(str(round(totalESfds * 100, 2)) + '%')
# Out:
# 0.86%

# %% [markdown]
# **Probabilidade dos acidentes acontecem no PR nos fins de semana - sexta, sábado e domingo**

# %%
PRfds2019 = len(leitura2019[leitura2019['uf'] == 'PR']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probPRfds2019 = PRfds2019 / len(leitura2019)

print('A probabilidade dos acidentes acontecerem no Paraná nos fins de semana em 2019 é de: ' + str(round(probPRfds2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Paraná nos fins de semana em 2019 é de: 7.59%

# %%
PRfds2020 = len(leitura2020[leitura2020['uf'] == 'PR']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probPRfds2020 = PRfds2020 / len(leitura2020)

print('A probabilidade dos acidentes acontecerem no Paraná nos fins de semana em 2020 é de: ' + str(round(probPRfds2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Paraná nos fins de semana em 2020 é de: 4.84%

# %%
PRfds2021 = len(leitura2021[leitura2021['uf'] == 'PR']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probPRfds2021 = PRfds2021 / len(leitura2021)

print('A probabilidade dos acidentes acontecerem no Paraná nos fins de semana em 2021 é de: ' + str(round(probPRfds2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Paraná nos fins de semana em 2021 é de: 6.35%

# %%
PRfds2022 = len(leitura2022[leitura2022['uf'] == 'PR']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probPRfds2022 = PRfds2022 / len(leitura2022)

print('A probabilidade dos acidentes acontecerem no Paraná nos fins de semana em 2022 é de: ' + str(round(probPRfds2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Paraná nos fins de semana em 2022 é de: 6.54%

# %%
PRfds2023 = len(leitura2023[leitura2023['uf'] == 'PR']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probPRfds2023 = PRfds2023 / len(leitura2023)

print('A probabilidade dos acidentes acontecerem no Paraná nos fins de semana em 2023 é de: ' + str(round(probPRfds2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Paraná nos fins de semana em 2023 é de: 6.62%

# %%
totalPRfds = (PRfds2019 + PRfds2020 + PRfds2021 + PRfds2022 + PRfds2023) / trafficIncidents
print(str(round(totalPRfds * 100, 2)) + '%')
# Out:
# 6.38%

# %% [markdown]
# **Probabilidade dos acidentes acontecem no RS nos fins de semana - sexta, sábado e domingo**

# %%
RSfds2019 = len(leitura2019[leitura2019['uf'] == 'RS']) & len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') | (leitura2019[('dia_semana')] == 'sábado') | (leitura2019 [('dia_semana')] == 'domingo')])
probRSfds2019 = RSfds2019 / len(leitura2019)

print('A probabilidade dos acidentes acontecerem no Rio Grande do Sul nos fins de semana em 2019 é de: ' + str(round(probRSfds2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Rio Grande do Sul nos fins de semana em 2019 é de: 6.36%

# %%
RSfds2020 = len(leitura2020[leitura2020['uf'] == 'RS']) & len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') | (leitura2020[('dia_semana')] == 'sábado') | (leitura2020 [('dia_semana')] == 'domingo')])
probRSfds2020 = RSfds2020 / len(leitura2020)

print('A probabilidade dos acidentes acontecerem no Rio Grande do Sul nos fins de semana em 2020 é de: ' + str(round(probRSfds2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Rio Grande do Sul nos fins de semana em 2020 é de: 0.1%

# %%
RSfds2021 = len(leitura2021[leitura2021['uf'] == 'RS']) & len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') | (leitura2021[('dia_semana')] == 'sábado') | (leitura2021 [('dia_semana')] == 'domingo')])
probRSfds2021 = RSfds2021 / len(leitura2021)

print('A probabilidade dos acidentes acontecerem no Rio Grande do Sul nos fins de semana em 2021 é de: ' + str(round(probRSfds2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Rio Grande do Sul nos fins de semana em 2021 é de: 6.35%

# %%
RSfds2022 = len(leitura2022[leitura2022['uf'] == 'RS']) & len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') | (leitura2022[('dia_semana')] == 'sábado') | (leitura2022 [('dia_semana')] == 'domingo')])
probRSfds2022 = RSfds2022 / len(leitura2022)

print('A probabilidade dos acidentes acontecerem no Rio Grande do Sul nos fins de semana em 2022 é de: ' + str(round(probRSfds2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Rio Grande do Sul nos fins de semana em 2022 é de: 6.74%

# %%
RSfds2023 = len(leitura2023[leitura2023['uf'] == 'RS']) & len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') | (leitura2023[('dia_semana')] == 'sábado') | (leitura2023 [('dia_semana')] == 'domingo')])
probRSfds2023 = RSfds2023 / len(leitura2023)

print('A probabilidade dos acidentes acontecerem no Rio Grande do Sul nos fins de semana em 2023 é de: ' + str(round(probRSfds2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem no Rio Grande do Sul nos fins de semana em 2023 é de: 6.63%

# %%
totalRSfds = (RSfds2019 + RSfds2020 + RSfds2021 + RSfds2022 + RSfds2023) / trafficIncidents
print(str(round(totalRSfds * 100, 2)) + '%')
# Out:
# 5.11%

# %% [markdown]
# **Região Norte:**

# %%
totalRegNorteFds2019 = ((AMfds2019 + RRfds2022 + APfds2019 + PAfds2019 + TOfds2019 + ROfds2019 + ACfds2019) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Norte nos fins de semana em 2019 é: " + str(round(totalRegNorteFds2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Norte nos fins de semana em 2019 é: 0.48%

# %%
totalRegNorteFds2020 = ((AMfds2020 + RRfds2022 + APfds2020 + PAfds2020 + TOfds2020 + ROfds2020 + ACfds2020) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Norte nos fins de semana em 2020 é: " + str(round(totalRegNorteFds2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Norte nos fins de semana em 2020 é: 1.01%

# %%
totalRegNorteFds2021 = ((AMfds2021 + RRfds2022 + APfds2021 + PAfds2021 + TOfds2021 + ROfds2021 + ACfds2021) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Norte nos fins de semana em 2021 é: " + str(round(totalRegNorteFds2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Norte nos fins de semana em 2021 é: 0.24%

# %%
totalRegNorteFds2022 = ((AMfds2022 + RRfds2022 + APfds2022 + PAfds2022 + TOfds2022 + ROfds2022 + ACfds2022) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Norte nos fins de semana em 2022 é: " + str(round(totalRegNorteFds2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Norte nos fins de semana em 2022 é: 0.39%

# %%
totalRegNorteFds2023 = ((AMfds2023 + RRfds2023 + APfds2023 + PAfds2023 + TOfds2023 + ROfds2023 + ACfds2023) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Norte nos fins de semana em 2023 é: " + str(round(totalRegNorteFds2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Norte nos fins de semana em 2023 é: 0.14%

# %% [markdown]
# **Região Nordeste:**

# %%
totalRegNordesteFds2023 = ((ALfds2023 + BAfds2023 + CEfds2023 + PBfds2023 + PEfds2023 + PIfds2023 + SEfds2023 + RNfds2023) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Nordeste nos fins de semana em 2023 é: " + str(round(totalRegNordesteFds2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Nordeste nos fins de semana em 2023 é: 0.1%

# %%
totalRegNordesteFds2022 = ((ALfds2022 + BAfds2022 + CEfds2022 + PBfds2022 + PEfds2022 + PIfds2022 + SEfds2022 + RNfds2022) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Nordeste nos fins de semana em 2022 é: " + str(round(totalRegNordesteFds2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Nordeste nos fins de semana em 2022 é: 0.61%

# %%
totalRegNordesteFds2021 = ((ALfds2021 + BAfds2021 + CEfds2021 + PBfds2021 + PEfds2021 + PIfds2021 + SEfds2021 + RNfds2021) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Nordeste nos fins de semana em 2021 é: " + str(round(totalRegNordesteFds2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Nordeste nos fins de semana em 2021 é: 0.36%

# %%
totalRegNordesteFds2020 = ((ALfds2020 + BAfds2020 + CEfds2020 + PBfds2020 + PEfds2020 + PIfds2020 + SEfds2020 + RNfds2020) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Nordeste nos fins de semana em 2020 é: " + str(round(totalRegNordesteFds2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Nordeste nos fins de semana em 2020 é: 4.05%

# %%
totalRegNordesteFds2019 = ((ALfds2019 + BAfds2019 + CEfds2019 + PBfds2019 + PEfds2019 + PIfds2019 + SEfds2019 + RNfds2019) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Nordeste nos fins de semana em 2019 é: " + str(round(totalRegNordesteFds2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Nordeste nos fins de semana em 2019 é: 1.79%

# %% [markdown]
# **Região Centro-Oeste:**

# %%
totalRegNordesteFds2019 = ((MSfds2019 + DFfds2019 + MTfds2019 + GOfds2019 ) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Centro-Oeste nos fins de semana em 2019 é: " + str(round(totalRegNordesteFds2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Centro-Oeste nos fins de semana em 2019 é: 1.15%

# %%
totalRegCentroOesteFds2020 = ((MSfds2020 + DFfds2020 + MTfds2020 + GOfds2020) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Centro-Oeste nos fins de semana em 2020 é: " + str(round(totalRegCentroOesteFds2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Centro-Oeste nos fins de semana em 2020 é: 2.71%

# %%
totalRegCentroOesteFds2021 = ((MSfds2021 + DFfds2021 + MTfds2021 + GOfds2021) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Centro-Oeste nos fins de semana em 2021 é: " + str(round(totalRegCentroOesteFds2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Centro-Oeste nos fins de semana em 2021 é: 0.35%

# %%
totalRegCentroOesteFds2022 = ((MSfds2022 + DFfds2022 + MTfds2022 + GOfds2022) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Centro-Oeste nos fins de semana em 2022 é: " + str(round(totalRegCentroOesteFds2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Centro-Oeste nos fins de semana em 2022 é: 0.17%

# %%
totalRegCentroOesteFds2023 = ((MSfds2023 + DFfds2023 + MTfds2023 + GOfds2023) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Centro-Oeste nos fins de semana em 2023 é: " + str(round(totalRegCentroOesteFds2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Centro-Oeste nos fins de semana em 2023 é: 0.07%

# %% [markdown]
# **Região Suldeste:**

# %%
totalRegCentroOesteFds2023 = ((ESfds2023 + MGfds2023 + RJfds2023 + SPfds2023) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Centro-Oeste nos fins de semana em 2023 é: " + str(round(totalRegCentroOesteFds2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Centro-Oeste nos fins de semana em 2023 é: 1.48%

# %%
totalRegSudesteFds2022 = ((ESfds2022 + MGfds2022 + RJfds2022 + SPfds2022) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Sudeste nos fins de semana em 2022 é: " + str(round(totalRegSudesteFds2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Sudeste nos fins de semana em 2022 é: 2.97%

# %%
totalRegSudesteFds2021 = ((ESfds2021 + MGfds2021 + RJfds2021 + SPfds2021) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Sudeste nos fins de semana em 2021 é: " + str(round(totalRegSudesteFds2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Sudeste nos fins de semana em 2021 é: 2.8%

# %%
totalRegSudesteFds2020 = ((ESfds2020 + MGfds2020 + RJfds2020 + SPfds2020) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Sudeste nos fins de semana em 2020 é: " + str(round(totalRegSudesteFds2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Sudeste nos fins de semana em 2020 é: 2.17%

# %%
totalRegSudesteFds2019 = ((ESfds2019 + MGfds2019 + RJfds2019 + SPfds2019) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Sudeste nos fins de semana em 2019 é: " + str(round(totalRegSudesteFds2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Sudeste nos fins de semana em 2019 é: 5.8%

# %% [markdown]
# **Região Sul:**

# %%
totalRegSudesteFds2019 = ((PRfds2019 + SCfds2019 + RSfds2019) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Sudeste nos fins de semana em 2019 é: " + str(round(totalRegSudesteFds2019 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Sudeste nos fins de semana em 2019 é: 3.29%

# %%
totalRegSulFds2020 = ((PRfds2020 + SCfds2020 + RSfds2020) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Sul nos fins de semana em 2020 é: " + str(round(totalRegSulFds2020 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Sul nos fins de semana em 2020 é: 2.13%

# %%
totalRegSulFds2021 = ((PRfds2021 + SCfds2021 + RSfds2021) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Sul nos fins de semana em 2021 é: " + str(round(totalRegSulFds2021 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Sul nos fins de semana em 2021 é: 4.38%

# %%
totalRegSulFds2022 = ((PRfds2022 + SCfds2022 + RSfds2022) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Sul nos fins de semana em 2022 é: " + str(round(totalRegSulFds2022 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Sul nos fins de semana em 2022 é: 4.47%

# %%
totalRegSulFds2023 = ((PRfds2023 + SCfds2023 + RSfds2023) / trafficIncidents)
print("A probabilidade dos acidentes acontecerem na Região Sul nos fins de semana em 2023 é: " + str(round(totalRegSulFds2023 * 100, 2)) + '%')
# Out:
# A probabilidade dos acidentes acontecerem na Região Sul nos fins de semana em 2023 é: 2.21%

# %% [markdown]
# **Conclusão:**

# %% [markdown]
# # **Probabilidade com Complemento**

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em SP**

# %%
probNaoChuvaSP2019 = probSP2019 - probSPChuva2019
print("A probabilidade dos acidentes ocorrem no estado de São Paulo sem chuva em 2019 é: " + str(round(probNaoChuvaSP2019*100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrem no estado de São Paulo sem chuva em 2019 é: 0.39%

# %%
probNaoChuvaSP2020 = probSP2020 - probSPChuva2020
print("A probabilidade dos acidentes ocorrem no estado de São Paulo sem chuva em 2020 é: " + str(round(probNaoChuvaSP2020*100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrem no estado de São Paulo sem chuva em 2020 é: 2.12%

# %%
probNaoChuvaSP2021 = probSP2021 - probSPChuva2021
print("A probabilidade dos acidentes ocorrem no estado de São Paulo sem chuva em 2021 é: " + str(round(probNaoChuvaSP2021*100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrem no estado de São Paulo sem chuva em 2021 é: 0.31%

# %%
probNaoChuvaSP2022 = probSP2022 - probSPChuva2022
print("A probabilidade dos acidentes ocorrem no estado de São Paulo sem chuva em 2022 é: " + str(round(probNaoChuvaSP2022*100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrem no estado de São Paulo sem chuva em 2022 é: 0.05%

# %%
probNaoChuvaSP2023 = probSP2023 - probSPChuva2023
print("A probabilidade dos acidentes ocorrem no estado de São Paulo sem chuva em 2023 é: " + str(round(probNaoChuvaSP2023*100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrem no estado de São Paulo sem chuva em 2023 é: 0.22%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em MG**

# %%
probNaoChuvaMG2019 = probMG2019 - probMGChuva2019
print("A probabilidade dos acidentes ocorrem no estado de Minas Gerais sem chuva em 2019 é: " + str(round(probNaoChuvaMG2019*100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrem no estado de Minas Gerais sem chuva em 2019 é: 12.88%

# %%
probNaoChuvaMG2020 = probMG2020 - probMGChuva2020
print("A probabilidade dos acidentes ocorrem no estado de Minas Gerais sem chuva em 2020 é: " + str(round(probNaoChuvaMG2020*100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrem no estado de Minas Gerais sem chuva em 2020 é: 12.94%

# %%
probNaoChuvaMG2021 = probMG2021 - probMGChuva2021
print("A probabilidade dos acidentes ocorrem no estado de Minas Gerais sem chuva em 2021 é: " + str(round(probNaoChuvaMG2021*100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrem no estado de Minas Gerais sem chuva em 2021 é: 12.89%

# %%
probNaoChuvaMG2022 = probMG2022 - probMGChuva2022
print("A probabilidade dos acidentes ocorrem no estado de Minas Gerais sem chuva em 2022 é: " + str(round(probNaoChuvaMG2022*100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrem no estado de Minas Gerais sem chuva em 2022 é: 12.74%

# %%
probNaoChuvaMG2023 = probMG2023 - probMGChuva2023
print("A probabilidade dos acidentes ocorrem no estado de Minas Gerais sem chuva em 2023 é: " + str(round(probNaoChuvaMG2023*100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrem no estado de Minas Gerais sem chuva em 2023 é: 12.65%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em PE**

# %%
probNaoChuvaPE2019 = probPE2019 - probPEChuva2019
print("A probabilidade dos acidentes ocorrerem no estado de Pernambuco sem chuva em 2019 é: " + str(round(probNaoChuvaPE2019*100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Pernambuco sem chuva em 2019 é: 4.01%

# %%
probNaoChuvaPE2020 = probPE2020 - probPEChuva2020
print("A probabilidade dos acidentes ocorrerem no estado de Pernambuco sem chuva em 2020 é: " + str(round(probNaoChuvaPE2020*100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Pernambuco sem chuva em 2020 é: 3.8%

# %%
probNaoChuvaPE2021 = probPE2021 - probPEChuva2021
print("A probabilidade dos acidentes ocorrerem no estado de Pernambuco sem chuva em 2021 é: " + str(round(probNaoChuvaPE2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Pernambuco sem chuva em 2021 é: 3.95%

# %%
probNaoChuvaPE2022 = probPE2022 - probPEChuva2022
print("A probabilidade dos acidentes ocorrerem no estado de Pernambuco sem chuva em 2022 é: " + str(round(probNaoChuvaPE2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Pernambuco sem chuva em 2022 é: 4.15%

# %%
probNaoChuvaPE2023 = probPE2023 - probPEChuva2023
print("A probabilidade dos acidentes ocorrerem no estado de Pernambuco sem chuva em 2023 é: " + str(round(probNaoChuvaPE2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Pernambuco sem chuva em 2023 é: 4.04%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em PA**

# %%
probNaoChuvaPA2019 = probPA2019 - probPAChuva2019
print("A probabilidade dos acidentes ocorrerem no estado do Pará sem chuva em 2019 é: " + str(round(probNaoChuvaPA2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Pará sem chuva em 2019 é: 1.14%

# %%
probNaoChuvaPA2020 = probPA2020 - probPAChuva2020
print("A probabilidade dos acidentes ocorrerem no estado do Pará sem chuva em 2020 é: " + str(round(probNaoChuvaPA2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Pará sem chuva em 2020 é: 0.51%

# %%
probNaoChuvaPA2021 = probPA2021 - probPAChuva2021
print("A probabilidade dos acidentes ocorrerem no estado do Pará sem chuva em 2021 é: " + str(round(probNaoChuvaPA2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Pará sem chuva em 2021 é: 0.51%

# %%
probNaoChuvaPA2022 = probPA2022 - probPAChuva2022
print("A probabilidade dos acidentes ocorrerem no estado do Pará sem chuva em 2022 é: " + str(round(probNaoChuvaPA2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Pará sem chuva em 2022 é: 0.07%

# %%
probNaoChuvaPA2023 = probPA2023 - probPAChuva2023
print("A probabilidade dos acidentes ocorrerem no estado do Pará sem chuva em 2023 é: " + str(round(probNaoChuvaPA2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Pará sem chuva em 2023 é: 0.0%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em SC**

# %%
probNaoChuvaSC2019 = probSC2019 - probSCChuva2019
print("A probabilidade dos acidentes ocorrerem no estado de Santa Catarina sem chuva em 2019 é: " + str(round(probNaoChuvaSC2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Santa Catarina sem chuva em 2019 é: 12.41%

# %%
probNaoChuvaSC2020 = probSC2020 - probSCChuva2020
print("A probabilidade dos acidentes ocorrerem no estado de Santa Catarina sem chuva em 2020 é: " + str(round(probNaoChuvaSC2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Santa Catarina sem chuva em 2020 é: 1.66%

# %%
probNaoChuvaSC2021 = probSC2021 - probSCChuva2021
print("A probabilidade dos acidentes ocorrerem no estado de Santa Catarina sem chuva em 2021 é: " + str(round(probNaoChuvaSC2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Santa Catarina sem chuva em 2021 é: 1.88%

# %%
probNaoChuvaSC2022 = probSC2022 - probSCChuva2022
print("A probabilidade dos acidentes ocorrerem no estado de Santa Catarina sem chuva em 2022 é: " + str(round(probNaoChuvaSC2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Santa Catarina sem chuva em 2022 é: 1.64%

# %%
probNaoChuvaSC2023 = probSC2023 - probSCChuva2023
print("A probabilidade dos acidentes ocorrerem no estado de Santa Catarina sem chuva em 2023 é: " + str(round(probNaoChuvaSC2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Santa Catarina sem chuva em 2023 é: 1.85%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em RJ**

# %%
probNaoChuvaRJ2019 = probRJ2019 - probRJChuva2019
print("A probabilidade dos acidentes ocorrerem no estado do Rio de Janeiro sem chuva em 2019 é: " + str(round(probNaoChuvaRJ2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Rio de Janeiro sem chuva em 2019 é: 0.77%

# %%
probNaoChuvaRJ2020 = probRJ2020 - probRJChuva2020
print("A probabilidade dos acidentes ocorrerem no estado do Rio de Janeiro sem chuva em 2020 é: " + str(round(probNaoChuvaRJ2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Rio de Janeiro sem chuva em 2020 é: 0.0%

# %%
probNaoChuvaRJ2021 = probRJ2021 - probRJChuva2021
print("A probabilidade dos acidentes ocorrerem no estado do Rio de Janeiro sem chuva em 2021 é: " + str(round(probNaoChuvaRJ2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Rio de Janeiro sem chuva em 2021 é: 0.7%

# %%
probNaoChuvaRJ2022 = probRJ2022 - probRJChuva2022
print("A probabilidade dos acidentes ocorrerem no estado do Rio de Janeiro sem chuva em 2022 é: " + str(round(probNaoChuvaRJ2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Rio de Janeiro sem chuva em 2022 é: 0.05%

# %%
probNaoChuvaRJ2023 = probRJ2023 - probRJChuva2023
print("A probabilidade dos acidentes ocorrerem no estado do Rio de Janeiro sem chuva em 2023 é: " + str(round(probNaoChuvaRJ2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Rio de Janeiro sem chuva em 2023 é: 1.6%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em AM**

# %%
probNaoChuvaAM2019 = probAM2019 - probAMChuva2019
print("A probabilidade dos acidentes ocorrerem no estado do Amazonas sem chuva em 2019 é: " + str(round(probNaoChuvaAM2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Amazonas sem chuva em 2019 é: 0.09%

# %%
probNaoChuvaAM2020 = probAM2020 - probAMChuva2020
print("A probabilidade dos acidentes ocorrerem no estado do Amazonas sem chuva em 2020 é: " + str(round(probNaoChuvaAM2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Amazonas sem chuva em 2020 é: 0.0%

# %%
probNaoChuvaAM2021 = probAM2021 - probAMChuva2021
print("A probabilidade dos acidentes ocorrerem no estado do Amazonas sem chuva em 2021 é: " + str(round(probNaoChuvaAM2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Amazonas sem chuva em 2021 é: 0.11%

# %%
probNaoChuvaAM2022 = probAM2022 - probAMChuva2022
print("A probabilidade dos acidentes ocorrerem no estado do Amazonas sem chuva em 2022 é: " + str(round(probNaoChuvaAM2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Amazonas sem chuva em 2022 é: 0.05%

# %%
probNaoChuvaAM2023 = probAM2023 - probAMChuva2023
print("A probabilidade dos acidentes ocorrerem no estado do Amazonas sem chuva em 2023 é: " + str(round(probNaoChuvaAM2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Amazonas sem chuva em 2023 é: 0.02%

# %%
probNaoChuvaAP2022 = probAP2022 - probAPChuva2022
print("A probabilidade dos acidentes ocorrerem no estado do Amapá sem chuva em 2022 é: " + str(round(probNaoChuvaAP2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Amapá sem chuva em 2022 é: 0.06%

# %%
probNaoChuvaAP2023 = probAP2023 - probAPChuva2023
print("A probabilidade dos acidentes ocorrerem no estado do Amapá sem chuva em 2023 é: " + str(round(probNaoChuvaAP2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Amapá sem chuva em 2023 é: 0.2%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em AC**

# %%
probNaoChuvaAC2019 = probAC2019 - probACChuva2019
print("A probabilidade dos acidentes ocorrerem no estado do Acre sem chuva em 2019 é: " + str(round(probNaoChuvaAC2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Acre sem chuva em 2019 é: 0.38%

# %%
probNaoChuvaAC2020 = probAC2020 - probACChuva2020
print("A probabilidade dos acidentes ocorrerem no estado do Acre sem chuva em 2020 é: " + str(round(probNaoChuvaAC2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Acre sem chuva em 2020 é: 0.45%

# %%
probNaoChuvaAC2021 = probAC2021 - probACChuva2021
print("A probabilidade dos acidentes ocorrerem no estado do Acre sem chuva em 2021 é: " + str(round(probNaoChuvaAC2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Acre sem chuva em 2021 é: 0.31%

# %%
probNaoChuvaAC2022 = probAC2022 - probACChuva2022
print("A probabilidade dos acidentes ocorrerem no estado do Acre sem chuva em 2022 é: " + str(round(probNaoChuvaAC2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Acre sem chuva em 2022 é: 0.05%

# %%
probNaoChuvaAC2023 = probAC2023 - probACChuva2023
print("A probabilidade dos acidentes ocorrerem no estado do Acre sem chuva em 2023 é: " + str(round(probNaoChuvaAC2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Acre sem chuva em 2023 é: 0.2%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em RO**

# %%
probNaoChuvaRO2019 = probRO2019 - probROChuva2019
print("A probabilidade dos acidentes ocorrerem no estado de Rondônia sem chuva em 2019 é: " + str(round(probNaoChuvaRO2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Rondônia sem chuva em 2019 é: 0.76%

# %%
probNaoChuvaRO2020 = probRO2020 - probROChuva2020
print("A probabilidade dos acidentes ocorrerem no estado de Rondônia sem chuva em 2020 é: " + str(round(probNaoChuvaRO2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Rondônia sem chuva em 2020 é: 2.12%

# %%
probNaoChuvaRO2021 = probRO2021 - probROChuva2021
print("A probabilidade dos acidentes ocorrerem no estado de Rondônia sem chuva em 2021 é: " + str(round(probNaoChuvaRO2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Rondônia sem chuva em 2021 é: 2.2%

# %%
probNaoChuvaRO2022 = probRO2022 - probROChuva2022
print("A probabilidade dos acidentes ocorrerem no estado de Rondônia sem chuva em 2022 é: " + str(round(probNaoChuvaRO2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Rondônia sem chuva em 2022 é: 1.64%

# %%
probNaoChuvaRO2023 = probRO2023 - probROChuva2023
print("A probabilidade dos acidentes ocorrerem no estado de Rondônia sem chuva em 2023 é: " + str(round(probNaoChuvaRO2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Rondônia sem chuva em 2023 é: 1.65%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em RR**

# %%
probNaoChuvaRR2019 = probRR2019 - probRRChuva2019
print("A probabilidade dos acidentes ocorrerem no estado de Roraima sem chuva em 2019 é: " + str(round(probNaoChuvaRR2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Roraima sem chuva em 2019 é: 0.3%

# %%
probNaoChuvaRR2020 = probRR2020 - probRRChuva2020
print("A probabilidade dos acidentes ocorrerem no estado de Roraima sem chuva em 2020 é: " + str(round(probNaoChuvaRR2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Roraima sem chuva em 2020 é: 0.15%

# %%
probNaoChuvaRR2021 = probRR2021 - probRRChuva2021
print("A probabilidade dos acidentes ocorrerem no estado de Roraima sem chuva em 2021 é: " + str(round(probNaoChuvaRR2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Roraima sem chuva em 2021 é: 0.41%

# %%
probNaoChuvaRR2022 = probRR2022 - probRRChuva2022
print("A probabilidade dos acidentes ocorrerem no estado de Roraima sem chuva em 2022 é: " + str(round(probNaoChuvaRR2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Roraima sem chuva em 2022 é: 0.06%

# %%
probNaoChuvaRR2023 = probRR2023 - probRRChuva2023
print("A probabilidade dos acidentes ocorrerem no estado de Roraima sem chuva em 2023 é: " + str(round(probNaoChuvaRR2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Roraima sem chuva em 2023 é: 0.22%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em TO**

# %%
probNaoChuvaTO2019 = probTO2019 - probTOChuva2019
print("A probabilidade dos acidentes ocorrerem no estado de Tocantins sem chuva em 2019 é: " + str(round(probNaoChuvaTO2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Tocantins sem chuva em 2019 é: 0.77%

# %%
probNaoChuvaTO2020 = probTO2020 - probTOChuva2020
print("A probabilidade dos acidentes ocorrerem no estado de Tocantins sem chuva em 2020 é: " + str(round(probNaoChuvaTO2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Tocantins sem chuva em 2020 é: 0.1%

# %%
probNaoChuvaTO2021 = probTO2021 - probTOChuva2021
print("A probabilidade dos acidentes ocorrerem no estado de Tocantins sem chuva em 2021 é: " + str(round(probNaoChuvaTO2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Tocantins sem chuva em 2021 é: 0.7%

# %%
probNaoChuvaTO2022 = probTO2022 - probTOChuva2022
print("A probabilidade dos acidentes ocorrerem no estado de Tocantins sem chuva em 2022 é: " + str(round(probNaoChuvaTO2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Tocantins sem chuva em 2022 é: 0.06%

# %%
probNaoChuvaTO2023 = probTO2023 - probTOChuva2023
print("A probabilidade dos acidentes ocorrerem no estado de Tocantins sem chuva em 2023 é: " + str(round(probNaoChuvaTO2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Tocantins sem chuva em 2023 é: 0.02%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em MA**

# %%
probNaoChuvaMA2019 = probMA2019 - probMAChuva2019
print("A probabilidade dos acidentes ocorrerem no estado do Maranhão sem chuva em 2019 é: " + str(round(probNaoChuvaMA2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Maranhão sem chuva em 2019 é: 0.0%

# %%
probNaoChuvaMA2020 = probMA2020 - probMAChuva2020
print("A probabilidade dos acidentes ocorrerem no estado do Maranhão sem chuva em 2020 é: " + str(round(probNaoChuvaMA2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Maranhão sem chuva em 2020 é: 1.61%

# %%
probNaoChuvaMA2021 = probMA2021 - probMAChuva2021
print("A probabilidade dos acidentes ocorrerem no estado do Maranhão sem chuva em 2021 é: " + str(round(probNaoChuvaMA2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Maranhão sem chuva em 2021 é: 1.7%

# %%
probNaoChuvaMA2022 = probMA2022 - probMAChuva2022
print("A probabilidade dos acidentes ocorrerem no estado do Maranhão sem chuva em 2022 é: " + str(round(probNaoChuvaMA2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Maranhão sem chuva em 2022 é: 1.65%

# %%
probNaoChuvaMA2023 = probMA2023 - probMAChuva2023
print("A probabilidade dos acidentes ocorrerem no estado do Maranhão sem chuva em 2023 é: " + str(round(probNaoChuvaMA2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Maranhão sem chuva em 2023 é: 1.63%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em PI**

# %%
probNaoChuvaPI2019 = probPI2019 - probPIChuva2019
print("A probabilidade dos acidentes ocorrerem no estado do Piauí sem chuva em 2019 é: " + str(round(probNaoChuvaPI2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Piauí sem chuva em 2019 é: 0.47%

# %%
probNaoChuvaPI2020 = probPI2020 - probPIChuva2020
print("A probabilidade dos acidentes ocorrerem no estado do Piauí sem chuva em 2020 é: " + str(round(probNaoChuvaPI2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Piauí sem chuva em 2020 é: 1.66%

# %%
probNaoChuvaPI2021 = probPI2021 - probPIChuva2021
print("A probabilidade dos acidentes ocorrerem no estado do Piauí sem chuva em 2021 é: " + str(round(probNaoChuvaPI2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Piauí sem chuva em 2021 é: 1.69%

# %%
probNaoChuvaPI2022 = probPI2022 - probPIChuva2022
print("A probabilidade dos acidentes ocorrerem no estado do Piauí sem chuva em 2022 é: " + str(round(probNaoChuvaPI2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Piauí sem chuva em 2022 é: 1.6%

# %%
probNaoChuvaPI2023 = probPI2023 - probPIChuva2023
print("A probabilidade dos acidentes ocorrerem no estado do Piauí sem chuva em 2023 é: " + str(round(probNaoChuvaPI2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Piauí sem chuva em 2023 é: 1.63%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em CE**

# %%
probNaoChuvaCE2019 = probCE2019 - probCEChuva2019
print("A probabilidade dos acidentes ocorrerem no estado do Ceará sem chuva em 2019 é: " + str(round(probNaoChuvaCE2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Ceará sem chuva em 2019 é: 0.96%

# %%
probNaoChuvaCE2020 = probCE2020 - probCEChuva2020
print("A probabilidade dos acidentes ocorrerem no estado do Ceará sem chuva em 2020 é: " + str(round(probNaoChuvaCE2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Ceará sem chuva em 2020 é: 1.66%

# %%
probNaoChuvaCE2021 = probCE2021 - probCEChuva2021
print("A probabilidade dos acidentes ocorrerem no estado do Ceará sem chuva em 2021 é: " + str(round(probNaoChuvaCE2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Ceará sem chuva em 2021 é: 1.59%

# %%
probNaoChuvaCE2022 = probCE2022 - probCEChuva2022
print("A probabilidade dos acidentes ocorrerem no estado do Ceará sem chuva em 2022 é: " + str(round(probNaoChuvaCE2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Ceará sem chuva em 2022 é: 1.61%

# %%
probNaoChuvaCE2023 = probCE2023 - probCEChuva2023
print("A probabilidade dos acidentes ocorrerem no estado do Ceará sem chuva em 2023 é: " + str(round(probNaoChuvaCE2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Ceará sem chuva em 2023 é: 1.58%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em RN**

# %%
probNaoChuvaRN2019 = probRN2019 - probRNChuva2019
print("A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Norte sem chuva em 2019 é: " + str(round(probNaoChuvaRN2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Norte sem chuva em 2019 é: 0.57%

# %%
probNaoChuvaRN2020 = probRN2020 - probRNChuva2020
print("A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Norte sem chuva em 2020 é: " + str(round(probNaoChuvaRN2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Norte sem chuva em 2020 é: 2.07%

# %%
probNaoChuvaRN2021 = probRN2021 - probRNChuva2021
print("A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Norte sem chuva em 2021 é: " + str(round(probNaoChuvaRN2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Norte sem chuva em 2021 é: 2.0%

# %%
probNaoChuvaRN2022 = probRN2022 - probRNChuva2022
print("A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Norte sem chuva em 2022 é: " + str(round(probNaoChuvaRN2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Norte sem chuva em 2022 é: 1.59%

# %%
probNaoChuvaRN2023 = probRN2023 - probRNChuva2023
print("A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Norte sem chuva em 2023 é: " + str(round(probNaoChuvaRN2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Norte sem chuva em 2023 é: 1.6%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em PB**

# %%
probNaoChuvaPB2019 = probPB2019 - probPBChuva2019
print("A probabilidade dos acidentes ocorrerem no estado da Paraíba sem chuva em 2019 é: " + str(round(probNaoChuvaPB2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado da Paraíba sem chuva em 2019 é: 0.77%

# %%
probNaoChuvaPB2020 = probPB2020 - probPBChuva2020
print("A probabilidade dos acidentes ocorrerem no estado da Paraíba sem chuva em 2020 é: " + str(round(probNaoChuvaPB2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado da Paraíba sem chuva em 2020 é: 2.16%

# %%
probNaoChuvaPB2021 = probPB2021 - probPBChuva2021
print("A probabilidade dos acidentes ocorrerem no estado da Paraíba sem chuva em 2021 é: " + str(round(probNaoChuvaPB2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado da Paraíba sem chuva em 2021 é: 2.18%

# %%
probNaoChuvaPB2022 = probPB2022 - probPBChuva2022
print("A probabilidade dos acidentes ocorrerem no estado da Paraíba sem chuva em 2022 é: " + str(round(probNaoChuvaPB2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado da Paraíba sem chuva em 2022 é: 1.59%

# %%
probNaoChuvaPB2023 = probPB2023 - probPBChuva2023
print("A probabilidade dos acidentes ocorrerem no estado da Paraíba sem chuva em 2023 é: " + str(round(probNaoChuvaPB2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado da Paraíba sem chuva em 2023 é: 1.8%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em AL**

# %%
probNaoChuvaAL2019 = probAL2019 - probALChuva2019
print("A probabilidade dos acidentes ocorrerem no estado de Alagoas sem chuva em 2019 é: " + str(round(probNaoChuvaAL2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Alagoas sem chuva em 2019 é: 0.85%

# %%
probNaoChuvaAL2020 = probAL2020 - probALChuva2020
print("A probabilidade dos acidentes ocorrerem no estado de Alagoas sem chuva em 2020 é: " + str(round(probNaoChuvaAL2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Alagoas sem chuva em 2020 é: 0.15%

# %%
probNaoChuvaAL2021 = probAL2021 - probALChuva2021
print("A probabilidade dos acidentes ocorrerem no estado de Alagoas sem chuva em 2021 é: " + str(round(probNaoChuvaAL2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Alagoas sem chuva em 2021 é: 0.1%

# %%
probNaoChuvaAL2022 = probAL2022 - probALChuva2022
print("A probabilidade dos acidentes ocorrerem no estado de Alagoas sem chuva em 2022 é: " + str(round(probNaoChuvaAL2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Alagoas sem chuva em 2022 é: 0.0%

# %%
probNaoChuvaAL2023 = probAL2023 - probALChuva2023
print("A probabilidade dos acidentes ocorrerem no estado de Alagoas sem chuva em 2023 é: " + str(round(probNaoChuvaAL2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Alagoas sem chuva em 2023 é: 0.05%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em SE**

# %%
probNaoChuvaSE2019 = probSE2019 - probSEChuva2019
print("A probabilidade dos acidentes ocorrerem no estado de Sergipe sem chuva em 2019 é: " + str(round(probNaoChuvaSE2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Sergipe sem chuva em 2019 é: 0.85%

# %%
probNaoChuvaSE2020 = probSE2020 - probSEChuva2020
print("A probabilidade dos acidentes ocorrerem no estado de Sergipe sem chuva em 2020 é: " + str(round(probNaoChuvaSE2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Sergipe sem chuva em 2020 é: 0.05%

# %%
probNaoChuvaSE2021 = probSE2021 - probSEChuva2021
print("A probabilidade dos acidentes ocorrerem no estado de Sergipe sem chuva em 2021 é: " + str(round(probNaoChuvaSE2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Sergipe sem chuva em 2021 é: 0.71%

# %%
probNaoChuvaSE2022 = probSE2022 - probSEChuva2022
print("A probabilidade dos acidentes ocorrerem no estado de Sergipe sem chuva em 2022 é: " + str(round(probNaoChuvaSE2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Sergipe sem chuva em 2022 é: 0.07%

# %%
probNaoChuvaSE2023 = probSE2023 - probSEChuva2023
print("A probabilidade dos acidentes ocorrerem no estado de Sergipe sem chuva em 2023 é: " + str(round(probNaoChuvaSE2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Sergipe sem chuva em 2023 é: 0.0%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em BA**

# %%
probNaoChuvaBA2019 = probBA2019 - probBAChuva2019
print("A probabilidade dos acidentes ocorrerem no estado da Bahia sem chuva em 2019 é: " + str(round(probNaoChuvaBA2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado da Bahia sem chuva em 2019 é: 0.58%

# %%
probNaoChuvaBA2020 = probBA2020 - probBAChuva2020
print("A probabilidade dos acidentes ocorrerem no estado da Bahia sem chuva em 2020 é: " + str(round(probNaoChuvaBA2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado da Bahia sem chuva em 2020 é: 2.01%

# %%
probNaoChuvaBA2021 = probBA2021 - probBAChuva2021
print("A probabilidade dos acidentes ocorrerem no estado da Bahia sem chuva em 2021 é: " + str(round(probNaoChuvaBA2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado da Bahia sem chuva em 2021 é: 1.89%

# %%
probNaoChuvaBA2022 = probBA2022 - probBAChuva2022
print("A probabilidade dos acidentes ocorrerem no estado da Bahia sem chuva em 2022 é: " + str(round(probNaoChuvaBA2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado da Bahia sem chuva em 2022 é: 1.64%

# %%
probNaoChuvaBA2023 = probBA2023 - probBAChuva2023
print("A probabilidade dos acidentes ocorrerem no estado da Bahia sem chuva em 2023 é: " + str(round(probNaoChuvaBA2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado da Bahia sem chuva em 2023 é: 1.8%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em GO**

# %%
probNaoChuvaGO2019 = probGO2019 - probGOChuva2019
print("A probabilidade dos acidentes ocorrerem no estado de Goiás sem chuva em 2019 é: " + str(round(probNaoChuvaGO2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Goiás sem chuva em 2019 é: 0.39%

# %%
probNaoChuvaGO2020 = probGO2020 - probGOChuva2020
print("A probabilidade dos acidentes ocorrerem no estado de Goiás sem chuva em 2020 é: " + str(round(probNaoChuvaGO2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Goiás sem chuva em 2020 é: 1.61%

# %%
probNaoChuvaGO2021 = probGO2021 - probGOChuva2021
print("A probabilidade dos acidentes ocorrerem no estado de Goiás sem chuva em 2021 é: " + str(round(probNaoChuvaGO2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Goiás sem chuva em 2021 é: 1.69%

# %%
probNaoChuvaGO2022 = probGO2022 - probGOChuva2022
print("A probabilidade dos acidentes ocorrerem no estado de Goiás sem chuva em 2022 é: " + str(round(probNaoChuvaGO2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Goiás sem chuva em 2022 é: 1.65%

# %%
probNaoChuvaGO2023 = probGO2023 - probGOChuva2023
print("A probabilidade dos acidentes ocorrerem no estado de Goiás sem chuva em 2023 é: " + str(round(probNaoChuvaGO2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado de Goiás sem chuva em 2023 é: 0.22%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em MT**

# %%
probNaoChuvaMT2019 = probMT2019 - probMTChuva2019
print("A probabilidade dos acidentes ocorrerem no estado do Mato Grosso sem chuva em 2019 é: " + str(round(probNaoChuvaMT2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Mato Grosso sem chuva em 2019 é: 0.11%

# %%
probNaoChuvaMT2020 = probMT2020 - probMTChuva2020
print("A probabilidade dos acidentes ocorrerem no estado do Mato Grosso sem chuva em 2020 é: " + str(round(probNaoChuvaMT2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Mato Grosso sem chuva em 2020 é: 0.0%

# %%
probNaoChuvaMT2021 = probMT2021 - probMTChuva2021
print("A probabilidade dos acidentes ocorrerem no estado do Mato Grosso sem chuva em 2021 é: " + str(round(probNaoChuvaMT2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Mato Grosso sem chuva em 2021 é: 0.11%

# %%
probNaoChuvaMT2022 = probMT2022 - probMTChuva2022
print("A probabilidade dos acidentes ocorrerem no estado do Mato Grosso sem chuva em 2022 é: " + str(round(probNaoChuvaMT2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Mato Grosso sem chuva em 2022 é: 0.07%

# %%
probNaoChuvaMT2023 = probMT2023 - probMTChuva2023
print("A probabilidade dos acidentes ocorrerem no estado do Mato Grosso sem chuva em 2023 é: " + str(round(probNaoChuvaMT2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Mato Grosso sem chuva em 2023 é: 0.05%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em MS**

# %%
probNaoChuvaMS2019 = probMS2019 - probMSChuva2019
print("A probabilidade dos acidentes ocorrerem no estado do Mato Grosso do Sul sem chuva em 2019 é: " + str(round(probNaoChuvaMS2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Mato Grosso do Sul sem chuva em 2019 é: 0.58%

# %%
probNaoChuvaMS2020 = probMS2020 - probMSChuva2020
print("A probabilidade dos acidentes ocorrerem no estado do Mato Grosso do Sul sem chuva em 2020 é: " + str(round(probNaoChuvaMS2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Mato Grosso do Sul sem chuva em 2020 é: 1.61%

# %%
probNaoChuvaMS2021 = probMS2021 - probMSChuva2021
print("A probabilidade dos acidentes ocorrerem no estado do Mato Grosso do Sul sem chuva em 2021 é: " + str(round(probNaoChuvaMS2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Mato Grosso do Sul sem chuva em 2021 é: 1.7%

# %%
probNaoChuvaMS2022 = probMS2022 - probMSChuva2022
print("A probabilidade dos acidentes ocorrerem no estado do Mato Grosso do Sul sem chuva em 2022 é: " + str(round(probNaoChuvaMS2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Mato Grosso do Sul sem chuva em 2022 é: 1.64%

# %%
probNaoChuvaMS2023 = probMS2023 - probMSChuva2023
print("A probabilidade dos acidentes ocorrerem no estado do Mato Grosso do Sul sem chuva em 2023 é: " + str(round(probNaoChuvaMS2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Mato Grosso do Sul sem chuva em 2023 é: 1.6%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em DF**

# %%
probNaoChuvaDF2019 = probDF2019 - probDFChuva2019
print("A probabilidade dos acidentes ocorrerem no Distrito Federal sem chuva em 2019 é: " + str(round(probNaoChuvaDF2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no Distrito Federal sem chuva em 2019 é: 0.09%

# %%
probNaoChuvaDF2020 = probDF2020 - probDFChuva2020
print("A probabilidade dos acidentes ocorrerem no Distrito Federal sem chuva em 2020 é: " + str(round(probNaoChuvaDF2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no Distrito Federal sem chuva em 2020 é: 1.61%

# %%
probNaoChuvaDF2021 = probDF2021 - probDFChuva2021
print("A probabilidade dos acidentes ocorrerem no Distrito Federal sem chuva em 2021 é: " + str(round(probNaoChuvaDF2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no Distrito Federal sem chuva em 2021 é: 0.7%

# %%
probNaoChuvaDF2022 = probDF2022 - probDFChuva2022
print("A probabilidade dos acidentes ocorrerem no Distrito Federal sem chuva em 2022 é: " + str(round(probNaoChuvaDF2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no Distrito Federal sem chuva em 2022 é: 0.01%

# %%
probNaoChuvaDF2023 = probDF2023 - probDFChuva2023
print("A probabilidade dos acidentes ocorrerem no Distrito Federal sem chuva em 2023 é: " + str(round(probNaoChuvaDF2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no Distrito Federal sem chuva em 2023 é: 0.25%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em ES**

# %%
probNaoChuvaES2019 = probES2019 - probESChuva2019
print("A probabilidade dos acidentes ocorrerem no estado do Espírito Santo sem chuva em 2019 é: " + str(round(probNaoChuvaES2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Espírito Santo sem chuva em 2019 é: 1.15%

# %%
probNaoChuvaES2020 = probES2020 - probESChuva2020
print("A probabilidade dos acidentes ocorrerem no estado do Espírito Santo sem chuva em 2020 é: " + str(round(probNaoChuvaES2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Espírito Santo sem chuva em 2020 é: 0.56%

# %%
probNaoChuvaES2021 = probES2021 - probESChuva2021
print("A probabilidade dos acidentes ocorrerem no estado do Espírito Santo sem chuva em 2021 é: " + str(round(probNaoChuvaES2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Espírito Santo sem chuva em 2021 é: 0.71%

# %%
probNaoChuvaES2022 = probES2022 - probESChuva2022
print("A probabilidade dos acidentes ocorrerem no estado do Espírito Santo sem chuva em 2022 é: " + str(round(probNaoChuvaES2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Espírito Santo sem chuva em 2022 é: 0.06%

# %%
probNaoChuvaES2023 = probES2023 - probESChuva2023
print("A probabilidade dos acidentes ocorrerem no estado do Espírito Santo sem chuva em 2023 é: " + str(round(probNaoChuvaES2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Espírito Santo sem chuva em 2023 é: 0.2%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em PR**

# %%
probNaoChuvaPR2019 = probPR2019 - probPRChuva2019
print("A probabilidade dos acidentes ocorrerem no estado do Paraná sem chuva em 2019 é: " + str(round(probNaoChuvaPR2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Paraná sem chuva em 2019 é: 0.77%

# %%
probNaoChuvaPR2020 = probPR2020 - probPRChuva2020
print("A probabilidade dos acidentes ocorrerem no estado do Paraná sem chuva em 2020 é: " + str(round(probNaoChuvaPR2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Paraná sem chuva em 2020 é: 1.61%

# %%
probNaoChuvaPR2021 = probPR2021 - probPRChuva2021
print("A probabilidade dos acidentes ocorrerem no estado do Paraná sem chuva em 2021 é: " + str(round(probNaoChuvaPR2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Paraná sem chuva em 2021 é: 1.8%

# %%
probNaoChuvaPR2022 = probPR2022 - probPRChuva2022
print("A probabilidade dos acidentes ocorrerem no estado do Paraná sem chuva em 2022 é: " + str(round(probNaoChuvaPR2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Paraná sem chuva em 2022 é: 1.59%

# %%
probNaoChuvaPR2023 = probPR2023 - probPRChuva2023
print("A probabilidade dos acidentes ocorrerem no estado do Paraná sem chuva em 2023 é: " + str(round(probNaoChuvaPR2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Paraná sem chuva em 2023 é: 0.25%

# %% [markdown]
# **Probabilidade dos acidentes acontecem  sem chuva em RS**

# %%
probNaoChuvaRS2019 = probRS2019 - probRSChuva2019
print("A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Sul sem chuva em 2019 é: " + str(round(probNaoChuvaRS2019 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Sul sem chuva em 2019 é: 0.66%

# %%
probNaoChuvaRS2020 = probRS2020 - probRSChuva2020
print("A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Sul sem chuva em 2020 é: " + str(round(probNaoChuvaRS2020 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Sul sem chuva em 2020 é: 0.1%

# %%
probNaoChuvaRS2021 = probRS2021 - probRSChuva2021
print("A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Sul sem chuva em 2021 é: " + str(round(probNaoChuvaRS2021 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Sul sem chuva em 2021 é: 0.61%

# %%
probNaoChuvaRS2022 = probRS2022 - probRSChuva2022
print("A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Sul sem chuva em 2022 é: " + str(round(probNaoChuvaRS2022 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Sul sem chuva em 2022 é: 0.0%

# %%
probNaoChuvaRS2023 = probRS2023 - probRSChuva2023
print("A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Sul sem chuva em 2023 é: " + str(round(probNaoChuvaRS2023 * 100, 2)) + "%")
# Out:
# A probabilidade dos acidentes ocorrerem no estado do Rio Grande do Sul sem chuva em 2023 é: 0.22%

# %% [markdown]
# # **Probabilidade com diferença**

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em SPs**

# %%
semMortosSP2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosSP2019 = semMortosSP2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em SP é: ' + str(round((probsemMortosSP2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em SP é: 44.06%

# %%
semMortosSP2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosSP2020 = semMortosSP2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em SP em 2020 é: ' + str(round((probsemMortosSP2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em SP em 2020 é: 41.02%

# %%
semMortosSP2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosSP2021 = semMortosSP2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em SP em 2021 é: ' + str(round((probsemMortosSP2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em SP em 2021 é: 41.97%

# %%
semMortosSP2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosSP2022 = semMortosSP2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em SP em 2022 é: ' + str(round((probsemMortosSP2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em SP em 2022 é: 42.11%

# %%
semMortosSP2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosSP2023 = semMortosSP2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em SP em 2023 é: ' + str(round((probsemMortosSP2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em SP em 2023 é: 43.9%

# %%
semMortesSP = [probsemMortosSP2020, probsemMortosSP2021, probsemMortosSP2022, probsemMortosSP2023]
mediaSemMortesSP = sum(semMortesSP) / len(semMortesSP)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em SP em 2023 é : ' + str(round((mediaSemMortesSP * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em SP em 2023 é : 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em MG**

# %%
semMortosMG2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosMG2019 = semMortosMG2019 / len(leitura2019)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em MG em 2020 é: ' + str(round((probsemMortosMG2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MG em 2020 é: 44.06%

# %%
semMortosMG2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosMG2020 = semMortosMG2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em MG em 2020 é: ' + str(round((probsemMortosMG2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MG em 2020 é: 41.02%

# %%
semMortosMG2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosMG2021 = semMortosMG2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em MG em 2021 é: ' + str(round((probsemMortosMG2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MG em 2021 é: 41.97%

# %%
semMortosMG2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosMG2022 = semMortosMG2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em MG em 2022 é: ' + str(round((probsemMortosMG2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MG em 2022 é: 42.11%

# %%
semMortosMG2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosMG2023 = semMortosMG2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em MG em 2023 é: ' + str(round((probsemMortosMG2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MG em 2023 é: 43.9%

# %%
semMortesMG = [probsemMortosMG2019, probsemMortosMG2020, probsemMortosMG2021, probsemMortosMG2022, probsemMortosMG2023]
mediaSemMortesMG = sum(semMortesMG) / len(semMortesMG)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em MG de 2020 a 2023 é: ' + str(round((mediaSemMortesMG * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MG de 2020 a 2023 é: 42.61%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em PE**

# %%
semMortosPE2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosPE2019 = semMortosPE2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PE em 2019 é: ' + str(round((probsemMortosPE2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PE em 2019 é: 44.06%

# %%
semMortosPE2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosPE2020 = semMortosPE2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PE em 2020 é: ' + str(round((probsemMortosPE2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PE em 2020 é: 41.02%

# %%
semMortosPE2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosPE2021 = semMortosPE2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PE em 2021 é: ' + str(round((probsemMortosPE2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PE em 2021 é: 41.97%

# %%
semMortosPE2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosPE2022 = semMortosPE2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PE em 2022 é: ' + str(round((probsemMortosPE2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PE em 2022 é: 42.11%

# %%
semMortosPE2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosPE2023 = semMortosPE2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PE em 2023 é: ' + str(round((probsemMortosPE2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PE em 2023 é: 43.9%

# %%
semMortesPE = [probsemMortosPE2020, probsemMortosPE2021, probsemMortosPE2022, probsemMortosPE2023]
mediaSemMortesPE = sum(semMortesPE) / len(semMortesPE)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em PE de 2020 a 2023 é: ' + str(round((mediaSemMortesPE * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PE de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em PA**

# %%
semMortosPA2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosPA2019 = semMortosPA2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PA em 2019 é: ' + str(round((probsemMortosPA2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PA em 2019 é: 44.06%

# %%
semMortosPA2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosPA2020 = semMortosPA2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PA em 2020 é: ' + str(round((probsemMortosPA2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PA em 2020 é: 41.02%

# %%
semMortosPA2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosPA2021 = semMortosPA2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PA em 2021 é: ' + str(round((probsemMortosPA2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PA em 2021 é: 41.97%

# %%
semMortosPA2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosPA2022 = semMortosPA2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PA em 2022 é: ' + str(round((probsemMortosPA2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PA em 2022 é: 42.11%

# %%
semMortosPA2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosPA2023 = semMortosPA2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PA em 2023 é: ' + str(round((probsemMortosPA2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PA em 2023 é: 43.9%

# %%
semMortesPA = [probsemMortosPA2020, probsemMortosPA2021, probsemMortosPA2022, probsemMortosPA2023]
mediaSemMortesPA = sum(semMortesPA) / len(semMortesPA)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em PA de 2020 a 2023 é: ' + str(round((mediaSemMortesPA * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PA de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em SC**

# %%
semMortosSC2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosSC2019 = semMortosSC2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em SC em 2019 é: ' + str(round((probsemMortosSC2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em SC em 2019 é: 44.06%

# %%
semMortosSC2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosSC2020 = semMortosSC2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em SC em 2020 é: ' + str(round((probsemMortosSC2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em SC em 2020 é: 41.02%

# %%
semMortosSC2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosSC2021 = semMortosSC2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em SC em 2021 é: ' + str(round((probsemMortosSC2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em SC em 2021 é: 41.97%

# %%
semMortosSC2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosSC2022 = semMortosSC2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em SC em 2022 é: ' + str(round((probsemMortosSC2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em SC em 2022 é: 42.11%

# %%
semMortosSC2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosSC2023 = semMortosSC2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em SC em 2023 é: ' + str(round((probsemMortosSC2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em SC em 2023 é: 43.9%

# %%
semMortesSC = [probsemMortosSC2020, probsemMortosSC2021, probsemMortosSC2022, probsemMortosSC2023]
mediaSemMortesSC = sum(semMortesSC) / len(semMortesSC)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em SC de 2020 a 2023 é: ' + str(round((mediaSemMortesSC * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em SC de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em RJ**

# %%
semMortosRJ2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosRJ2019 = semMortosRJ2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no RJ em 2019 é: ' + str(round((probsemMortosRJ2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no RJ em 2019 é: 44.06%

# %%
semMortosRJ2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosRJ2020 = semMortosRJ2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no RJ em 2020 é: ' + str(round((probsemMortosRJ2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no RJ em 2020 é: 41.02%

# %%
semMortosRJ2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosRJ2021 = semMortosRJ2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no RJ em 2021 é: ' + str(round((probsemMortosRJ2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no RJ em 2021 é: 41.97%

# %%
semMortosRJ2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosRJ2022 = semMortosRJ2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no RJ em 2022 é: ' + str(round((probsemMortosRJ2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no RJ em 2022 é: 42.11%

# %%
semMortosRJ2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosRJ2023 = semMortosRJ2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no RJ em 2023 é: ' + str(round((probsemMortosRJ2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no RJ em 2023 é: 43.9%

# %%
semMortesRJ = [probsemMortosRJ2020, probsemMortosRJ2021, probsemMortosRJ2022, probsemMortosRJ2023]
mediaSemMortesRJ = sum(semMortesRJ) / len(semMortesRJ)
print('A probabilidade dos acidentes ocorridos não deixarem mortos no RJ de 2020 a 2023 é: ' + str(round((mediaSemMortesRJ * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no RJ de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em AM**

# %%
semMortosAM2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosAM2019 = semMortosAM2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no AM em 2019 é: ' + str(round((probsemMortosAM2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no AM em 2019 é: 44.06%

# %%
semMortosAM2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosAM2020 = semMortosAM2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no AM em 2020 é: ' + str(round((probsemMortosAM2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no AM em 2020 é: 41.02%

# %%
semMortosAM2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosAM2021 = semMortosAM2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no AM em 2021 é: ' + str(round((probsemMortosAM2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no AM em 2021 é: 41.97%

# %%
semMortosAM2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosAM2022 = semMortosAM2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no AM em 2022 é: ' + str(round((probsemMortosAM2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no AM em 2022 é: 42.11%

# %%
semMortosAM2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosAM2023 = semMortosAM2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no AM em 2023 é: ' + str(round((probsemMortosAM2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no AM em 2023 é: 43.9%

# %%
semMortesAM = [probsemMortosAM2020, probsemMortosAM2021, probsemMortosAM2022, probsemMortosAM2023]
mediaSemMortesAM = sum(semMortesAM) / len(semMortesAM)
print('A probabilidade dos acidentes ocorridos não deixarem mortos no AM de 2020 a 2023 é: ' + str(round((mediaSemMortesAM * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no AM de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em AC**

# %%
semMortosAC2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosAC2019 = semMortosAC2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no AC em 2019 é: ' + str(round((probsemMortosAC2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no AC em 2019 é: 44.06%

# %%
semMortosAC2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosAC2020 = semMortosAC2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no AC em 2020 é: ' + str(round((probsemMortosAC2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no AC em 2020 é: 41.02%

# %%
semMortosAC2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosAC2021 = semMortosAC2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no AC em 2021 é: ' + str(round((probsemMortosAC2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no AC em 2021 é: 41.97%

# %%
semMortosAC2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosAC2022 = semMortosAC2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no AC em 2022 é: ' + str(round((probsemMortosAC2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no AC em 2022 é: 42.11%

# %%
semMortosAC2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosAC2023 = semMortosAC2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no AC em 2023 é: ' + str(round((probsemMortosAC2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no AC em 2023 é: 43.9%

# %%
semMortesAC = [probsemMortosAC2020, probsemMortosAC2021, probsemMortosAC2022, probsemMortosAC2023]
mediaSemMortesAC = sum(semMortesAC) / len(semMortesAC)
print('A probabilidade dos acidentes ocorridos não deixarem mortos no AC de 2020 a 2023 é: ' + str(round((mediaSemMortesAC * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no AC de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em AP**

# %%
semMortosAP2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosAP2019 = semMortosAP2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no AP em 2019 é: ' + str(round((probsemMortosAP2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no AP em 2019 é: 44.06%

# %%
semMortosAP2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosAP2020 = semMortosAP2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no AP em 2020 é: ' + str(round((probsemMortosAP2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no AP em 2020 é: 41.02%

# %%
semMortosAP2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosAP2021 = semMortosAP2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no AP em 2021 é: ' + str(round((probsemMortosAP2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no AP em 2021 é: 41.97%

# %%
semMortosAP2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosAP2022 = semMortosAP2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no AP em 2022 é: ' + str(round((probsemMortosAP2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no AP em 2022 é: 42.11%

# %%
semMortosAP2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosAP2023 = semMortosAP2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no AP em 2023 é: ' + str(round((probsemMortosAP2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no AP em 2023 é: 43.9%

# %%
semMortesAP = [probsemMortosAP2020, probsemMortosAP2021, probsemMortosAP2022, probsemMortosAP2023]
mediaSemMortesAP = sum(semMortesAP) / len(semMortesAP)
print('A probabilidade dos acidentes ocorridos não deixarem mortos no AP de 2020 a 2023 é: ' + str(round((mediaSemMortesAP * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no AP de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em RO**

# %%
semMortosRO2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosRO2019 = semMortosRO2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em RO em 2019 é: ' + str(round((probsemMortosRO2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em RO em 2019 é: 44.06%

# %%
semMortosRO2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosRO2020 = semMortosRO2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em RO em 2020 é: ' + str(round((probsemMortosRO2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em RO em 2020 é: 41.02%

# %%
semMortosRO2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosRO2021 = semMortosRO2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em RO em 2021 é: ' + str(round((probsemMortosRO2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em RO em 2021 é: 41.97%

# %%
semMortosRO2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosRO2022 = semMortosRO2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em RO em 2022 é: ' + str(round((probsemMortosRO2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em RO em 2022 é: 42.11%

# %%
semMortosRO2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosRO2023 = semMortosRO2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em RO em 2023 é: ' + str(round((probsemMortosRO2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em RO em 2023 é: 43.9%

# %%
semMortesRO = [probsemMortosRO2020, probsemMortosRO2021, probsemMortosRO2022, probsemMortosRO2023]
mediaSemMortesRO = sum(semMortesRO) / len(semMortesRO)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em RO de 2020 a 2023 é: ' + str(round((mediaSemMortesRO * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em RO de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em RR**

# %%
semMortosRR2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosRR2019 = semMortosRR2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em RR em 2019 é: ' + str(round((probsemMortosRR2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em RR em 2019 é: 44.06%

# %%
semMortosRR2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosRR2020 = semMortosRR2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em RR em 2020 é: ' + str(round((probsemMortosRR2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em RR em 2020 é: 41.02%

# %%
semMortosRR2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosRR2021 = semMortosRR2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em RR em 2021 é: ' + str(round((probsemMortosRR2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em RR em 2021 é: 41.97%

# %%
semMortosRR2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosRR2022 = semMortosRR2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em RR em 2022 é: ' + str(round((probsemMortosRR2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em RR em 2022 é: 42.11%

# %%
semMortosRR2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosRR2023 = semMortosRR2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em RR em 2023 é: ' + str(round((probsemMortosRR2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em RR em 2023 é: 43.9%

# %%
semMortesRR = [probsemMortosRR2020, probsemMortosRR2021, probsemMortosRR2022, probsemMortosRR2023]
mediaSemMortesRR = sum(semMortesRR) / len(semMortesRR)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em RR de 2020 a 2023 é: ' + str(round((mediaSemMortesRR * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em RR de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em TO**

# %%
semMortosTO2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosTO2019 = semMortosTO2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em TO em 2019 é: ' + str(round((probsemMortosTO2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em TO em 2019 é: 44.06%

# %%
semMortosTO2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosTO2020 = semMortosTO2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em TO em 2020 é: ' + str(round((probsemMortosTO2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em TO em 2020 é: 41.02%

# %%
semMortosTO2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosTO2021 = semMortosTO2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em TO em 2021 é: ' + str(round((probsemMortosTO2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em TO em 2021 é: 41.97%

# %%
semMortosTO2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosTO2022 = semMortosTO2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em TO em 2022 é: ' + str(round((probsemMortosTO2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em TO em 2022 é: 42.11%

# %%
semMortosTO2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosTO2023 = semMortosTO2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em TO em 2023 é: ' + str(round((probsemMortosTO2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em TO em 2023 é: 43.9%

# %%
semMortesTO = [probsemMortosTO2020, probsemMortosTO2021, probsemMortosTO2022, probsemMortosTO2023]
mediaSemMortesTO = sum(semMortesTO) / len(semMortesTO)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em TO de 2020 a 2023 é: ' + str(round((mediaSemMortesTO * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em TO de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em MA**

# %%
semMortosMA2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosMA2019 = semMortosMA2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em MA em 2019 é: ' + str(round((probsemMortosMA2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MA em 2019 é: 44.06%

# %%
semMortosMA2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosMA2020 = semMortosMA2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em MA em 2020 é: ' + str(round((probsemMortosMA2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MA em 2020 é: 41.02%

# %%
semMortosMA2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosMA2021 = semMortosMA2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em MA em 2021 é: ' + str(round((probsemMortosMA2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MA em 2021 é: 41.97%

# %%
semMortosMA2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosMA2022 = semMortosMA2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em MA em 2022 é: ' + str(round((probsemMortosMA2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MA em 2022 é: 42.11%

# %%
semMortosMA2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosMA2023 = semMortosMA2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em MA em 2023 é: ' + str(round((probsemMortosMA2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MA em 2023 é: 43.9%

# %%
semMortesMA = [probsemMortosMA2020, probsemMortosMA2021, probsemMortosMA2022, probsemMortosMA2023]
mediaSemMortesMA = sum(semMortesMA) / len(semMortesMA)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em MA de 2020 a 2023 é: ' + str(round((mediaSemMortesMA * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MA de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em PI**

# %%
semMortosPI2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosPI2019 = semMortosPI2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PI em 2019 é: ' + str(round((probsemMortosPI2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PI em 2019 é: 44.06%

# %%
semMortosPI2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosPI2020 = semMortosPI2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PI em 2020 é: ' + str(round((probsemMortosPI2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PI em 2020 é: 41.02%

# %%
semMortosPI2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosPI2021 = semMortosPI2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PI em 2021 é: ' + str(round((probsemMortosPI2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PI em 2021 é: 41.97%

# %%
semMortosPI2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosPI2022 = semMortosPI2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PI em 2022 é: ' + str(round((probsemMortosPI2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PI em 2022 é: 42.11%

# %%
semMortosPI2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosPI2023 = semMortosPI2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PI em 2023 é: ' + str(round((probsemMortosPI2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PI em 2023 é: 43.9%

# %%
semMortesPI = [probsemMortosPI2020, probsemMortosPI2021, probsemMortosPI2022, probsemMortosPI2023]
mediaSemMortesPI = sum(semMortesPI) / len(semMortesPI)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em PI de 2020 a 2023 é: ' + str(round((mediaSemMortesPI * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PI de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em CE**

# %%
semMortosCE2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosCE2019 = semMortosCE2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em CE em 2019 é: ' + str(round((probsemMortosCE2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em CE em 2019 é: 44.06%

# %%
semMortosCE2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosCE2020 = semMortosCE2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em CE em 2020 é: ' + str(round((probsemMortosCE2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em CE em 2020 é: 41.02%

# %%
semMortosCE2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosCE2021 = semMortosCE2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em CE em 2021 é: ' + str(round((probsemMortosCE2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em CE em 2021 é: 41.97%

# %%
semMortosCE2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosCE2022 = semMortosCE2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em CE em 2022 é: ' + str(round((probsemMortosCE2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em CE em 2022 é: 42.11%

# %%
semMortosCE2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosCE2023 = semMortosCE2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em CE em 2023 é: ' + str(round((probsemMortosCE2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em CE em 2023 é: 43.9%

# %%
semMortesCE = [probsemMortosCE2020, probsemMortosCE2021, probsemMortosCE2022, probsemMortosCE2023]
mediaSemMortesCE = sum(semMortesCE) / len(semMortesCE)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em CE de 2020 a 2023 é: ' + str(round((mediaSemMortesCE * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em CE de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em RN**

# %%
semMortosRN2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosRN2019 = semMortosRN2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em RN em 2019 é: ' + str(round((probsemMortosRN2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em RN em 2019 é: 44.06%

# %%
semMortosRN2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosRN2020 = semMortosRN2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em RN em 2020 é: ' + str(round((probsemMortosRN2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em RN em 2020 é: 41.02%

# %%
semMortosRN2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosRN2021 = semMortosRN2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em RN em 2021 é: ' + str(round((probsemMortosRN2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em RN em 2021 é: 41.97%

# %%
semMortosRN2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosRN2022 = semMortosRN2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em RN em 2022 é: ' + str(round((probsemMortosRN2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em RN em 2022 é: 42.11%

# %%
semMortosRN2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosRN2023 = semMortosRN2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em RN em 2023 é: ' + str(round((probsemMortosRN2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em RN em 2023 é: 43.9%

# %%
semMortesRN = [probsemMortosRN2020, probsemMortosRN2021, probsemMortosRN2022, probsemMortosRN2023]
mediaSemMortesRN = sum(semMortesRN) / len(semMortesRN)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em RN de 2020 a 2023 é: ' + str(round((mediaSemMortesRN * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em RN de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em PB**

# %%
semMortosPB2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosPB2019 = semMortosPB2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PB em 2019 é: ' + str(round((probsemMortosPB2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PB em 2019 é: 44.06%

# %%
semMortosPB2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosPB2020 = semMortosPB2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PB em 2020 é: ' + str(round((probsemMortosPB2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PB em 2020 é: 41.02%

# %%
semMortosPB2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosPB2021 = semMortosPB2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PB em 2021 é: ' + str(round((probsemMortosPB2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PB em 2021 é: 41.97%

# %%
semMortosPB2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosPB2022 = semMortosPB2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PB em 2022 é: ' + str(round((probsemMortosPB2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PB em 2022 é: 42.11%

# %%
semMortosPB2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosPB2023 = semMortosPB2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em PB em 2023 é: ' + str(round((probsemMortosPB2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PB em 2023 é: 43.9%

# %%
semMortesPB = [probsemMortosPB2020, probsemMortosPB2021, probsemMortosPB2022, probsemMortosPB2023]
mediaSemMortesPB = sum(semMortesPB) / len(semMortesPB)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em PB de 2020 a 2023 é: ' + str(round((mediaSemMortesPB * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em PB de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em AL**

# %%
semMortosAL2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosAL2019 = semMortosAL2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em AL em 2019 é: ' + str(round((probsemMortosAL2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em AL em 2019 é: 44.06%

# %%
semMortosAL2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosAL2020 = semMortosAL2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em AL em 2020 é: ' + str(round((probsemMortosAL2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em AL em 2020 é: 41.02%

# %%
semMortosAL2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosAL2021 = semMortosAL2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em AL em 2021 é: ' + str(round((probsemMortosAL2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em AL em 2021 é: 41.97%

# %%
semMortosAL2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosAL2022 = semMortosAL2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em AL em 2022 é: ' + str(round((probsemMortosAL2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em AL em 2022 é: 42.11%

# %%
semMortosAL2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosAL2023 = semMortosAL2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em AL em 2023 é: ' + str(round((probsemMortosAL2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em AL em 2023 é: 43.9%

# %%
semMortesAL = [probsemMortosAL2020, probsemMortosAL2021, probsemMortosAL2022, probsemMortosAL2023]
mediaSemMortesAL = sum(semMortesAL) / len(semMortesAL)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em AL de 2020 a 2023 é: ' + str(round((mediaSemMortesAL * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em AL de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em SE**

# %%
semMortosSE2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosSE2019 = semMortosSE2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em SE em 2019 é: ' + str(round((probsemMortosSE2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em SE em 2019 é: 44.06%

# %%
semMortosSE2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosSE2019 = semMortosSE2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em SE em 2019 é: ' + str(round((probsemMortosSE2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em SE em 2019 é: 44.06%

# %%
semMortosSE2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosSE2020 = semMortosSE2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em SE em 2020 é: ' + str(round((probsemMortosSE2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em SE em 2020 é: 41.02%

# %%
semMortosSE2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosSE2021 = semMortosSE2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em SE em 2021 é: ' + str(round((probsemMortosSE2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em SE em 2021 é: 41.97%

# %%
semMortosSE2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosSE2022 = semMortosSE2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em SE em 2022 é: ' + str(round((probsemMortosSE2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em SE em 2022 é: 42.11%

# %%
semMortosSE2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosSE2023 = semMortosSE2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em SE em 2023 é: ' + str(round((probsemMortosSE2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em SE em 2023 é: 43.9%

# %%
semMortesSE = [probsemMortosSE2020, probsemMortosSE2021, probsemMortosSE2022, probsemMortosSE2023]
mediaSemMortesSE = sum(semMortesSE) / len(semMortesSE)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em SE de 2020 a 2023 é: ' + str(round((mediaSemMortesSE * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em SE de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em BA: **

# %%
semMortosBA2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosBA2019 = semMortosBA2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em BA em 2019 é: ' + str(round((probsemMortosBA2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em BA em 2019 é: 44.06%

# %%
semMortosBA2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosBA2020 = semMortosBA2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em BA em 2020 é: ' + str(round((probsemMortosBA2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em BA em 2020 é: 41.02%

# %%
semMortosBA2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosBA2021 = semMortosBA2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em BA em 2021 é: ' + str(round((probsemMortosBA2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em BA em 2021 é: 41.97%

# %%
semMortosBA2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosBA2022 = semMortosBA2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em BA em 2022 é: ' + str(round((probsemMortosBA2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em BA em 2022 é: 42.11%

# %%
semMortosBA2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosBA2023 = semMortosBA2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em BA em 2023 é: ' + str(round((probsemMortosBA2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em BA em 2023 é: 43.9%

# %%
semMortesBA = [probsemMortosBA2020, probsemMortosBA2021, probsemMortosBA2022, probsemMortosBA2023]
mediaSemMortesBA = sum(semMortesBA) / len(semMortesBA)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em BA de 2020 a 2023 é: '+ str(round((mediaSemMortesBA * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em BA de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em GO**

# %%
semMortosGO2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosGO2019 = semMortosGO2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em GO em 2019 é: ' + str(round((probsemMortosGO2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em GO em 2019 é: 44.06%

# %%
semMortosGO2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosGO2020 = semMortosGO2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em GO em 2020 é: ' + str(round((probsemMortosGO2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em GO em 2020 é: 41.02%

# %%
semMortosGO2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosGO2021 = semMortosGO2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em GO em 2021 é: ' + str(round((probsemMortosGO2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em GO em 2021 é: 41.97%

# %%
semMortosGO2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosGO2022 = semMortosGO2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em GO em 2022 é: ' + str(round((probsemMortosGO2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em GO em 2022 é: 42.11%

# %%
semMortosGO2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosGO2023 = semMortosGO2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em GO em 2023 é: ' + str(round((probsemMortosGO2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em GO em 2023 é: 43.9%

# %%
semMortesGO = [probsemMortosGO2020, probsemMortosGO2021, probsemMortosGO2022, probsemMortosGO2023]
mediaSemMortesGO = sum(semMortesGO) / len(semMortesGO)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em GO de 2020 a 2023 é: ' + str(round((mediaSemMortesGO * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em GO de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em MT**

# %%
semMortosMT2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosMT2019 = semMortosMT2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em MT em 2019 é: ' + str(round((probsemMortosMT2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MT em 2019 é: 44.06%

# %%
semMortosMT2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosMT2020 = semMortosMT2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em MT em 2020 é: ' + str(round((probsemMortosMT2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MT em 2020 é: 41.02%

# %%
semMortosMT2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosMT2021 = semMortosMT2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em MT em 2021 é: ' + str(round((probsemMortosMT2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MT em 2021 é: 41.97%

# %%
semMortosMT2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosMT2022 = semMortosMT2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em MT em 2022 é: ' + str(round((probsemMortosMT2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MT em 2022 é: 42.11%

# %%
semMortosMT2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosMT2023 = semMortosMT2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em MT em 2023 é: ' + str(round((probsemMortosMT2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MT em 2023 é: 43.9%

# %%
semMortesMT = [probsemMortosMT2020, probsemMortosMT2021, probsemMortosMT2022, probsemMortosMT2023]
mediaSemMortesMT = sum(semMortesMT) / len(semMortesMT)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em MT de 2020 a 2023 é: ' + str(round((mediaSemMortesMT * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MT de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em MS**

# %%
semMortosMS2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosMS2019 = semMortosMS2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em MS em 2019 é: ' + str(round((probsemMortosMS2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MS em 2019 é: 44.06%

# %%
semMortosMS2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosMS2020 = semMortosMS2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em MS em 2020 é: ' + str(round((probsemMortosMS2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MS em 2020 é: 41.02%

# %%
semMortosMS2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosMS2021 = semMortosMS2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em MS em 2021 é: ' + str(round((probsemMortosMS2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MS em 2021 é: 41.97%

# %%
semMortosMS2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosMS2022 = semMortosMS2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em MS em 2022 é: ' + str(round((probsemMortosMS2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MS em 2022 é: 42.11%

# %%
semMortosMS2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosMS2023 = semMortosMS2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos em MS em 2023 é: ' + str(round((probsemMortosMS2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MS em 2023 é: 43.9%

# %%
semMortesMS = [probsemMortosMS2020, probsemMortosMS2021, probsemMortosMS2022, probsemMortosMS2023]
mediaSemMortesMS = sum(semMortesMS) / len(semMortesMS)
print('A probabilidade dos acidentes ocorridos não deixarem mortos em MS de 2020 a 2023 é: ' + str(round((mediaSemMortesMS * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos em MS de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em DF**

# %%
semMortosDF2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosDF2019 = semMortosDF2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no DF em 2019 é: ' + str(round((probsemMortosDF2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no DF em 2019 é: 44.06%

# %%
semMortosDF2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosDF2020 = semMortosDF2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no DF em 2020 é: ' + str(round((probsemMortosDF2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no DF em 2020 é: 41.02%

# %%
semMortosDF2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosDF2021 = semMortosDF2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no DF em 2021 é: ' + str(round((probsemMortosDF2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no DF em 2021 é: 41.97%

# %%
semMortosDF2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosDF2022 = semMortosDF2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no DF em 2022 é: ' + str(round((probsemMortosDF2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no DF em 2022 é: 42.11%

# %%
semMortosDF2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosDF2023 = semMortosDF2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no DF em 2023 é: ' + str(round((probsemMortosDF2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no DF em 2023 é: 43.9%

# %%
semMortesDF = [probsemMortosDF2020, probsemMortosDF2021, probsemMortosDF2022, probsemMortosDF2023]
mediaSemMortesDF = sum(semMortesDF) / len(semMortesDF)
print('A probabilidade dos acidentes ocorridos não deixarem mortos no DF de 2020 a 2023 é: ' + str(round((mediaSemMortesDF * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no DF de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em ES**

# %%
semMortosES2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosES2019 = semMortosES2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no ES em 2019 é: ' + str(round((probsemMortosES2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no ES em 2019 é: 44.06%

# %%
semMortosES2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosES2020 = semMortosES2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no ES em 2020 é: ' + str(round((probsemMortosES2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no ES em 2020 é: 41.02%

# %%
semMortosES2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosES2021 = semMortosES2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no ES em 2021 é: ' + str(round((probsemMortosES2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no ES em 2021 é: 41.97%

# %%
semMortosES2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosES2022 = semMortosES2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no ES em 2022 é: ' + str(round((probsemMortosES2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no ES em 2022 é: 42.11%

# %%
semMortosES2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosES2023 = semMortosES2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no ES em 2023 é: ' + str(round((probsemMortosES2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no ES em 2023 é: 43.9%

# %%
semMortesES = [probsemMortosES2020, probsemMortosES2021, probsemMortosES2022, probsemMortosES2023]
mediaSemMortesES = sum(semMortesES) / len(semMortesES)
print('A probabilidade dos acidentes ocorridos não deixarem mortos no ES de 2020 a 2023 é: ' + str(round((mediaSemMortesES * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no ES de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em PR**

# %%
semMortosPR2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosPR2019 = semMortosPR2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no PR em 2019 é: ' + str(round((probsemMortosPR2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no PR em 2019 é: 44.06%

# %%
semMortosPR2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosPR2020 = semMortosPR2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no PR em 2020 é: ' + str(round((probsemMortosPR2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no PR em 2020 é: 41.02%

# %%
semMortosPR2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosPR2021 = semMortosPR2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no PR em 2021 é: ' + str(round((probsemMortosPR2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no PR em 2021 é: 41.97%

# %%
semMortosPR2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosPR2022 = semMortosPR2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no PR em 2022 é: ' + str(round((probsemMortosPR2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no PR em 2022 é: 42.11%

# %%
semMortosPR2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosPR2023 = semMortosPR2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no PR em 2023 é: ' + str(round((probsemMortosPR2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no PR em 2023 é: 43.9%

# %%
semMortesPR = [probsemMortosPR2020, probsemMortosPR2021, probsemMortosPR2022, probsemMortosPR2023]
mediaSemMortesPR = sum(semMortesPR) / len(semMortesPR)
print('A probabilidade dos acidentes ocorridos não deixarem mortos no PR de 2020 a 2023 é: ' + str(round((mediaSemMortesPR * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no PR de 2020 a 2023 é: 42.25%

# %% [markdown]
# **Probabilidade dos acidentes não deixarem mortos em RS**

# %%
semMortosRS2019 = len(leitura2019[(leitura2019['mortos'] == 0) & (leitura2019['feridos'] > 0) & (leitura2019['ilesos'] > 0)])
probsemMortosRS2019 = semMortosRS2019 / len(leitura2019)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no RS em 2019 é: ' + str(round((probsemMortosRS2019 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no RS em 2019 é: 44.06%

# %%
semMortosRS2020 = len(leitura2020[(leitura2020['mortos'] == 0) & (leitura2020['feridos'] > 0) & (leitura2020['ilesos'] > 0)])
probsemMortosRS2020 = semMortosRS2020 / len(leitura2020)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no RS em 2020 é: ' + str(round((probsemMortosRS2020 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no RS em 2020 é: 41.02%

# %%
semMortosRS2021 = len(leitura2021[(leitura2021['mortos'] == 0) & (leitura2021['feridos'] > 0) & (leitura2021['ilesos'] > 0)])
probsemMortosRS2021 = semMortosRS2021 / len(leitura2021)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no RS em 2021 é: ' + str(round((probsemMortosRS2021 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no RS em 2021 é: 41.97%

# %%
semMortosRS2022 = len(leitura2022[(leitura2022['mortos'] == 0) & (leitura2022['feridos'] > 0) & (leitura2022['ilesos'] > 0)])
probsemMortosRS2022 = semMortosRS2022 / len(leitura2022)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no RS em 2022 é: ' + str(round((probsemMortosRS2022 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no RS em 2022 é: 42.11%

# %%
semMortosRS2023 = len(leitura2023[(leitura2023['mortos'] == 0) & (leitura2023['feridos'] > 0) & (leitura2023['ilesos'] > 0)])
probsemMortosRS2023 = semMortosRS2023 / len(leitura2023)

print('A probabilidade dos acidentes ocorridos não deixarem mortos no RS em 2023 é: ' + str(round((probsemMortosRS2023 * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no RS em 2023 é: 43.9%

# %%
semMortesRS = [probsemMortosRS2020, probsemMortosRS2021, probsemMortosRS2022, probsemMortosRS2023]
mediaSemMortesRS = sum(semMortesRS) / len(semMortesRS)
print('A probabilidade dos acidentes ocorridos não deixarem mortos no RS de 2020 a 2023 é: ' + str(round((mediaSemMortesRS * 100), 2)) + '%')
# Out:
# A probabilidade dos acidentes ocorridos não deixarem mortos no RS de 2020 a 2023 é: 42.25%

# %% [markdown]
# # **Probabilidade condicional / Teorema de Bayes**

# %% [markdown]
# **Probabilidade dos acidentes acontecerem com feridos dado que o acidente ocorreu na sexta-feira em SP**

# %%
probComFeridosSextaSP2019 =  len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'SP') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'SP')])
print(str(round(probComFeridosSextaSP2019*100, 2)) + "%")

# %%
probComFeridosSextaSP2020 =  len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'SP') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'SP')])
print(str(round(probComFeridosSextaSP2020 * 100, 2)) + "%")

# %%
probComFeridosSextaSP2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['feridos'] > 0)]) / len(leitura2021[leitura2021['dia_semana'] == 'sexta-feira'])
print(str(round(probComFeridosSextaSP2021 * 100, 2)) + "%")

# %%
probComFeridosSextaSP2022 =  len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'SP') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'SP')])
print(str(round(probComFeridosSextaSP2022 * 100, 2)) + "%")

# %%
probComFeridosSextaSP2023 =  len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'SP') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'SP')])
print(str(round(probComFeridosSextaSP2023 * 100, 2)) + "%")

# %%
probabilidadesSP = [probComFeridosSextaSP2019, probComFeridosSextaSP2020, probComFeridosSextaSP2021, probComFeridosSextaSP2022, probComFeridosSextaSP2023]
media_probabilidadeSP = sum(probabilidadesSP) / len(probabilidadesSP)
print("Média das probabilidades: " + str(round(media_probabilidadeSP * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecerem com feridos dado que o acidente ocorreu na sexta-feira  em MG**

# %%
probComFeridosSextaMG2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'MG') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'MG')])
print(str(round(probComFeridosSextaMG2019 * 100, 2)) + "%")

# %%
probComFeridosSextaMG2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'MG') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'MG')])
print(str(round(probComFeridosSextaMG2020 * 100, 2)) + "%")

# %%
probComFeridosSextaMG2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'MG') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'MG')])
print(str(round(probComFeridosSextaMG2021 * 100, 2)) + "%")

# %%
probComFeridosSextaMG2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'MG') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'MG')])
print(str(round(probComFeridosSextaMG2022 * 100, 2)) + "%")

# %%
probComFeridosSextaMG2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'MG') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'MG')])
print(str(round(probComFeridosSextaMG2023 * 100, 2)) + "%")

# %%
probabilidadeMG = [probComFeridosSextaMG2019, probComFeridosSextaMG2020, probComFeridosSextaMG2021, probComFeridosSextaMG2022, probComFeridosSextaMG2023]
media_probabilidadeMG = sum(probabilidadeMG) / len(probabilidadeMG)

print("Média das probabilidades: " + str(round(media_probabilidadeMG * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecerem com feridos dado que o acidente ocorreu na sexta-feira  em PE**

# %%
probComFeridosSextaPE2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'PE') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'PE')])
print(str(round(probComFeridosSextaPE2019 * 100, 2)) + "%")

# %%
probComFeridosSextaPE2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'PE') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'PE')])
print(str(round(probComFeridosSextaPE2020 * 100, 2)) + "%")

# %%
probComFeridosSextaPE2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'PE') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'PE')])
print(str(round(probComFeridosSextaPE2021 * 100, 2)) + "%")

# %%
probComFeridosSextaPE2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'PE') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'PE')])
print(str(round(probComFeridosSextaPE2022 * 100, 2)) + "%")

# %%
probComFeridosSextaPE2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'PE') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'PE')])
print(str(round(probComFeridosSextaPE2023 * 100, 2)) + "%")

# %%
probabilidadesPE = [probComFeridosSextaPE2019, probComFeridosSextaPE2020, probComFeridosSextaPE2021, probComFeridosSextaPE2022, probComFeridosSextaPE2023]
media_probabilidadePE = sum(probabilidadesPE) / len(probabilidadesPE)
print("Média das probabilidades em Pernambuco (PE): " + str(round(media_probabilidadePE * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecerem com feridos dado que o acidente ocorreu na sexta-feira  no PA**

# %%
probComFeridosSextaPA2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'PA') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'PA')])
print(str(round(probComFeridosSextaPA2019 * 100, 2)) + "%")

# %%
probComFeridosSextaPA2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'PA') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'PA')])
print(str(round(probComFeridosSextaPA2020 * 100, 2)) + "%")

# %%
probComFeridosSextaPA2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'PA') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'PA')])
print(str(round(probComFeridosSextaPA2021 * 100, 2)) + "%")

# %%
probComFeridosSextaPA2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'PA') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'PA')])
print(str(round(probComFeridosSextaPA2022 * 100, 2)) + "%")

# %%
probComFeridosSextaPA2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'PA') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'PA')])
print(str(round(probComFeridosSextaPA2023 * 100, 2)) + "%")

# %%
probabilidadesPA = [probComFeridosSextaPA2019, probComFeridosSextaPA2020, probComFeridosSextaPA2021, probComFeridosSextaPA2022, probComFeridosSextaPA2023]
media_probabilidadePA = sum(probabilidadesPA) / len(probabilidadesPA)
print("Média das probabilidades no Pará (PA): " +
str(round(media_probabilidadePA * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecerem com feridos dado que o acidente ocorreu na sexta-feira em SC**

# %%
probComFeridosSextaSC2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'SC') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'SC')])
print(str(round(probComFeridosSextaSC2019 * 100, 2)) + "%")

# %%
probComFeridosSextaSC2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'SC') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'SC')])
print(str(round(probComFeridosSextaSC2020 * 100, 2)) + "%")

# %%
probComFeridosSextaSC2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'SC') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'SC')])
print(str(round(probComFeridosSextaSC2021 * 100, 2)) + "%")

# %%
probComFeridosSextaSC2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'SC') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'SC')])
print(str(round(probComFeridosSextaSC2022 * 100, 2)) + "%")

# %%
probComFeridosSextaSC2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'SC') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'SC')])
print(str(round(probComFeridosSextaSC2023 * 100, 2)) + "%")

# %%
probabilidadesSC = [probComFeridosSextaSC2019, probComFeridosSextaSC2020, probComFeridosSextaSC2021, probComFeridosSextaSC2022, probComFeridosSextaSC2023]
media_probabilidadeSC = sum(probabilidadesSC) / len(probabilidadesSC)
print("Média das probabilidades em Santa Catarina (SC): " +
str(round(media_probabilidadeSC * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecerem com feridos dado que o acidente ocorreu na sexta-feira  no RJ**

# %%
probComFeridosSextaRJ2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'RJ') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'RJ')])
print(str(round(probComFeridosSextaRJ2019 * 100, 2)) + "%")

# %%
probComFeridosSextaRJ2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'RJ') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'RJ')])
print(str(round(probComFeridosSextaRJ2020 * 100, 2)) + "%")

# %%
probComFeridosSextaRJ2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'RJ') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'RJ')])
print(str(round(probComFeridosSextaRJ2021 * 100, 2)) + "%")

# %%
probComFeridosSextaRJ2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'RJ') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'RJ')])
print(str(round(probComFeridosSextaRJ2022 * 100, 2)) + "%")

# %%
probComFeridosSextaRJ2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'RJ') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'RJ')])
print(str(round(probComFeridosSextaRJ2023 * 100, 2)) + "%")

# %%
probabilidadesRJ = [probComFeridosSextaRJ2019, probComFeridosSextaRJ2020, probComFeridosSextaRJ2021, probComFeridosSextaRJ2022, probComFeridosSextaRJ2023]
media_probabilidadeRJ = sum(probabilidadesRJ) / len(probabilidadesRJ)
print("Média das probabilidades no Rio de Janeiro (RJ): " +
str(round(media_probabilidadeRJ * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira em AM**

# %%
probComFeridosSextaAM2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'AM') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'AM')])
print(str(round(probComFeridosSextaAM2019 * 100, 2)) + "%")

# %%
probComFeridosSextaAM2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'AM') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'AM')])
print(str(round(probComFeridosSextaAM2020 * 100, 2)) + "%")

# %%
probComFeridosSextaAM2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'AM') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'AM')])
print(str(round(probComFeridosSextaAM2021 * 100, 2)) + "%")

# %%
probComFeridosSextaAM2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'AM') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'AM')])
print(str(round(probComFeridosSextaAM2022 * 100, 2)) + "%")

# %%
probComFeridosSextaAM2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'AM') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'AM')])
print(str(round(probComFeridosSextaAM2023 * 100, 2)) + "%")

# %%
probabilidadesAM = [probComFeridosSextaAM2019, probComFeridosSextaAM2020, probComFeridosSextaAM2021, probComFeridosSextaAM2022, probComFeridosSextaAM2023]
media_probabilidadeAM = sum(probabilidadesAM) / len(probabilidadesAM)
print("Média das probabilidades no Amazonas (AM): " +
str(round(media_probabilidadeAM * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira  em AC**

# %%
probComFeridosSextaAC2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'AC') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'AC')])
print(str(round(probComFeridosSextaAC2019 * 100, 2)) + "%")

# %%
probComFeridosSextaAC2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'AC') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'AC')])
print(str(round(probComFeridosSextaAC2020 * 100, 2)) + "%")

# %%
probComFeridosSextaAC2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'AC') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'AC')])
print(str(round(probComFeridosSextaAC2021 * 100, 2)) + "%")

# %%
probComFeridosSextaAC2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'AC') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'AC')])
print(str(round(probComFeridosSextaAC2022 * 100, 2)) + "%")

# %%
probComFeridosSextaAC2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'AC') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'AC')])
print(str(round(probComFeridosSextaAC2023 * 100, 2)) + "%")

# %%
probabilidadesAC = [probComFeridosSextaAC2019, probComFeridosSextaAC2020, probComFeridosSextaAC2021, probComFeridosSextaAC2022, probComFeridosSextaAC2023]
media_probabilidadeAC = sum(probabilidadesAC) / len(probabilidadesAC)
print("Média das probabilidades no Acre (AC): " +
str(round(media_probabilidadeAC * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira em AP**

# %%
probComFeridosSextaAP2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'AP') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'AP')])
print(str(round(probComFeridosSextaAP2019 * 100, 2)) + "%")

# %%
probComFeridosSextaAP2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'AP') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'AP')])
print(str(round(probComFeridosSextaAP2020 * 100, 2)) + "%")

# %%
probComFeridosSextaAP2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'AP') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'AP')])
print(str(round(probComFeridosSextaAP2021 * 100, 2)) + "%")

# %%
probComFeridosSextaAP2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'AP') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'AP')])
print(str(round(probComFeridosSextaAP2022 * 100, 2)) + "%")

# %%
probComFeridosSextaAP2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'AP') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'AP')])
print(str(round(probComFeridosSextaAP2023 * 100, 2)) + "%")

# %%
probabilidadesAP = [probComFeridosSextaAP2019, probComFeridosSextaAP2020, probComFeridosSextaAP2021, probComFeridosSextaAP2022, probComFeridosSextaAP2023]
media_probabilidadeAP = sum(probabilidadesAP) / len(probabilidadesAP)
print("Média das probabilidades no Amapá (AP): " +
str(round(media_probabilidadeAP * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira  em RO**

# %%
probComFeridosSextaRO2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'RO') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'RO')])
print(str(round(probComFeridosSextaRO2019 * 100, 2)) + "%")

# %%
probComFeridosSextaRO2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'RO') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'RO')])
print(str(round(probComFeridosSextaRO2020 * 100, 2)) + "%")

# %%
probComFeridosSextaRO2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'RO') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'RO')])
print(str(round(probComFeridosSextaRO2021 * 100, 2)) + "%")

# %%
probComFeridosSextaRO2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'RO') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'RO')])
print(str(round(probComFeridosSextaRO2022 * 100, 2)) + "%")

# %%
probComFeridosSextaRO2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'RO') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'RO')])
print(str(round(probComFeridosSextaRO2023 * 100, 2)) + "%")

# %%
probabilidadesRO = [probComFeridosSextaRO2019, probComFeridosSextaRO2020, probComFeridosSextaRO2021, probComFeridosSextaRO2022, probComFeridosSextaRO2023]
media_probabilidadeRO = sum(probabilidadesRO) / len(probabilidadesRO)
print("Média das probabilidades em Rondônia (RO): " +
str(round(media_probabilidadeRO * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira  em RR**

# %%
probComFeridosSextaRR2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'RR') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'RR')])
print(str(round(probComFeridosSextaRR2019 * 100, 2)) + "%")

# %%
probComFeridosSextaRR2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'RR') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'RR')])
print(str(round(probComFeridosSextaRR2020 * 100, 2)) + "%")

# %%
probComFeridosSextaRR2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'RR') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'RR')])
print(str(round(probComFeridosSextaRR2021 * 100, 2)) + "%")

# %%
probComFeridosSextaRR2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'RR') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'RR')])
print(str(round(probComFeridosSextaRR2022 * 100, 2)) + "%")

# %%
probComFeridosSextaRR2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'RR') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'RR')])
print(str(round(probComFeridosSextaRR2023 * 100, 2)) + "%")

# %%
probabilidadesRR = [probComFeridosSextaRR2019, probComFeridosSextaRR2020, probComFeridosSextaRR2021, probComFeridosSextaRR2022, probComFeridosSextaRR2023]
media_probabilidadeRR = sum(probabilidadesRR) / len(probabilidadesRR)
print("Média das probabilidades em Roraima (RR): " +
str(round(media_probabilidadeRR * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira  em TO**

# %%
probComFeridosSextaTO2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'TO') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'TO')])
print(str(round(probComFeridosSextaTO2019 * 100, 2)) + "%")

# %%
probComFeridosSextaTO2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'TO') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'TO')])
print(str(round(probComFeridosSextaTO2020 * 100, 2)) + "%")

# %%
probComFeridosSextaTO2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'TO') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'TO')])
print(str(round(probComFeridosSextaTO2021 * 100, 2)) + "%")

# %%
probComFeridosSextaTO2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'TO') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'TO')])
print(str(round(probComFeridosSextaTO2022 * 100, 2)) + "%")

# %%
probComFeridosSextaTO2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'TO') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'TO')])
print(str(round(probComFeridosSextaTO2023 * 100, 2)) + "%")

# %%
probabilidadesTO = [probComFeridosSextaTO2019, probComFeridosSextaTO2020, probComFeridosSextaTO2021, probComFeridosSextaTO2022, probComFeridosSextaTO2023]
media_probabilidadeTO = sum(probabilidadesTO) / len(probabilidadesTO)
print("Média das probabilidades em Tocantins (TO): " +
str(round(media_probabilidadeTO * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira  em MA**

# %%
probComFeridosSextaMA2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'MA') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'MA')])
print(str(round(probComFeridosSextaMA2019 * 100, 2)) + "%")

# %%
probComFeridosSextaMA2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'MA') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'MA')])
print(str(round(probComFeridosSextaMA2020 * 100, 2)) + "%")

# %%
probComFeridosSextaMA2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'MA') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'MA')])
print(str(round(probComFeridosSextaMA2021 * 100, 2)) + "%")

# %%
probComFeridosSextaMA2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'MA') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'MA')])
print(str(round(probComFeridosSextaMA2022 * 100, 2)) + "%")

# %%
probComFeridosSextaMA2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'MA') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'MA')])
print(str(round(probComFeridosSextaMA2023 * 100, 2)) + "%")

# %%
probabilidadesMA = [probComFeridosSextaMA2019, probComFeridosSextaMA2020, probComFeridosSextaMA2021, probComFeridosSextaMA2022, probComFeridosSextaMA2023]
media_probabilidadeMA = sum(probabilidadesMA) / len(probabilidadesMA)
print("Média das probabilidades no Maranhão (MA): " +
str(round(media_probabilidadeMA * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira  em PI**

# %%
probComFeridosSextaPI2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'PI') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'PI')])
print(str(round(probComFeridosSextaPI2019 * 100, 2)) + "%")

# %%
probComFeridosSextaPI2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'PI') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'PI')])
print(str(round(probComFeridosSextaPI2020 * 100, 2)) + "%")

# %%
probComFeridosSextaPI2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'PI') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'PI')])
print(str(round(probComFeridosSextaPI2021 * 100, 2)) + "%")

# %%
probComFeridosSextaPI2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'PI') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'PI')])
print(str(round(probComFeridosSextaPI2022 * 100, 2)) + "%")

# %%
probComFeridosSextaPI2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'PI') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'PI')])
print(str(round(probComFeridosSextaPI2023 * 100, 2)) + "%")

# %%
probabilidadesPI = [probComFeridosSextaPI2019, probComFeridosSextaPI2020, probComFeridosSextaPI2021, probComFeridosSextaPI2022, probComFeridosSextaPI2023]
media_probabilidadePI = sum(probabilidadesPI) / len(probabilidadesPI)
print("Média das probabilidades no Piauí (PI): " +
str(round(media_probabilidadePI * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira  em CE**

# %%
probComFeridosSextaCE2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'CE') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'CE')])
print(str(round(probComFeridosSextaCE2019 * 100, 2)) + "%")

# %%
probComFeridosSextaCE2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'CE') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'CE')])
print(str(round(probComFeridosSextaCE2020 * 100, 2)) + "%")

# %%
probComFeridosSextaCE2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'CE') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'CE')])
print(str(round(probComFeridosSextaCE2021 * 100, 2)) + "%")

# %%
probComFeridosSextaCE2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'CE') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'CE')])
print(str(round(probComFeridosSextaCE2022 * 100, 2)) + "%")

# %%
probComFeridosSextaCE2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'CE') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'CE')])
print(str(round(probComFeridosSextaCE2023 * 100, 2)) + "%")

# %%
probabilidadesCE = [probComFeridosSextaCE2019, probComFeridosSextaCE2020, probComFeridosSextaCE2021, probComFeridosSextaCE2022, probComFeridosSextaCE2023]
media_probabilidadeCE = sum(probabilidadesCE) / len(probabilidadesCE)
print("Média das probabilidades no Ceará (CE): " +
str(round(media_probabilidadeCE * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira  em RN**

# %%
probComFeridosSextaRN2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'RN') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'RN')])
print(str(round(probComFeridosSextaRN2019 * 100, 2)) + "%")

# %%
probComFeridosSextaRN2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'RN') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'RN')])
print(str(round(probComFeridosSextaRN2020 * 100, 2)) + "%")

# %%
probComFeridosSextaRN2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'RN') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'RN')])
print(str(round(probComFeridosSextaRN2021 * 100, 2)) + "%")

# %%
probComFeridosSextaRN2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'RN') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'RN')])
print(str(round(probComFeridosSextaRN2022 * 100, 2)) + "%")

# %%
probComFeridosSextaRN2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'RN') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'RN')])
print(str(round(probComFeridosSextaRN2023 * 100, 2)) + "%")

# %%
probabilidadesRN = [probComFeridosSextaRN2019, probComFeridosSextaRN2020, probComFeridosSextaRN2021, probComFeridosSextaRN2022, probComFeridosSextaRN2023]
media_probabilidadeRN = sum(probabilidadesRN) / len(probabilidadesRN)
print("Média das probabilidades no Rio Grande do Norte (RN): " +
str(round(media_probabilidadeRN * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira  em PB**

# %%
probComFeridosSextaPB2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'PB') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'PB')])
print(str(round(probComFeridosSextaPB2019 * 100, 2)) + "%")

# %%
probComFeridosSextaPB2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'PB') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'PB')])
print(str(round(probComFeridosSextaPB2020 * 100, 2)) + "%")

# %%
probComFeridosSextaPB2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'PB') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'PB')])
print(str(round(probComFeridosSextaPB2021 * 100, 2)) + "%")

# %%
probComFeridosSextaPB2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'PB') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'PB')])
print(str(round(probComFeridosSextaPB2022 * 100, 2)) + "%")

# %%
probComFeridosSextaPB2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'PB') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'PB')])
print(str(round(probComFeridosSextaPB2023 * 100, 2)) + "%")

# %%
probabilidadesPB = [probComFeridosSextaPB2019, probComFeridosSextaPB2020, probComFeridosSextaPB2021, probComFeridosSextaPB2022, probComFeridosSextaPB2023]
media_probabilidadePB = sum(probabilidadesPB) / len(probabilidadesPB)
print("Média das probabilidades na Paraíba (PB): " +
str(round(media_probabilidadePB * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira em AL**

# %%
probComFeridosSextaAL2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'AL') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'AL')])
print(str(round(probComFeridosSextaAL2019 * 100, 2)) + "%")

# %%
probComFeridosSextaAL2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'AL') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'AL')])
print(str(round(probComFeridosSextaAL2020 * 100, 2)) + "%")

# %%
probComFeridosSextaAL2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'AL') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'AL')])
print(str(round(probComFeridosSextaAL2021 * 100, 2)) + "%")

# %%
probComFeridosSextaAL2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'AL') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'AL')])
print(str(round(probComFeridosSextaAL2022 * 100, 2)) + "%")

# %%
probComFeridosSextaAL2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'AL') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'AL')])
print(str(round(probComFeridosSextaAL2023 * 100, 2)) + "%")

# %%
probabilidadesAL = [probComFeridosSextaAL2019, probComFeridosSextaAL2020, probComFeridosSextaAL2021, probComFeridosSextaAL2022, probComFeridosSextaAL2023]
media_probabilidadeAL = sum(probabilidadesAL) / len(probabilidadesAL)
print("Média das probabilidades em Alagoas (AL): " +
str(round(media_probabilidadeAL * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira  em SE**

# %%
probComFeridosSextaSE2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'SE') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'SE')])
print(str(round(probComFeridosSextaSE2019 * 100, 2)) + "%")

# %%
probComFeridosSextaSE2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'SE') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'SE')])
print(str(round(probComFeridosSextaSE2020 * 100, 2)) + "%")

# %%
probComFeridosSextaSE2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'SE') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'SE')])
print(str(round(probComFeridosSextaSE2021 * 100, 2)) + "%")

# %%
probComFeridosSextaSE2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'SE') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'SE')])
print(str(round(probComFeridosSextaSE2022 * 100, 2)) + "%")

# %%
probComFeridosSextaSE2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'SE') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'SE')])
print(str(round(probComFeridosSextaSE2023 * 100, 2)) + "%")

# %%
probabilidadesSE = [probComFeridosSextaSE2019, probComFeridosSextaSE2020, probComFeridosSextaSE2021, probComFeridosSextaSE2022, probComFeridosSextaSE2023]
media_probabilidadeSE = sum(probabilidadesSE) / len(probabilidadesSE)
print("Média das probabilidades em Sergipe (SE): " +
str(round(media_probabilidadeSE * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira  em BA**

# %%
probComFeridosSextaBA2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'BA') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'BA')])
print(str(round(probComFeridosSextaBA2019 * 100, 2)) + "%")

# %%
probComFeridosSextaBA2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'BA') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'BA')])
print(str(round(probComFeridosSextaBA2020 * 100, 2)) + "%")

# %%
probComFeridosSextaBA2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'BA') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'BA')])
print(str(round(probComFeridosSextaBA2021 * 100, 2)) + "%")

# %%
probComFeridosSextaBA2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'BA') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'BA')])
print(str(round(probComFeridosSextaBA2022 * 100, 2)) + "%")

# %%
probComFeridosSextaBA2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'BA') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'BA')])
print(str(round(probComFeridosSextaBA2023 * 100, 2)) + "%")

# %%
probabilidadesBA = [probComFeridosSextaBA2019, probComFeridosSextaBA2020, probComFeridosSextaBA2021, probComFeridosSextaBA2022, probComFeridosSextaBA2023]
media_probabilidadeBA = sum(probabilidadesBA) / len(probabilidadesBA)
print("Média das probabilidades na Bahia (BA): " +
str(round(media_probabilidadeBA * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira  em GO**

# %%
probComFeridosSextaGO2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'GO') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'GO')])
print(str(round(probComFeridosSextaGO2019 * 100, 2)) + "%")

# %%
probComFeridosSextaGO2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'GO') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'GO')])
print(str(round(probComFeridosSextaGO2020 * 100, 2)) + "%")

# %%
probComFeridosSextaGO2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'GO') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'GO')])
print(str(round(probComFeridosSextaGO2021 * 100, 2)) + "%")

# %%
probComFeridosSextaGO2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'GO') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'GO')])
print(str(round(probComFeridosSextaGO2022 * 100, 2)) + "%")

# %%
probComFeridosSextaGO2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'GO') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'GO')])
print(str(round(probComFeridosSextaGO2023 * 100, 2)) + "%")

# %%
probabilidadesGO = [probComFeridosSextaGO2019, probComFeridosSextaGO2020, probComFeridosSextaGO2021, probComFeridosSextaGO2022, probComFeridosSextaGO2023]
media_probabilidadeGO = sum(probabilidadesGO) / len(probabilidadesGO)
print("Média das probabilidades em Goiás (GO): " +
str(round(media_probabilidadeGO * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira  em MT**

# %%
probComFeridosSextaMT2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'MT') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'MT')])
print(str(round(probComFeridosSextaMT2019 * 100, 2)) + "%")

# %%
probComFeridosSextaMT2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'MT') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'MT')])
print(str(round(probComFeridosSextaMT2020 * 100, 2)) + "%")

# %%
probComFeridosSextaMT2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'MT') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'MT')])
print(str(round(probComFeridosSextaMT2021 * 100, 2)) + "%")

# %%
probComFeridosSextaMT2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'MT') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'MT')])
print(str(round(probComFeridosSextaMT2022 * 100, 2)) + "%")

# %%
probComFeridosSextaMT2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'MT') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'MT')])
print(str(round(probComFeridosSextaMT2023 * 100, 2)) + "%")

# %%
probabilidadesMT = [probComFeridosSextaMT2019, probComFeridosSextaMT2020, probComFeridosSextaMT2021, probComFeridosSextaMT2022, probComFeridosSextaMT2023]
media_probabilidadeMT = sum(probabilidadesMT) / len(probabilidadesMT)
print("Média das probabilidades em Mato Grosso (MT): " +
str(round(media_probabilidadeMT * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira  em MS**

# %%
probComFeridosSextaMS2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'MS') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'MS')])
print(str(round(probComFeridosSextaMS2019 * 100, 2)) + "%")

# %%
probComFeridosSextaMS2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'MS') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'MS')])
print(str(round(probComFeridosSextaMS2020 * 100, 2)) + "%")

# %%
probComFeridosSextaMS2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'MS') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'MS')])
print(str(round(probComFeridosSextaMS2021 * 100, 2)) + "%")

# %%
probComFeridosSextaMS2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'MS') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'MS')])
print(str(round(probComFeridosSextaMS2022 * 100, 2)) + "%")

# %%
probComFeridosSextaMS2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'MS') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'MS')])
print(str(round(probComFeridosSextaMS2023 * 100, 2)) + "%")

# %%
probabilidadesMS = [probComFeridosSextaMS2019, probComFeridosSextaMS2020, probComFeridosSextaMS2021, probComFeridosSextaMS2022, probComFeridosSextaMS2023]
media_probabilidadeMS = sum(probabilidadesMS) / len(probabilidadesMS)
print("Média das probabilidades em Mato Grosso do Sul (MS): " +
str(round(media_probabilidadeMS * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira  em DF**

# %%
probComFeridosSextaDF2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'DF') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'DF')])
print(str(round(probComFeridosSextaDF2019 * 100, 2)) + "%")

# %%
probComFeridosSextaDF2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'DF') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'DF')])
print(str(round(probComFeridosSextaDF2020 * 100, 2)) + "%")

# %%
probComFeridosSextaDF2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'DF') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'DF')])
print(str(round(probComFeridosSextaDF2021 * 100, 2)) + "%")

# %%
probComFeridosSextaDF2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'DF') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'DF')])
print(str(round(probComFeridosSextaDF2022 * 100, 2)) + "%")

# %%
probComFeridosSextaDF2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'DF') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'DF')])
print(str(round(probComFeridosSextaDF2023 * 100, 2)) + "%")

# %%
probabilidadesDF = [probComFeridosSextaDF2019, probComFeridosSextaDF2020, probComFeridosSextaDF2021, probComFeridosSextaDF2022, probComFeridosSextaDF2023]
media_probabilidadeDF = sum(probabilidadesDF) / len(probabilidadesDF)
print("Média das probabilidades no Distrito Federal (DF): " +
str(round(media_probabilidadeDF * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira em ES**

# %%
probComFeridosSextaES2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'ES') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'ES')])
print(str(round(probComFeridosSextaES2019 * 100, 2)) + "%")

# %%
probComFeridosSextaES2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'ES') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'ES')])
print(str(round(probComFeridosSextaES2020 * 100, 2)) + "%")

# %%
probComFeridosSextaES2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'ES') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'ES')])
print(str(round(probComFeridosSextaES2021 * 100, 2)) + "%")

# %%
probComFeridosSextaES2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'ES') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'ES')])
print(str(round(probComFeridosSextaES2022 * 100, 2)) + "%")

# %%
probComFeridosSextaES2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'ES') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'ES')])
print(str(round(probComFeridosSextaES2023 * 100, 2)) + "%")

# %%
probabilidadesES = [probComFeridosSextaES2019, probComFeridosSextaES2020, probComFeridosSextaES2021, probComFeridosSextaES2022, probComFeridosSextaES2023]
media_probabilidadeES = sum(probabilidadesES) / len(probabilidadesES)
print("Média das probabilidades no Espírito Santo (ES): " +
str(round(media_probabilidadeES * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira  em PR**

# %%
probComFeridosSextaPR2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'PR') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'PR')])
print(str(round(probComFeridosSextaPR2019 * 100, 2)) + "%")

# %%
probComFeridosSextaPR2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'PR') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'PR')])
print(str(round(probComFeridosSextaPR2020 * 100, 2)) + "%")

# %%
probComFeridosSextaPR2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'PR') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'PR')])
print(str(round(probComFeridosSextaPR2021 * 100, 2)) + "%")

# %%
probComFeridosSextaPR2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'PR') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'PR')])
print(str(round(probComFeridosSextaPR2022 * 100, 2)) + "%")

# %%
probComFeridosSextaPR2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'PR') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'PR')])
print(str(round(probComFeridosSextaPR2023 * 100, 2)) + "%")

# %%
probabilidadesPR = [probComFeridosSextaPR2019, probComFeridosSextaPR2020, probComFeridosSextaPR2021, probComFeridosSextaPR2022, probComFeridosSextaPR2023]
media_probabilidadePR = sum(probabilidadesPR) / len(probabilidadesPR)
print("Média das probabilidades no Paraná (PR): " +
str(round(media_probabilidadePR * 100, 2)) + "%")

# %% [markdown]
# **Probabilidade dos acidentes acontecem com feridos dado que o acidente ocorreu na sexta-feira em RS**

# %%
probComFeridosSextaRS2019 = len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'RS') & (leitura2019['feridos'] > 0)]) / len(leitura2019[(leitura2019['dia_semana'] == 'sexta-feira') & (leitura2019['uf'] == 'RS')])
print(str(round(probComFeridosSextaRS2019 * 100, 2)) + "%")

# %%
probComFeridosSextaRS2020 = len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'RS') & (leitura2020['feridos'] > 0)]) / len(leitura2020[(leitura2020['dia_semana'] == 'sexta-feira') & (leitura2020['uf'] == 'RS')])
print(str(round(probComFeridosSextaRS2020 * 100, 2)) + "%")

# %%
probComFeridosSextaRS2021 = len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'RS') & (leitura2021['feridos'] > 0)]) / len(leitura2021[(leitura2021['dia_semana'] == 'sexta-feira') & (leitura2021['uf'] == 'RS')])
print(str(round(probComFeridosSextaRS2021 * 100, 2)) + "%")

# %%
probComFeridosSextaRS2022 = len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'RS') & (leitura2022['feridos'] > 0)]) / len(leitura2022[(leitura2022['dia_semana'] == 'sexta-feira') & (leitura2022['uf'] == 'RS')])
print(str(round(probComFeridosSextaRS2022 * 100, 2)) + "%")

# %%
probComFeridosSextaRS2023 = len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'RS') & (leitura2023['feridos'] > 0)]) / len(leitura2023[(leitura2023['dia_semana'] == 'sexta-feira') & (leitura2023['uf'] == 'RS')])
print(str(round(probComFeridosSextaRS2023 * 100, 2)) + "%")

# %%
probabilidadesRS = [probComFeridosSextaRS2019, probComFeridosSextaRS2020, probComFeridosSextaRS2021, probComFeridosSextaRS2022, probComFeridosSextaRS2023]
media_probabilidadeRS = sum(probabilidadesRS) / len(probabilidadesRS)
print("Média das probabilidades no Rio Grande do Sul (RS): " +
str(round(media_probabilidadeRS * 100, 2)) + "%")

# %% [markdown]
# # **Variáveis aleatórias**

# %%
leitura2019['feridos'] = leitura2019['feridos_leves'] + leitura2019['feridos_graves']

# %%
leitura2019['feridos'].value_counts()
# Out:
# feridos
# 1     37106
# 0     14513
# 2     11057
# 3      2639
# 4      1231
# 5       537
# 6       210
# 7        74
# 8        52
# 9        28
# 10       17
# 14       13
# 12        9
# 13        8
# 11        7
# 15        7
# 16        5
# 17        4
# 21        4
# 26        3
# 23        3
# 20        3
# 24        3
# 19        2
# 36        2
# 18        2
# 25        2
# 28        2
# 22        2
# 42        1
# 46        1
# 27        1
# 47        1
# 35        1
# 34        1
# 49        1
# 29        1
# 44        1
# 45        1
# 48        1
# Name: count, dtype: int64

# %%
leitura2019['feridos'].value_counts(sort = False).sort_index()
# Out:
# feridos
# 0     14513
# 1     37106
# 2     11057
# 3      2639
# 4      1231
# 5       537
# 6       210
# 7        74
# 8        52
# 9        28
# 10       17
# 11        7
# 12        9
# 13        8
# 14       13
# 15        7
# 16        5
# 17        4
# 18        2
# 19        2
# 20        3
# 21        4
# 22        2
# 23        3
# 24        3
# 25        2
# 26        3
# 27        1
# 28        2
# 29        1
# 34        1
# 35        1
# 36        2
# 42        1
# 44        1
# 45        1
# 46        1
# 47        1
# 48        1
# 49        1
# Name: count, dtype: int64

# %%
leitura2020['feridos'] = leitura2020['feridos_leves'] + leitura2020['feridos_graves']

# %%
leitura2020['feridos'].value_counts()
# Out:
# feridos
# 1     34751
# 0     14449
# 2     10173
# 3      2366
# 4      1038
# 5       469
# 6       160
# 7        65
# 8        32
# 9        19
# 10        9
# 12        8
# 11        6
# 13        4
# 17        3
# 33        2
# 21        2
# 23        2
# 20        2
# 26        2
# 25        2
# 16        1
# 32        1
# 14        1
# 28        1
# 39        1
# 31        1
# 15        1
# 19        1
# 34        1
# 44        1
# 30        1
# 24        1
# Name: count, dtype: int64

# %%
leitura2020['feridos'].value_counts(sort = False).sort_index()
# Out:
# feridos
# 0     14449
# 1     34751
# 2     10173
# 3      2366
# 4      1038
# 5       469
# 6       160
# 7        65
# 8        32
# 9        19
# 10        9
# 11        6
# 12        8
# 13        4
# 14        1
# 15        1
# 16        1
# 17        3
# 19        1
# 20        2
# 21        2
# 23        2
# 24        1
# 25        2
# 26        2
# 28        1
# 30        1
# 31        1
# 32        1
# 33        2
# 34        1
# 39        1
# 44        1
# Name: count, dtype: int64

# %%
leitura2021['feridos'] = leitura2021['feridos_leves'] + leitura2021['feridos_graves']

# %%
leitura2021['feridos'].value_counts()
# Out:
# feridos
# 1     35799
# 0     14691
# 2     10022
# 3      2237
# 4      1016
# 5       447
# 6       135
# 7        73
# 8        40
# 10       12
# 9        11
# 12       10
# 11        8
# 14        4
# 19        3
# 13        3
# 20        3
# 18        3
# 23        2
# 27        2
# 17        2
# 45        2
# 33        2
# 49        1
# 24        1
# 44        1
# 32        1
# 42        1
# 15        1
# 21        1
# 16        1
# 22        1
# 38        1
# 36        1
# 30        1
# Name: count, dtype: int64

# %%
leitura2021['feridos'].value_counts(sort = False).sort_index()
# Out:
# feridos
# 0     14691
# 1     35799
# 2     10022
# 3      2237
# 4      1016
# 5       447
# 6       135
# 7        73
# 8        40
# 9        11
# 10       12
# 11        8
# 12       10
# 13        3
# 14        4
# 15        1
# 16        1
# 17        2
# 18        3
# 19        3
# 20        3
# 21        1
# 22        1
# 23        2
# 24        1
# 27        2
# 30        1
# 32        1
# 33        2
# 36        1
# 38        1
# 42        1
# 44        1
# 45        2
# 49        1
# Name: count, dtype: int64

# %%
leitura2022['feridos'] = leitura2022['feridos_leves'] + leitura2022['feridos_graves']

# %%
leitura2022['feridos'].value_counts()
# Out:
# feridos
# 1     35852
# 0     14449
# 2     10018
# 3      2375
# 4      1007
# 5       454
# 6       160
# 7        70
# 8        39
# 9        24
# 11       16
# 10       15
# 12       13
# 14        8
# 15        6
# 13        6
# 18        5
# 17        4
# 20        4
# 22        3
# 33        3
# 23        2
# 19        2
# 26        1
# 16        1
# 29        1
# 30        1
# 55        1
# 54        1
# 51        1
# 35        1
# 44        1
# 25        1
# 28        1
# 40        1
# Name: count, dtype: int64

# %%
leitura2022['feridos'].value_counts(sort = False).sort_index()
# Out:
# feridos
# 0     14449
# 1     35852
# 2     10018
# 3      2375
# 4      1007
# 5       454
# 6       160
# 7        70
# 8        39
# 9        24
# 10       15
# 11       16
# 12       13
# 13        6
# 14        8
# 15        6
# 16        1
# 17        4
# 18        5
# 19        2
# 20        4
# 22        3
# 23        2
# 25        1
# 26        1
# 28        1
# 29        1
# 30        1
# 33        3
# 35        1
# 40        1
# 44        1
# 51        1
# 54        1
# 55        1
# Name: count, dtype: int64

# %%
leitura2023['feridos'] = leitura2023['feridos_leves'] + leitura2023['feridos_graves']

# %%
leitura2023['feridos'].value_counts()
# Out:
# feridos
# 1     18309
# 0      6759
# 2      5231
# 3      1192
# 4       522
# 5       235
# 6        86
# 7        39
# 8        17
# 9         8
# 11        7
# 14        4
# 22        4
# 13        4
# 10        4
# 12        3
# 16        3
# 25        2
# 21        2
# 44        1
# 20        1
# 38        1
# 23        1
# 29        1
# 62        1
# 30        1
# 19        1
# 15        1
# Name: count, dtype: int64

# %%
leitura2023['feridos'].value_counts(sort = False).sort_index()
# Out:
# feridos
# 0      6759
# 1     18309
# 2      5231
# 3      1192
# 4       522
# 5       235
# 6        86
# 7        39
# 8        17
# 9         8
# 10        4
# 11        7
# 12        3
# 13        4
# 14        4
# 15        1
# 16        3
# 19        1
# 20        1
# 21        2
# 22        4
# 23        1
# 25        2
# 29        1
# 30        1
# 38        1
# 44        1
# 62        1
# Name: count, dtype: int64

# %% [markdown]
# # **Função probabilidade**

# %%
fp2019 = leitura2019['feridos'].value_counts(sort=False).sort_index()/leitura2019['feridos'].count()
print(fp2019)
# Out:
# feridos
# 0     0.214829
# 1     0.549263
# 2     0.163672
# 3     0.039064
# 4     0.018222
# 5     0.007949
# 6     0.003109
# 7     0.001095
# 8     0.000770
# 9     0.000414
# 10    0.000252
# 11    0.000104
# 12    0.000133
# 13    0.000118
# 14    0.000192
# 15    0.000104
# 16    0.000074
# 17    0.000059
# 18    0.000030
# 19    0.000030
# 20    0.000044
# 21    0.000059
# 22    0.000030
# 23    0.000044
# 24    0.000044
# 25    0.000030
# 26    0.000044
# 27    0.000015
# 28    0.000030
# 29    0.000015
# 34    0.000015
# 35    0.000015
# 36    0.000030
# 42    0.000015
# 44    0.000015
# 45    0.000015
# 46    0.000015
# 47    0.000015
# 48    0.000015
# 49    0.000015
# Name: count, dtype: float64

# %%
fp2020 = leitura2020['feridos'].value_counts(sort=False).sort_index()/leitura2020['feridos'].count()
print(fp2020)
# Out:
# feridos
# 0     0.227271
# 1     0.546606
# 2     0.160013
# 3     0.037215
# 4     0.016327
# 5     0.007377
# 6     0.002517
# 7     0.001022
# 8     0.000503
# 9     0.000299
# 10    0.000142
# 11    0.000094
# 12    0.000126
# 13    0.000063
# 14    0.000016
# 15    0.000016
# 16    0.000016
# 17    0.000047
# 19    0.000016
# 20    0.000031
# 21    0.000031
# 23    0.000031
# 24    0.000016
# 25    0.000031
# 26    0.000031
# 28    0.000016
# 30    0.000016
# 31    0.000016
# 32    0.000016
# 33    0.000031
# 34    0.000016
# 39    0.000016
# 44    0.000016
# Name: count, dtype: float64

# %%
fp2021 = leitura2021['feridos'].value_counts(sort=False).sort_index()/leitura2021['feridos'].count()
print(fp2021)
# Out:
# feridos
# 0     0.227630
# 1     0.554688
# 2     0.155286
# 3     0.034661
# 4     0.015742
# 5     0.006926
# 6     0.002092
# 7     0.001131
# 8     0.000620
# 9     0.000170
# 10    0.000186
# 11    0.000124
# 12    0.000155
# 13    0.000046
# 14    0.000062
# 15    0.000015
# 16    0.000015
# 17    0.000031
# 18    0.000046
# 19    0.000046
# 20    0.000046
# 21    0.000015
# 22    0.000015
# 23    0.000031
# 24    0.000015
# 27    0.000031
# 30    0.000015
# 32    0.000015
# 33    0.000031
# 36    0.000015
# 38    0.000015
# 42    0.000015
# 44    0.000015
# 45    0.000031
# 49    0.000015
# Name: count, dtype: float64

# %%
fp2022 = leitura2022['feridos'].value_counts(sort=False).sort_index()/leitura2022['feridos'].count()
print(fp2022)
# Out:
# feridos
# 0     0.223852
# 1     0.555440
# 2     0.155205
# 3     0.036795
# 4     0.015601
# 5     0.007034
# 6     0.002479
# 7     0.001084
# 8     0.000604
# 9     0.000372
# 10    0.000232
# 11    0.000248
# 12    0.000201
# 13    0.000093
# 14    0.000124
# 15    0.000093
# 16    0.000015
# 17    0.000062
# 18    0.000077
# 19    0.000031
# 20    0.000062
# 22    0.000046
# 23    0.000031
# 25    0.000015
# 26    0.000015
# 28    0.000015
# 29    0.000015
# 30    0.000015
# 33    0.000046
# 35    0.000015
# 40    0.000015
# 44    0.000015
# 51    0.000015
# 54    0.000015
# 55    0.000015
# Name: count, dtype: float64

# %%
fp2023 = leitura2023['feridos'].value_counts(sort=False).sort_index()/leitura2023['feridos'].count()
print(fp2023)
# Out:
# feridos
# 0     0.208354
# 1     0.564396
# 2     0.161252
# 3     0.036745
# 4     0.016091
# 5     0.007244
# 6     0.002651
# 7     0.001202
# 8     0.000524
# 9     0.000247
# 10    0.000123
# 11    0.000216
# 12    0.000092
# 13    0.000123
# 14    0.000123
# 15    0.000031
# 16    0.000092
# 19    0.000031
# 20    0.000031
# 21    0.000062
# 22    0.000123
# 23    0.000031
# 25    0.000062
# 29    0.000031
# 30    0.000031
# 38    0.000031
# 44    0.000031
# 62    0.000031
# Name: count, dtype: float64

# %% [markdown]
# # **Função de repartição**

# %%
fp2019.cumsum()
# Out:
# feridos
# 0     0.214829
# 1     0.764092
# 2     0.927764
# 3     0.966828
# 4     0.985049
# 5     0.992998
# 6     0.996107
# 7     0.997202
# 8     0.997972
# 9     0.998387
# 10    0.998638
# 11    0.998742
# 12    0.998875
# 13    0.998993
# 14    0.999186
# 15    0.999289
# 16    0.999363
# 17    0.999423
# 18    0.999452
# 19    0.999482
# 20    0.999526
# 21    0.999586
# 22    0.999615
# 23    0.999660
# 24    0.999704
# 25    0.999734
# 26    0.999778
# 27    0.999793
# 28    0.999822
# 29    0.999837
# 34    0.999852
# 35    0.999867
# 36    0.999896
# 42    0.999911
# 44    0.999926
# 45    0.999941
# 46    0.999956
# 47    0.999970
# 48    0.999985
# 49    1.000000
# Name: count, dtype: float64

# %%
fp2020.cumsum()
# Out:
# feridos
# 0     0.227271
# 1     0.773877
# 2     0.933890
# 3     0.971105
# 4     0.987432
# 5     0.994809
# 6     0.997326
# 7     0.998348
# 8     0.998852
# 9     0.999151
# 10    0.999292
# 11    0.999387
# 12    0.999512
# 13    0.999575
# 14    0.999591
# 15    0.999607
# 16    0.999622
# 17    0.999670
# 19    0.999685
# 20    0.999717
# 21    0.999748
# 23    0.999780
# 24    0.999796
# 25    0.999827
# 26    0.999858
# 28    0.999874
# 30    0.999890
# 31    0.999906
# 32    0.999921
# 33    0.999953
# 34    0.999969
# 39    0.999984
# 44    1.000000
# Name: count, dtype: float64

# %%
fp2021.cumsum()
# Out:
# feridos
# 0     0.227630
# 1     0.782318
# 2     0.937604
# 3     0.972265
# 4     0.988007
# 5     0.994933
# 6     0.997025
# 7     0.998156
# 8     0.998776
# 9     0.998946
# 10    0.999132
# 11    0.999256
# 12    0.999411
# 13    0.999458
# 14    0.999520
# 15    0.999535
# 16    0.999551
# 17    0.999582
# 18    0.999628
# 19    0.999675
# 20    0.999721
# 21    0.999737
# 22    0.999752
# 23    0.999783
# 24    0.999799
# 27    0.999830
# 30    0.999845
# 32    0.999861
# 33    0.999892
# 36    0.999907
# 38    0.999923
# 42    0.999938
# 44    0.999954
# 45    0.999985
# 49    1.000000
# Name: count, dtype: float64

# %%
fp2022.cumsum()
# Out:
# feridos
# 0     0.223852
# 1     0.779293
# 2     0.934497
# 3     0.971292
# 4     0.986893
# 5     0.993927
# 6     0.996406
# 7     0.997490
# 8     0.998094
# 9     0.998466
# 10    0.998699
# 11    0.998947
# 12    0.999148
# 13    0.999241
# 14    0.999365
# 15    0.999458
# 16    0.999473
# 17    0.999535
# 18    0.999613
# 19    0.999644
# 20    0.999706
# 22    0.999752
# 23    0.999783
# 25    0.999799
# 26    0.999814
# 28    0.999830
# 29    0.999845
# 30    0.999861
# 33    0.999907
# 35    0.999923
# 40    0.999938
# 44    0.999954
# 51    0.999969
# 54    0.999985
# 55    1.000000
# Name: count, dtype: float64

# %%
fp2023.cumsum()
# Out:
# feridos
# 0     0.208354
# 1     0.772750
# 2     0.934001
# 3     0.970746
# 4     0.986837
# 5     0.994081
# 6     0.996732
# 7     0.997935
# 8     0.998459
# 9     0.998705
# 10    0.998829
# 11    0.999044
# 12    0.999137
# 13    0.999260
# 14    0.999383
# 15    0.999414
# 16    0.999507
# 19    0.999538
# 20    0.999568
# 21    0.999630
# 22    0.999753
# 23    0.999784
# 25    0.999846
# 29    0.999877
# 30    0.999908
# 38    0.999938
# 44    0.999969
# 62    1.000000
# Name: count, dtype: float64
